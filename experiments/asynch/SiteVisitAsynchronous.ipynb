# %%
import numpy as np
import torch
import torch.nn as nn
import torchvision
import torchvision.datasets as datasets
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Subset

# %%
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def encdec_accuracy(encoder, decoder, inf_gen, test_steps, device=DEVICE):
    correct = 0
    num_data = 0

    #grab a batch from the test loader
    for j in range(test_steps):
        examples, labels = next(inf_gen)
        embedding = encoder.forward(examples.to(device))
        outputs = decoder.forward(embedding.to(device))

        #for each output in the batch, check if the label is correct
        for i, output in enumerate(outputs):
            num_data += 1

            max_i = np.argmax(output.detach().cpu().numpy())
            if max_i == labels[i]:
                correct += 1

    acc = float(correct)/num_data
    
    return acc

# %%
def inf_loader_generator(dataloader):
    '''
    Generates a function that infinitely samples a dataloader
    '''
    while True:
        for x, y in dataloader:
            yield x, y

# %%
class mnist_Classifier(nn.Module):
    def __init__(self):
        super(mnist_Classifier, self).__init__()
        self.conv1 = nn.Conv2d(1, 28, kernel_size=(5,5))
        self.conv2 = nn.Conv2d(28, 32, kernel_size=(5,5))
        #ok, i undersatnd this now. the output from conv2 is 32 channels. the remaining width and height after
        # two 5x5 filters with NO PADDING and STRIDE 1 (defaults) is 20x20. So 32 channels * 20 h * 20 w
        self.fc1 = nn.Linear(32*20*20, 16)
        self.fc2 = nn.Linear(16, 10)

    def forward(self, x):
        x = self.conv1(x)
        x = nn.ReLU()(x)
        x = self.conv2(x)
        x = nn.ReLU()(x)
        # print(x.size()) --> torch.Size([16, 32, 20, 20])
        x = x.view(-1, 32*20*20)
        x = self.fc1(x)
        x = nn.ReLU()(x)
        x = self.fc2(x)
        x = nn.ReLU()(x)
        return torch.softmax(x,dim=1)

class EncoderCNN(nn.Module):
    def __init__(self, input_size=1, hidden_size=28):
        super().__init__()
        self.hidden_size = hidden_size
        self.conv = nn.Conv2d(input_size, hidden_size, kernel_size=(5,5))
        self.output_shape = (hidden_size,24,24)

    def forward(self, x):
        x = self.conv(x)
        x = nn.ReLU()(x)
        return x
    
class DecoderCNN(nn.Module):
    def __init__(self, hidden_size=28):
        super().__init__()
        self.hidden_size = hidden_size
        self.conv = nn.Conv2d(hidden_size, 32, kernel_size=(5,5))
        self.fc1 = nn.Linear(32*20*20, 16)
        self.fc2 = nn.Linear(16, 10)

    def forward(self, x):
        x = self.conv(x)
        x = nn.ReLU()(x)
        x = x.view(-1, 32*20*20)
        x = self.fc1(x)
        x = nn.ReLU()(x)
        x = self.fc2(x)
        x = nn.ReLU()(x)
        return torch.softmax(x,dim=1)
    
class EncoderCNN2(nn.Module):
    def __init__(self, input_size=1, hidden_size=28):
        super().__init__()
        self.hidden_size = hidden_size
        self.conv1 = nn.Conv2d(input_size, hidden_size, kernel_size=(5,5))
        self.conv2 = nn.Conv2d(hidden_size, 32, kernel_size=(5,5))
        self.output_shape = (hidden_size,24,24)
        self.fc1 = nn.Linear(32*20*20, 16)
        self.fc2 = nn.Linear(16, 10)

    def forward(self, x):
        x = self.conv1(x)
        x = nn.ReLU()(x)
        x = self.conv2(x)
        x = nn.ReLU()(x)
        x = x.view(-1, 32*20*20)
        x = self.fc1(x)
        x = nn.ReLU()(x)
        x = self.fc2(x)
        x = nn.ReLU()(x)
        return x
    
class DecoderCNN2(nn.Module):
    def __init__(self, hidden_size=28):
        super().__init__()
        self.hidden_size = hidden_size
        
    def forward(self, x):
        return torch.softmax(x,dim=1)

# %%
def compute_immediate_sensitivity(model, inp, loss) -> list:
    """Core. Computes immediate sensitivity"""

    # (1) first-order gradient (wrt parameters)
    first_order_grads = torch.autograd.grad(
        loss,
        model.parameters(),
        retain_graph=True,
        create_graph=True,
        # allow_unused=True
    )

    # (2) L2 norm of the gradient from (1)
    grad_l2_norm = torch.norm(torch.cat([x.view(-1) for x in first_order_grads]), p=2)

    # (3) Gradient (wrt inputs) of the L2 norm of the gradient from (2)
    sensitivity_vec = torch.autograd.grad(grad_l2_norm, inp, retain_graph=True)[0]

    # (4) L2 norm of (3) - "immediate sensitivity"
    # sensitivity = [torch.norm(v, p=2).item() for v in sensitivity_vec]
    sensitivity = torch.norm(
        sensitivity_vec.view(sensitivity_vec.shape[0], -1), p=2, dim=1
    )

    return sensitivity

# %%
def multiple_data_generators(n, dataset="mnist", folds=50, batch_sizes=16):
    if n > folds:
        raise ValueError(f"n {n} > {folds} folds")
    total = 60000
    fold_size = total//folds
    index = np.arange(total)
    np.random.shuffle(index)
    
    if np.array(batch_sizes).ndim == 0:
        batch_sizes = [batch_sizes] * n
    
    train_data_loaders = []
    test_data_loaders = []
    for i in range(n):
        batch_size = batch_sizes[i]
        if dataset == "mnist":
            mnist_trainset = datasets.MNIST(root='./data', train=True, download=True, transform=torchvision.transforms.ToTensor())
            mnist_testset = datasets.MNIST(root='./data', train=False, download=True, transform=torchvision.transforms.ToTensor())
        elif dataset == "fashionmnist":
            mnist_trainset = datasets.FashionMNIST(root='./data', train=True, download=True, transform=torchvision.transforms.ToTensor())
            mnist_testset = datasets.FashionMNIST(root='./data', train=False, download=True, transform=torchvision.transforms.ToTensor())
        else:
            raise ValueError(f"dataset {dataset}")
            
        mnist_trainset = Subset(mnist_trainset, index[i * fold_size:(i+1) * fold_size])
        print(f"data slice [{index[i * fold_size]}, ..., {index[(i+1)* fold_size - 1]}]")
        #print(i * fold_size, (i+1) * fold_size)
        #print(len(mnist_trainset))
        #print(len(mnist_testset))
        max_trainsteps = len(mnist_trainset) // batch_size
        max_teststeps = len(mnist_testset) // batch_size
        #print(max_trainsteps)
        #print(max_teststeps)

        train_loader = DataLoader(mnist_trainset, batch_size=batch_size, shuffle=True, drop_last=True)
        test_loader = DataLoader(mnist_testset, batch_size=batch_size, shuffle=True, drop_last=True)

        inf_train = inf_loader_generator(train_loader)
        inf_test = inf_loader_generator(test_loader)

        iters_per_epoch_train = len(mnist_trainset) // batch_size
        iters_per_epoch_test = len(mnist_testset) // batch_size
        
        train_data_loaders.append(inf_train)
        test_data_loaders.append(inf_test)
    
    return train_data_loaders, test_data_loaders

# %%
class MultipleDecoder:
    def __init__(self, n, hidden_size=28, device=DEVICE, alpha=20, epsilon=1e6, first_models=True, separate_encoders=False, separate_decoders=True, dataset="mnist", same_decoder_init=False, unbalanced=False):
        """
        Creates n decoders for single encoder
        """
        self.device = device
        self.n = n
        self.hidden_size = hidden_size
        self.alpha = alpha
        self.epsilon = epsilon
        self.dataset = dataset
        
        #if not first_models:
        #    print("Second Models")
        #    EncoderCNN = EncoderCNN2
        #    DecoderCNN = DecoderCNN2
        #    print(EncoderCNN)
        #    print(DecoderCNN)
        #else:
        #    EncoderCNN = EncoderCNN
        #    DecoderCNN = DecoderCNN
        
        self.separate_encoders = bool(separate_encoders)
        self.separate_decoders = bool(separate_decoders)
        if self.separate_encoders:
            self.encoders = []
            self.encoder_optimizers = []
            for i in range(self.n):
                self.encoders.append(EncoderCNN(1, self.hidden_size).to(self.device))
                self.encoder_optimizers.append(optim.Adam(self.encoders[i].parameters(),lr=0.001))
        else:
            self.encoder = EncoderCNN(1, self.hidden_size).to(self.device)
            self.encoder_optimizer = optim.Adam(self.encoder.parameters(),lr=0.001)
        
        if not self.separate_decoders:
            self.decoder = DecoderCNN(self.hidden_size).to(self.device)
            self.decoder_criterion = nn.CrossEntropyLoss()
            self.decoder_optimizer = optim.Adam(self.decoder.parameters(),lr=0.001)
        else:
            self.decoders = []
            self.decoder_criterions = []
            self.decoder_optimizers = []

            if same_decoder_init:
                decoder = DecoderCNN(self.hidden_size).to(self.device)
                for i in range(self.n):
                    if i == 0:
                        self.decoders.append(decoder)
                    else:
                        import copy
                        self.decoders.append(copy.deepcopy(decoder).to(self.device))
                    self.decoder_criterions.append(nn.CrossEntropyLoss())
                    self.decoder_optimizers.append(optim.Adam(self.decoders[i].parameters(),lr=0.001))
            else:
                for i in range(self.n):
                    self.decoders.append(DecoderCNN(self.hidden_size).to(self.device))
                    self.decoder_criterions.append(nn.CrossEntropyLoss())
                    self.decoder_optimizers.append(optim.Adam(self.decoders[i].parameters(),lr=0.001))
        
        if unbalanced:
            self.train_data_generators, self.test_data_generators = multiple_data_generators_unbalanced(self.n, batch_sizes=16, dataset=dataset)
        else:
            self.train_data_generators, self.test_data_generators = multiple_data_generators(self.n, batch_sizes=16, dataset=dataset)

    def train(self, epochs=20, train_steps_per_epoch=75, test_steps_per_epoch=50, final_test_steps=625, randomize_order=False, dp=True):
        self._train_init(epochs=epochs, train_steps_per_epoch=train_steps_per_epoch, test_steps_per_epoch=test_steps_per_epoch, randomize_order=randomize_order)
        
        import time
        start = time.time()
        elapsed_test_time = 0.0
        while True:
            if self.model_steps >= (self.train_steps_per_epoch*self.epochs):
                print("Finished Training")
                break
            if self.model_steps % self.train_steps_per_epoch == 0:
                print("Start of Epoch", (self.model_steps // self.train_steps_per_epoch))
  
            self._train_batch(dp=dp)

            if self.model_steps % self.train_steps_per_epoch == 0:
                train_losses = [round(10000 * np.mean(x))/10000 for x in self.train_losses]
                print(f"Average Train Loss:", train_losses)
                #for i in range(self.n):
                #    print(f"Average Train Loss for {i}:", np.mean(self.train_losses[i]))
                
                if test_steps_per_epoch:
                    start_test = time.time()
                    for i in range(self.n):
                        if self.separate_encoders:
                            encoder = self.encoders[i]
                        else:
                            encoder = self.encoder
                        if self.separate_decoders:
                            decoder = self.decoders[i]
                        else:
                            decoder = self.decoder
                        self.test_accs[i].append(encdec_accuracy(encoder, decoder, self.test_data_generators[i], self.test_steps_per_epoch, device=self.device))
                
                    test_accs = [x[-1] for x in self.test_accs]
                    print(f"Test Accuracy:", test_accs)
                    end_test = time.time()
                    elapsed_test_time += end_test - start_test
                #for i in range(self.n):
                #    print(f"Test Accuracy {i}:", self.test_accs[i][-1])
        
        end = time.time()
        elapsed = end - start
        self.training_time = elapsed - elapsed_test_time
        print(f"Elapsed Test Time:", elapsed_test_time)
        print(f"Elapsed Training Time:", self.training_time)
        for i in range(self.n):
            if self.separate_encoders:
                encoder = self.encoders[i]
            else:
                encoder = self.encoder
            if self.separate_decoders:
                decoder = self.decoders[i]
            else:
                decoder = self.decoder
            self.test_accs[i].append(encdec_accuracy(encoder, decoder, self.test_data_generators[i], final_test_steps, device=self.device))
            
        test_accs = [x[-1] for x in self.test_accs]
        print(f"Final Test Accuracy:", test_accs)
    
    def _train_init(self, epochs=20, train_steps_per_epoch=375, test_steps_per_epoch=100, randomize_order=False):
        self.epochs = epochs
        self.model_steps = 0
        if self.alpha is None or self.epsilon is None:
            self.epsilon_iter = None
        else:
            self.epsilon_iter = self.epsilon / self.epochs
        
        self.train_steps_per_epoch = train_steps_per_epoch
        self.test_steps_per_epoch = test_steps_per_epoch
        self.randomize_order = randomize_order
        
        # plotting criteria
        self.train_losses = [[] for x in range(self.n)]
        self.test_accs = [[] for x in range(self.n)]        

    def _train_batch(self, dp=True):
        index = list(range(self.n))
        if self.randomize_order:
            np.random.shuffle(index)
        
        for i in index:
            if dp:
                self._train_decoder_batch_dp(i)
            else:
                self._train_decoder_batch_no_dp(i)
        
        self.model_steps += 1
        
    def _train_decoder_batch_no_dp(self, i):
        """
        Train decoder i on the next batch without differential privacy
        """
        if self.separate_encoders:
            encoder = self.encoders[i]
            encoder_optimizer = self.encoder_optimizers[i]
        else:
            encoder = self.encoder
            encoder_optimizer = self.encoder_optimizer
        if self.separate_decoders:
            decoder = self.decoders[i]
            decoder_optimizer = self.decoder_optimizers[i]
            decoder_criterion = self.decoder_criterions[i]
        else:
            decoder = self.decoder
            decoder_optimizer = self.decoder_optimizer
            decoder_criterion = self.decoder_criterion
        
        x_batch_train, y_batch_train = (x.to(self.device) for x in next(self.train_data_generators[i]))
        encoder_optimizer.zero_grad()
        decoder_optimizer.zero_grad()
        
        # compute loss
        embedding = encoder.forward(x_batch_train)
        outputs = decoder.forward(embedding)
        loss = decoder_criterion(outputs, y_batch_train)

        loss.backward()
        self.train_losses[i].append(loss.item())

        # perform the a gradient step
        encoder_optimizer.step()
        decoder_optimizer.step()
        
    def _train_decoder_batch_dp(self, i):
        """
        Train decoder i on the next batch using differential privacy
        """
        if self.separate_encoders:
            encoder = self.encoders[i]
            encoder_optimizer = self.encoder_optimizers[i]
        else:
            encoder = self.encoder
            encoder_optimizer = self.encoder_optimizer
        if self.separate_decoders:
            decoder = self.decoders[i]
            decoder_optimizer = self.decoder_optimizers[i]
            decoder_criterion = self.decoder_criterions[i]
        else:
            decoder = self.decoder
            decoder_optimizer = self.decoder_optimizer
            decoder_criterion = self.decoder_criterion
        
        x_batch_train, y_batch_train = (x.to(self.device) for x in next(self.train_data_generators[i]))
        encoder_optimizer.zero_grad()
        decoder_optimizer.zero_grad()
        
        # Need grad on input for sensitivity; not sure if cloning is needed
        x_batch_train = torch.autograd.Variable(torch.clone(x_batch_train).to(self.device), requires_grad=True)
        
        # compute loss
        embedding = encoder.forward(x_batch_train)
        outputs = decoder.forward(embedding)
        loss = decoder_criterion(outputs, y_batch_train)
        
        batch_sensitivities = compute_immediate_sensitivity(
            encoder, x_batch_train, loss
        )
        batch_sensitivity = torch.max(batch_sensitivities) / len(x_batch_train)
        
        loss.backward()
        # step 4. compute noise
        # this is the scale of the Gaussian noise to be added to the batch gradient
        sigma = torch.sqrt(
            (batch_sensitivity ** 2 * self.alpha) / (2 * self.epsilon_iter)
        )
        
        # logging
        #x = loss.item()
        #if np.isnan(x):
        #    log.debug(
        #        f"Epoch (before adj): {epoch}; batch_idx: {batch_idx} loss: {loss}"
        #    )
        #    x = 0
        #    log.debug(
        #        f"    epoch (adfter adj): {epoch}; batch_idx: {batch_idx} loss: {loss}"
        #    )
        #train_loss += x
        
        self.train_losses[i].append(loss.item())
        
        # step 5. update gradients with computed sensitivities
        with torch.no_grad():
            for p in encoder.parameters():
                p.grad += sigma * torch.randn(1).to(self.device)
        
        # perform the a gradient step
        encoder_optimizer.step()
        decoder_optimizer.step()

    def fine_tune(self, dp=False, **kwargs):
        """
        Used to fine tune individual encoder / decoder pairs AFTER primary collective training
        """
        import copy
        self.separate_encoders = True
        if self.separate_encoders:
            self.encoders = []
            self.encoder_optimizers = []
            for i in range(self.n):
                self.encoders.append(copy.deepcopy(self.encoder).to(self.device))
                self.encoder_optimizers.append(optim.Adam(self.encoders[i].parameters(),lr=0.001))

        self.training_time_dp = self.training_time
        self.test_accs_dp = self.test_accs
        self.train(dp=dp, **kwargs)
        
        self.training_time += self.training_time_dp

# %%
m = MultipleDecoder(10, epsilon=1e6)
m.train(dp=True, epochs=3)
m.fine_tune(epochs=1)
test_accs = [x[-1] for x in m.test_accs]
training_times = m.training_time

print(f"Average training time", np.mean(training_times))
print(f"Average test accuracy", np.mean(test_accs))
print(f"Median test accuracy", np.median(test_accs))
print(f"Standard deviation test accuracy", np.std(test_accs))
# Out:
# data slice [19821, ..., 22599]
# data slice [20777, ..., 46303]
# data slice [4275, ..., 46837]
# data slice [2075, ..., 54875]
# data slice [20274, ..., 44860]
# data slice [21638, ..., 44344]
# data slice [45998, ..., 482]
# data slice [8153, ..., 48410]
# data slice [56503, ..., 50922]
# data slice [6358, ..., 26813]
# Start of Epoch 0
# Average Train Loss: [2.0524, 2.1395, 2.0987, 2.1257, 2.0831, 2.0851, 2.0488, 2.2103, 2.1478, 2.1269]
# Test Accuracy: [0.53, 0.385, 0.5175, 0.4675, 0.54625, 0.50375, 0.52875, 0.195, 0.41625, 0.3875]
# Start of Epoch 1
# Average Train Loss: [1.9913, 2.0939, 2.0195, 2.0763, 1.998, 2.0221, 1.9783, 2.1618, 2.0415, 2.0919]
# Test Accuracy: [0.5125, 0.49875, 0.54875, 0.49625, 0.5675, 0.57625, 0.59625, 0.35375, 0.55625, 0.48125]
# Start of Epoch 2
# Average Train Loss: [1.9587, 2.0343, 1.9868, 2.0568, 1.9561, 1.9982, 1.9265, 2.1138, 1.984, 2.0396]
# Test Accuracy: [0.555, 0.58125, 0.54125, 0.45125, 0.6, 0.55125, 0.6525, 0.37375, 0.62125, 0.58375]
# Finished Training
# Elapsed Test Time: 4.73488187789917
# Elapsed Training Time: 17.04473042488098
# Final Test Accuracy: [0.555, 0.5743, 0.5531, 0.4669, 0.5725, 0.5535, 0.6553, 0.3657, 0.611, 0.5751]
# Start of Epoch 0
# Average Train Loss: [1.8723, 1.871, 1.9077, 2.0092, 1.8055, 1.9268, 1.7995, 2.0057, 1.8333, 1.8552]
# Test Accuracy: [0.5425, 0.5875, 0.5625, 0.4475, 0.65375, 0.5575, 0.6525, 0.40375, 0.64125, 0.58125]
# Finished Training
# Elapsed Test Time: 1.5631294250488281
# Elapsed Training Time: 3.239583969116211
# Final Test Accuracy: [0.5588, 0.5719, 0.5562, 0.4805, 0.6607, 0.5652, 0.6545, 0.3759, 0.6007, 0.5847]
# Average training time 20.284314393997192
# Average test accuracy 0.56091
# Median test accuracy 0.56855
# Standard deviation test accuracy 0.07856629620899791

# %%
m = MultipleDecoder(10, epsilon=1e6)
m.train(dp=True, epochs=15)
m.fine_tune(epochs=5)
test_accs = [x[-1] for x in m.test_accs]
training_times = m.training_time

print(f"Average training time", np.mean(training_times))
print(f"Average test accuracy", np.mean(test_accs))
print(f"Median test accuracy", np.median(test_accs))
print(f"Standard deviation test accuracy", np.std(test_accs))
# Out:
# data slice [23223, ..., 17206]
# data slice [55630, ..., 25122]
# data slice [1601, ..., 34293]
# data slice [33619, ..., 58677]
# data slice [5187, ..., 27918]
# data slice [12793, ..., 29042]
# data slice [9856, ..., 47779]
# data slice [21065, ..., 8449]
# data slice [40734, ..., 41870]
# data slice [22216, ..., 2627]
# Start of Epoch 0
# Average Train Loss: [2.058, 2.0857, 2.0596, 2.0921, 2.16, 2.0385, 2.1345, 2.1231, 2.057, 2.1255]
# Test Accuracy: [0.5475, 0.5425, 0.61125, 0.485, 0.40625, 0.4575, 0.39, 0.345, 0.4875, 0.50625]
# Start of Epoch 1
# Average Train Loss: [1.9657, 2.004, 1.9185, 1.9982, 2.0823, 1.9843, 2.0652, 2.0625, 2.0216, 2.0148]
# Test Accuracy: [0.64625, 0.5575, 0.69625, 0.53625, 0.4475, 0.50625, 0.4825, 0.4525, 0.47125, 0.56]
# Start of Epoch 2
# Average Train Loss: [1.91, 1.9234, 1.8512, 1.9568, 2.0281, 1.9427, 2.0291, 2.0215, 2.0013, 1.9719]
# Test Accuracy: [0.68625, 0.66375, 0.74875, 0.56375, 0.5125, 0.58375, 0.5075, 0.45625, 0.52375, 0.55625]
# Start of Epoch 3
# Average Train Loss: [1.8677, 1.8694, 1.8121, 1.9309, 1.9874, 1.9097, 2.0052, 1.9968, 1.9793, 1.9406]
# Test Accuracy: [0.71625, 0.7325, 0.72375, 0.57375, 0.5775, 0.6475, 0.54375, 0.4675, 0.5625, 0.5825]
# Start of Epoch 4
# Average Train Loss: [1.8362, 1.8299, 1.7896, 1.9121, 1.9584, 1.8808, 1.9889, 1.9791, 1.9496, 1.9115]
# Test Accuracy: [0.7075, 0.77, 0.72125, 0.54875, 0.60125, 0.6775, 0.55625, 0.46125, 0.65125, 0.655]
# Start of Epoch 5
# Start of Epoch 0
# Average Train Loss: [1.6706, 1.6351, 1.6558, 1.8197, 1.7156, 1.6467, 1.8499, 1.8764, 1.5892, 1.6775]
# Test Accuracy: [0.76375, 0.76875, 0.77625, 0.5375, 0.64, 0.725, 0.60625, 0.4875, 0.835, 0.75625]
# Start of Epoch 1
# Average Train Loss: [1.6696, 1.6348, 1.6547, 1.8186, 1.7175, 1.6476, 1.8493, 1.8763, 1.5891, 1.6745]
# Test Accuracy: [0.7425, 0.7475, 0.78125, 0.55625, 0.64875, 0.74125, 0.5875, 0.46125, 0.81, 0.7425]
# Start of Epoch 2
# Average Train Loss: [1.6684, 1.6347, 1.6549, 1.8185, 1.7168, 1.6459, 1.8489, 1.8756, 1.5843, 1.6728]
# Test Accuracy: [0.74, 0.75125, 0.77375, 0.52875, 0.64125, 0.7675, 0.605, 0.47, 0.845, 0.70875]
# Start of Epoch 3
# Average Train Loss: [1.6678, 1.6346, 1.6548, 1.8176, 1.7158, 1.6446, 1.8482, 1.8751, 1.573, 1.672]
# Test Accuracy: [0.75, 0.75875, 0.7775, 0.535, 0.6225, 0.7775, 0.57375, 0.47375, 0.87125, 0.74875]
# Start of Epoch 4
# Average Train Loss: [1.6659, 1.6345, 1.6502, 1.817, 1.7152, 1.6434, 1.8476, 1.8767, 1.5597, 1.6709]
# Test Accuracy: [0.775, 0.75125, 0.83125, 0.57125, 0.63125, 0.75625, 0.5925, 0.48375, 0.91625, 0.755]
# Finished Training
# Elapsed Test Time: 7.854880332946777
# Elapsed Training Time: 16.322765588760376
# Final Test Accuracy: [0.7636, 0.761, 0.8006, 0.5726, 0.652, 0.7765, 0.5858, 0.4792, 0.9197, 0.7573]
# Average training time 101.66613435745239
# Average test accuracy 0.70683
# Median test accuracy 0.75915
# Standard deviation test accuracy 0.12456022679812363

# %%
def multiple_data_generators_unbalanced(n, dataset="mnist", folds=50, batch_sizes=16):
    if n != 10:
        raise NotImplementedError("n must currently be 10")
    if batch_sizes != 16:
        raise NotImplementedError("batch_sizes must currently be 16")
    if folds != 50:
        raise NotImplementedError("folds must currently be 50")
    if n > folds:
        raise ValueError(f"n {n} > {folds} folds")
    total = 60000
    if np.array(batch_sizes).ndim == 0:
        batch_sizes = [batch_sizes] * n
        
    main_total = 660 # primary class
    off_total = 60  # other classes
    
    batch_size = 16
    if dataset == "mnist":
        trainset = datasets.MNIST(root='./data', train=True, download=True, transform=torchvision.transforms.ToTensor())
    elif dataset == "fashionmnist":
        trainset = datasets.FashionMNIST(root='./data', train=True, download=True, transform=torchvision.transforms.ToTensor())
    else:
        raise ValueError(f"dataset {dataset}")
    dataloader = DataLoader(trainset, batch_size=16, shuffle=False, drop_last=True)
    ys = []
    for x, y in dataloader:
        ys.append(y)
    y = np.hstack(ys)

    classes = []
    n = 10  # number of classes
    for i in range(n):
        classes.append(np.where(y == i)[0])
        np.random.shuffle(classes[i])

    indexes = [[] for x in range(n)]
    for i in range(n):  # for each class
        c = classes[i]
        start = 0
        for j in range(n):  # for each organization
            index = indexes[j]
            if i == j:  # main total
                index.extend(c[start:start+main_total])
                start += main_total
            else:  # off total
                index.extend(c[start:start+off_total])
                start += off_total

    for i in range(n):
        print(np.bincount(y[indexes[i]]))

    train_data_loaders = []
    test_data_loaders = []
    for i in range(n):
        batch_size = batch_sizes[i]
        if dataset == "mnist":
            mnist_trainset = datasets.MNIST(root='./data', train=True, download=True, transform=torchvision.transforms.ToTensor())
            mnist_testset = datasets.MNIST(root='./data', train=False, download=True, transform=torchvision.transforms.ToTensor())
        elif dataset == "fashionmnist":
            mnist_trainset = datasets.FashionMNIST(root='./data', train=True, download=True, transform=torchvision.transforms.ToTensor())
            mnist_testset = datasets.FashionMNIST(root='./data', train=False, download=True, transform=torchvision.transforms.ToTensor())
        else:
            raise ValueError(f"dataset {dataset}")
            
        mnist_trainset = Subset(mnist_trainset, indexes[i])
        #print(i * fold_size, (i+1) * fold_size)
        print(len(mnist_trainset))
        print(len(mnist_testset))
        max_trainsteps = len(mnist_trainset) // batch_size
        max_teststeps = len(mnist_testset) // batch_size
        #print(max_trainsteps)
        #print(max_teststeps)

        train_loader = DataLoader(mnist_trainset, batch_size=batch_size, shuffle=True, drop_last=True)
        test_loader = DataLoader(mnist_testset, batch_size=batch_size, shuffle=True, drop_last=True)

        inf_train = inf_loader_generator(train_loader)
        inf_test = inf_loader_generator(test_loader)

        iters_per_epoch_train = len(mnist_trainset) // batch_size
        iters_per_epoch_test = len(mnist_testset) // batch_size
        
        train_data_loaders.append(inf_train)
        test_data_loaders.append(inf_test)
    
    return train_data_loaders, test_data_loaders

# %%
test_accs = []
training_times = []
for i in range(2):
    m = MultipleDecoder(10, separate_encoders=True)
    m.train(dp=False, epochs=20)
    test_accs.extend([x[-1] for x in m.test_accs])
    training_times.append(m.training_time)
    
print(f"Average training time", np.mean(training_times))
print(f"Average test accuracy", np.mean(test_accs))
print(f"Median test accuracy", np.median(test_accs))
print(f"Standard deviation test accuracy", np.std(test_accs))
# Out:
# data slice [2445, ..., 52099]
# data slice [45448, ..., 13145]
# data slice [57776, ..., 31567]
# data slice [55419, ..., 10951]
# data slice [511, ..., 23039]
# data slice [8511, ..., 39363]
# data slice [17716, ..., 47010]
# data slice [19691, ..., 51794]
# data slice [12542, ..., 17397]
# data slice [41737, ..., 36102]
# Start of Epoch 0
# Average Train Loss: [2.1212, 2.1458, 2.0703, 2.1274, 2.1555, 2.0967, 2.0824, 2.0741, 2.1347, 2.1517]
# Test Accuracy: [0.58625, 0.40375, 0.5225, 0.46125, 0.3625, 0.43375, 0.5475, 0.48875, 0.37, 0.445]
# Start of Epoch 1
# Average Train Loss: [2.0071, 2.0844, 1.9851, 2.0296, 2.0947, 1.9997, 2.0054, 2.0087, 2.0125, 2.0344]
# Test Accuracy: [0.605, 0.36875, 0.59, 0.52375, 0.39625, 0.48875, 0.575, 0.47, 0.61, 0.55375]
# Start of Epoch 2
# Average Train Loss: [1.9563, 2.0611, 1.95, 1.9893, 2.0453, 1.9592, 1.9561, 1.9701, 1.9324, 1.9794]
# Test Accuracy: [0.61, 0.4325, 0.56375, 0.54375, 0.4875, 0.54125, 0.64, 0.5625, 0.6825, 0.6225]
# Start of Epoch 3
# Average Train Loss: [1.9229, 2.0412, 1.9287, 1.9602, 2.0136, 1.9291, 1.916, 1.9444, 1.8885, 1.9374]
# Average Train Loss: [1.7508, 1.9397, 1.8098, 1.8652, 1.9243, 1.8505, 1.7318, 1.8432, 1.7366, 1.7273]
# Test Accuracy: [0.8125, 0.57875, 0.68875, 0.5475, 0.46375, 0.5425, 0.7625, 0.65625, 0.74625, 0.82375]
# Start of Epoch 15
# Average Train Loss: [1.7416, 1.9349, 1.8062, 1.8625, 1.9216, 1.848, 1.7262, 1.8354, 1.7319, 1.7185]
# Test Accuracy: [0.8075, 0.59125, 0.66875, 0.55375, 0.48375, 0.555, 0.77375, 0.65, 0.7425, 0.8475]
# Start of Epoch 16
# Average Train Loss: [1.7333, 1.9304, 1.8028, 1.8599, 1.9197, 1.8457, 1.7212, 1.8283, 1.7275, 1.7104]
# Test Accuracy: [0.82125, 0.56375, 0.65625, 0.53875, 0.4625, 0.57375, 0.78, 0.67875, 0.74, 0.84125]
# Start of Epoch 17
# Average Train Loss: [1.725, 1.9235, 1.7998, 1.8575, 1.9177, 1.8436, 1.7166, 1.8219, 1.7236, 1.7029]
# Test Accuracy: [0.82, 0.6625, 0.695, 0.54125, 0.44625, 0.565, 0.7825, 0.675, 0.74625, 0.8275]
# Start of Epoch 18
# Average Train Loss: [1.7177, 1.9159, 1.7971, 1.8557, 1.916, 1.8418, 1.7125, 1.8161, 1.72, 1.6962]
# Test Accuracy: [0.8225, 0.6525, 0.68625, 0.5675, 0.48625, 0.5325, 0.7775, 0.6775, 0.7425, 0.8475]
# Start of Epoch 19
# Average Train Loss: [1.7105, 1.9089, 1.7946, 1.8538, 1.9142, 1.8401, 1.7088, 1.8107, 1.7166, 1.6898]
# Test Accuracy: [0.79, 0.66125, 0.7025, 0.57125, 0.46375, 0.56, 0.76125, 0.6875, 0.7475, 0.85875]
# Finished Training
# Elapsed Test Time: 31.30238628387451
# Elapsed Training Time: 65.21570181846619
# Final Test Accuracy: [0.8092, 0.6721, 0.6873, 0.5658, 0.4706, 0.5519, 0.7614, 0.6728, 0.7715, 0.8442]
# data slice [40955, ..., 43995]
# data slice [12659, ..., 39095]
# data slice [44809, ..., 24007]
# data slice [10961, ..., 42376]
# data slice [7083, ..., 58966]
# data slice [38104, ..., 5364]
# data slice [5590, ..., 52299]
# data slice [43249, ..., 31870]
# data slice [37775, ..., 8076]
# data slice [15146, ..., 35845]
# Start of Epoch 0
# Average Train Loss: [2.0837, 2.0616, 2.1665, 2.1301, 2.2289, 2.1004, 2.1064, 2.1053, 2.0381, 2.107]
# Test Accuracy: [0.6, 0.505, 0.34625, 0.475, 0.35875, 0.49125, 0.42625, 0.52125, 0.52875, 0.58125]
# Start of Epoch 1
# Average Train Loss: [1.9581, 1.9807, 2.0811, 2.0291, 2.1614, 2.0429, 2.0406, 1.9771, 1.9719, 1.9701]
# Test Accuracy: [0.63375, 0.5875, 0.48875, 0.53, 0.3725, 0.4825, 0.49, 0.67125, 0.60125, 0.7175]
# Start of Epoch 2
# Average Train Loss: [1.906, 1.9316, 2.0438, 1.9864, 2.1336, 2.0209, 2.014, 1.9113, 1.9228, 1.9015]
# Average Train Loss: [1.7519, 1.7397, 1.8621, 1.8077, 2.064, 1.8486, 1.7883, 1.7316, 1.7004, 1.7338]
# Test Accuracy: [0.7475, 0.84375, 0.75875, 0.7475, 0.39125, 0.74625, 0.8075, 0.8125, 0.86125, 0.76]
# Start of Epoch 14
# Average Train Loss: [1.747, 1.7295, 1.85, 1.7981, 2.0627, 1.8347, 1.7754, 1.7231, 1.6923, 1.7291]
# Test Accuracy: [0.78375, 0.835, 0.76, 0.76, 0.4075, 0.84375, 0.83125, 0.82125, 0.86375, 0.7525]
# Start of Epoch 15
# Average Train Loss: [1.7426, 1.7204, 1.8392, 1.7893, 2.0612, 1.819, 1.7641, 1.7151, 1.6852, 1.725]
# Test Accuracy: [0.77125, 0.81875, 0.74375, 0.77125, 0.37875, 0.83625, 0.8475, 0.8025, 0.86875, 0.77625]
# Start of Epoch 16
# Average Train Loss: [1.7386, 1.7122, 1.8297, 1.7818, 2.06, 1.8047, 1.7535, 1.7077, 1.6789, 1.7214]
# Test Accuracy: [0.79, 0.85875, 0.755, 0.72625, 0.3975, 0.8475, 0.855, 0.8425, 0.85, 0.75625]
# Start of Epoch 17
# Average Train Loss: [1.7351, 1.7048, 1.8211, 1.775, 2.0587, 1.7918, 1.7436, 1.7011, 1.6733, 1.7182]
# Test Accuracy: [0.76625, 0.8225, 0.74125, 0.75875, 0.3875, 0.84, 0.865, 0.82875, 0.815, 0.73875]
# Start of Epoch 18
# Average Train Loss: [1.7319, 1.6981, 1.8134, 1.7689, 2.0576, 1.7798, 1.7347, 1.695, 1.6683, 1.7151]
# Test Accuracy: [0.77375, 0.85375, 0.79125, 0.75, 0.40625, 0.84375, 0.85625, 0.8375, 0.86, 0.74125]
# Start of Epoch 19
# Average Train Loss: [1.729, 1.6921, 1.8065, 1.7633, 2.0566, 1.7689, 1.7266, 1.6895, 1.6638, 1.7123]
# Test Accuracy: [0.77625, 0.835, 0.7625, 0.77625, 0.34875, 0.86375, 0.8625, 0.8425, 0.8575, 0.8075]
# Finished Training
# Elapsed Test Time: 31.620145559310913
# Elapsed Training Time: 66.07067847251892
# Final Test Accuracy: [0.7642, 0.8344, 0.7478, 0.7611, 0.391, 0.8468, 0.8526, 0.8332, 0.8553, 0.7884]
# Average training time 65.64319014549255
# Average test accuracy 0.7240800000000001
# Median test accuracy 0.7627999999999999
# Standard deviation test accuracy 0.13085233127460894

# %%
test_accs_dp2 = []
training_times_dp2 = []
for i in range(10):
    m = MultipleDecoder(2, separate_encoders=False)
    m.train(dp=True, epochs=10)
    m.fine_tune(epochs=10)
    test_accs_dp2.extend([x[-1] for x in m.test_accs])
    training_times_dp2.append(m.training_time)

print(f"Average training time", np.mean(training_times_dp2))
print(f"Average test accuracy", np.mean(test_accs_dp2))
print(f"Median test accuracy", np.median(test_accs_dp2))
print(f"Standard deviation test accuracy", np.std(test_accs_dp2))
# Out:
# data slice [39645, ..., 3401]
# data slice [50470, ..., 8563]
# Start of Epoch 0
# Average Train Loss: [2.0409, 2.0566]
# Test Accuracy: [0.5225, 0.645]
# Start of Epoch 1
# Average Train Loss: [1.9675, 1.9201]
# Test Accuracy: [0.5625, 0.71375]
# Start of Epoch 2
# Average Train Loss: [1.9364, 1.8672]
# Test Accuracy: [0.60625, 0.7025]
# Start of Epoch 3
# Average Train Loss: [1.9178, 1.831]
# Test Accuracy: [0.55125, 0.7175]
# Start of Epoch 4
# Average Train Loss: [1.9004, 1.8053]
# Test Accuracy: [0.675, 0.71625]
# Start of Epoch 5
# Average Train Loss: [1.8781, 1.786]
# Test Accuracy: [0.7, 0.74625]
# Start of Epoch 6
# Average Train Loss: [1.8523, 1.7712]
# Test Accuracy: [0.74625, 0.74875]
# Start of Epoch 7
# Average Train Loss: [1.8307, 1.7591]
# Test Accuracy: [0.76, 0.7625]
# Start of Epoch 8
# Average Train Loss: [1.8128, 1.7499]
# Test Accuracy: [0.75625, 0.7625]
# Start of Epoch 9
# Average Train Loss: [1.7984, 1.7418]
# Test Accuracy: [0.7675, 0.76625]
# Finished Training
# Elapsed Test Time: 3.144005537033081
# Elapsed Training Time: 11.38125991821289
# Final Test Accuracy: [0.7679, 0.7583]
# Start of Epoch 0
# Average Train Loss: [1.6662, 1.6664]
# Test Accuracy: [0.76375, 0.7775]
# Start of Epoch 1
# Average Train Loss: [1.6671, 1.6651]
# Test Accuracy: [0.76125, 0.77375]
# Start of Epoch 2
# Average Train Loss: [1.6651, 1.6639]
# Test Accuracy: [0.7675, 0.7825]
# Start of Epoch 3
# Average Train Loss: [1.6629, 1.6627]
# Test Accuracy: [0.78375, 0.76375]
# Start of Epoch 4
# Average Train Loss: [1.6508, 1.6618]
# Test Accuracy: [0.8525, 0.74875]
# Start of Epoch 5
# Average Train Loss: [1.6396, 1.661]
# Test Accuracy: [0.8425, 0.76875]
# Start of Epoch 6
# Average Train Loss: [1.6303, 1.6605]
# Test Accuracy: [0.8625, 0.75625]
# Start of Epoch 7
# Average Train Loss: [1.6226, 1.6599]
# Test Accuracy: [0.85625, 0.77625]
# Start of Epoch 8
# Average Train Loss: [1.6163, 1.6595]
# Test Accuracy: [0.8625, 0.775]
# Start of Epoch 9
# Average Train Loss: [1.6111, 1.6592]
# Test Accuracy: [0.845, 0.75]
# Finished Training
# Elapsed Test Time: 3.1494553089141846
# Elapsed Training Time: 6.541797637939453
# Final Test Accuracy: [0.8582, 0.776]
# data slice [31292, ..., 47496]
# data slice [54037, ..., 43567]
# Start of Epoch 0
# Average Train Loss: [2.0918, 2.065]
# Test Accuracy: [0.47875, 0.52375]
# Start of Epoch 1
# Average Train Loss: [2.0267, 1.9641]
# Test Accuracy: [0.5425, 0.6125]
# Start of Epoch 2
# Average Train Loss: [1.9571, 1.906]
# Test Accuracy: [0.6825, 0.6775]
# Start of Epoch 3
# Average Train Loss: [1.8994, 1.8639]
# Test Accuracy: [0.7275, 0.7325]
# Start of Epoch 4
# Average Train Loss: [1.8604, 1.8319]
# Test Accuracy: [0.7525, 0.75125]
# Start of Epoch 5
# Average Train Loss: [1.8312, 1.8085]
# Test Accuracy: [0.76, 0.72375]
# Start of Epoch 6
# Average Train Loss: [1.8107, 1.7898]
# Test Accuracy: [0.7425, 0.7475]
# Start of Epoch 7
# Average Train Loss: [1.7937, 1.7722]
# Test Accuracy: [0.73875, 0.80375]
# Start of Epoch 8
# Average Train Loss: [1.7803, 1.7552]
# Test Accuracy: [0.72625, 0.82875]
# Start of Epoch 9
# Average Train Loss: [1.769, 1.7407]
# Test Accuracy: [0.7175, 0.82875]
# Finished Training
# Elapsed Test Time: 3.4361696243286133
# Elapsed Training Time: 12.637036085128784
# Final Test Accuracy: [0.7483, 0.8161]
# Start of Epoch 0
# Average Train Loss: [1.6675, 1.5959]
# Test Accuracy: [0.75, 0.82375]
# Start of Epoch 1
# Average Train Loss: [1.6621, 1.5946]
# Test Accuracy: [0.74, 0.8375]
# Start of Epoch 2
# Average Train Loss: [1.662, 1.5941]
# Test Accuracy: [0.76375, 0.8375]
# Start of Epoch 3
# Average Train Loss: [1.6621, 1.593]
# Test Accuracy: [0.71625, 0.8225]
# Start of Epoch 4
# Average Train Loss: [1.6599, 1.5919]
# Test Accuracy: [0.75625, 0.84625]
# Start of Epoch 5
# Average Train Loss: [1.658, 1.5908]
# Test Accuracy: [0.7575, 0.81375]
# Start of Epoch 6
# Average Train Loss: [1.6564, 1.5894]
# Test Accuracy: [0.73375, 0.84875]
# Start of Epoch 7
# Average Train Loss: [1.6556, 1.588]
# Test Accuracy: [0.76125, 0.82875]
# Start of Epoch 8
# Average Train Loss: [1.655, 1.587]
# Test Accuracy: [0.7375, 0.8375]
# Start of Epoch 9
# Average Train Loss: [1.6546, 1.5861]
# Test Accuracy: [0.76, 0.82]
# Finished Training
# Elapsed Test Time: 3.197640895843506
# Elapsed Training Time: 6.618644714355469
# Final Test Accuracy: [0.7466, 0.8249]
# data slice [39819, ..., 39603]
# data slice [190, ..., 51305]
# Start of Epoch 0
# Average Train Loss: [2.086, 2.0989]
# Test Accuracy: [0.53375, 0.5175]
# Start of Epoch 1
# Average Train Loss: [1.9778, 1.991]
# Test Accuracy: [0.52125, 0.61625]
# Start of Epoch 2
# Average Train Loss: [1.9302, 1.9376]
# Test Accuracy: [0.62125, 0.60375]
# Start of Epoch 3
# Average Train Loss: [1.9063, 1.9052]
# Test Accuracy: [0.60625, 0.62625]
# Start of Epoch 4
# Average Train Loss: [1.8888, 1.8854]
# Test Accuracy: [0.61875, 0.64]
# Start of Epoch 5
# Average Train Loss: [1.8773, 1.8714]
# Test Accuracy: [0.62875, 0.64375]
# Start of Epoch 6
# Average Train Loss: [1.8672, 1.8592]
# Test Accuracy: [0.64, 0.685]
# Start of Epoch 7
# Average Train Loss: [1.858, 1.8497]
# Test Accuracy: [0.62625, 0.6425]
# Start of Epoch 8
# Average Train Loss: [1.8526, 1.8423]
# Test Accuracy: [0.6525, 0.6675]
# Start of Epoch 9
# Average Train Loss: [1.8464, 1.8355]
# Test Accuracy: [0.65375, 0.62625]
# Finished Training
# Elapsed Test Time: 3.1597847938537598
# Elapsed Training Time: 11.37578821182251
# Final Test Accuracy: [0.6534, 0.6341]
# Start of Epoch 0
# Average Train Loss: [1.782, 1.7673]
# Test Accuracy: [0.6475, 0.6725]
# Start of Epoch 1
# Average Train Loss: [1.7771, 1.7601]
# Test Accuracy: [0.6975, 0.665]
# Start of Epoch 2
# Average Train Loss: [1.776, 1.7531]
# Test Accuracy: [0.6925, 0.66]
# Start of Epoch 3
# Average Train Loss: [1.778, 1.7484]
# Test Accuracy: [0.6575, 0.6775]
# Start of Epoch 4
# Average Train Loss: [1.7787, 1.7451]
# Test Accuracy: [0.69, 0.655]
# Start of Epoch 5
# Average Train Loss: [1.7789, 1.7426]
# Test Accuracy: [0.655, 0.675]
# Start of Epoch 6
# Average Train Loss: [1.7782, 1.7402]
# Test Accuracy: [0.6525, 0.635]
# Start of Epoch 7
# Average Train Loss: [1.7779, 1.7381]
# Test Accuracy: [0.61875, 0.66]
# Start of Epoch 8
# Average Train Loss: [1.777, 1.7365]
# Test Accuracy: [0.62375, 0.675]
# Start of Epoch 9
# Average Train Loss: [1.7766, 1.7348]
# Test Accuracy: [0.66875, 0.655]
# Finished Training
# Elapsed Test Time: 3.1501288414001465
# Elapsed Training Time: 6.539595365524292
# Final Test Accuracy: [0.656, 0.6658]
# data slice [22053, ..., 33235]
# data slice [49813, ..., 27921]
# Start of Epoch 0
# Average Train Loss: [2.0951, 2.0395]
# Test Accuracy: [0.4775, 0.49125]
# Start of Epoch 1
# Average Train Loss: [2.0335, 1.9734]
# Test Accuracy: [0.49, 0.63125]
# Start of Epoch 2
# Average Train Loss: [1.9999, 1.9204]
# Test Accuracy: [0.53375, 0.63375]
# Start of Epoch 3
# Average Train Loss: [1.9729, 1.8883]
# Test Accuracy: [0.575, 0.64375]
# Start of Epoch 4
# Average Train Loss: [1.9525, 1.8598]
# Test Accuracy: [0.58625, 0.76125]
# Start of Epoch 5
# Average Train Loss: [1.9364, 1.831]
# Test Accuracy: [0.6425, 0.75625]
# Start of Epoch 6
# Average Train Loss: [1.9131, 1.8087]
# Test Accuracy: [0.68375, 0.78125]
# Start of Epoch 7
# Average Train Loss: [1.894, 1.7847]
# Test Accuracy: [0.6725, 0.80125]
# Start of Epoch 8
# Average Train Loss: [1.8786, 1.7646]
# Test Accuracy: [0.665, 0.84875]
# Start of Epoch 9
# Average Train Loss: [1.8649, 1.7469]
# Test Accuracy: [0.72, 0.8175]
# Finished Training
# Elapsed Test Time: 3.1524484157562256
# Elapsed Training Time: 11.379425525665283
# Final Test Accuracy: [0.7077, 0.8356]
# Start of Epoch 0
# Average Train Loss: [1.6899, 1.5801]
# Test Accuracy: [0.74375, 0.83375]
# Start of Epoch 1
# Average Train Loss: [1.6835, 1.5812]
# Test Accuracy: [0.74125, 0.85375]
# Start of Epoch 2
# Average Train Loss: [1.6778, 1.5798]
# Test Accuracy: [0.8175, 0.835]
# Start of Epoch 3
# Average Train Loss: [1.6725, 1.5777]
# Test Accuracy: [0.785, 0.83875]
# Start of Epoch 4
# Average Train Loss: [1.6648, 1.5762]
# Test Accuracy: [0.80125, 0.8425]
# Start of Epoch 5
# Average Train Loss: [1.6578, 1.5751]
# Test Accuracy: [0.81875, 0.85]
# Start of Epoch 6
# Average Train Loss: [1.6486, 1.5743]
# Test Accuracy: [0.89375, 0.8525]
# Start of Epoch 7
# Average Train Loss: [1.6375, 1.5737]
# Test Accuracy: [0.89125, 0.8625]
# Start of Epoch 8
# Average Train Loss: [1.6247, 1.5732]
# Test Accuracy: [0.91125, 0.845]
# Start of Epoch 9
# Average Train Loss: [1.6128, 1.5728]
# Test Accuracy: [0.9325, 0.8725]
# Finished Training
# Elapsed Test Time: 3.1725716590881348
# Elapsed Training Time: 6.535766363143921
# Final Test Accuracy: [0.9211, 0.855]
# data slice [58522, ..., 13598]
# data slice [42105, ..., 20343]
# Start of Epoch 0
# Average Train Loss: [2.0858, 2.1234]
# Test Accuracy: [0.48, 0.38625]
# Start of Epoch 1
# Average Train Loss: [1.9979, 2.0665]
# Test Accuracy: [0.58625, 0.3525]
# Start of Epoch 2
# Average Train Loss: [1.9492, 2.0423]
# Test Accuracy: [0.59125, 0.3525]
# Start of Epoch 3
# Average Train Loss: [1.9126, 2.0305]
# Test Accuracy: [0.65875, 0.405]
# Start of Epoch 4
# Average Train Loss: [1.8849, 2.021]
# Test Accuracy: [0.65125, 0.37375]
# Start of Epoch 5
# Average Train Loss: [1.8586, 2.0138]
# Test Accuracy: [0.7125, 0.3675]
# Start of Epoch 6
# Average Train Loss: [1.8338, 2.0074]
# Test Accuracy: [0.7275, 0.41]
# Start of Epoch 7
# Average Train Loss: [1.8127, 2.0029]
# Test Accuracy: [0.7675, 0.3775]
# Start of Epoch 8
# Average Train Loss: [1.7958, 1.9997]
# Test Accuracy: [0.74375, 0.3825]
# Start of Epoch 9
# Average Train Loss: [1.7805, 1.9963]
# Test Accuracy: [0.825, 0.3625]
# Finished Training
# Elapsed Test Time: 3.148535966873169
# Elapsed Training Time: 11.37108039855957
# Final Test Accuracy: [0.8181, 0.3847]
# Start of Epoch 0
# Average Train Loss: [1.5976, 1.965]
# Test Accuracy: [0.82625, 0.3675]
# Start of Epoch 1
# Average Train Loss: [1.5941, 1.9636]
# Test Accuracy: [0.81, 0.38625]
# Start of Epoch 2
# Average Train Loss: [1.5918, 1.9636]
# Test Accuracy: [0.8525, 0.3725]
# Start of Epoch 3
# Average Train Loss: [1.5873, 1.9631]
# Test Accuracy: [0.8525, 0.365]
# Start of Epoch 4
# Average Train Loss: [1.5836, 1.9623]
# Test Accuracy: [0.845, 0.38]
# Start of Epoch 5
# Average Train Loss: [1.581, 1.9621]
# Test Accuracy: [0.86125, 0.37]
# Start of Epoch 6
# Average Train Loss: [1.579, 1.9615]
# Test Accuracy: [0.8425, 0.37375]
# Start of Epoch 7
# Average Train Loss: [1.5778, 1.9609]
# Test Accuracy: [0.855, 0.38625]
# Start of Epoch 8
# Average Train Loss: [1.5767, 1.9605]
# Test Accuracy: [0.855, 0.40125]
# Start of Epoch 9
# Average Train Loss: [1.5761, 1.9601]
# Test Accuracy: [0.85625, 0.37875]
# Finished Training
# Elapsed Test Time: 3.1585590839385986
# Elapsed Training Time: 6.550686836242676
# Final Test Accuracy: [0.8452, 0.3897]
# data slice [49121, ..., 14056]
# data slice [30527, ..., 52294]
# Start of Epoch 0
# Average Train Loss: [2.0598, 2.0852]
# Test Accuracy: [0.48375, 0.6025]
# Start of Epoch 1
# Average Train Loss: [2.0018, 1.9282]
# Test Accuracy: [0.54625, 0.69625]
# Start of Epoch 2
# Average Train Loss: [1.9717, 1.8543]
# Test Accuracy: [0.5625, 0.7575]
# Start of Epoch 3
# Average Train Loss: [1.9437, 1.8066]
# Test Accuracy: [0.65625, 0.825]
# Start of Epoch 4
# Average Train Loss: [1.9165, 1.7703]
# Test Accuracy: [0.65625, 0.805]
# Start of Epoch 5
# Average Train Loss: [1.8947, 1.7453]
# Test Accuracy: [0.65375, 0.805]
# Start of Epoch 6
# Average Train Loss: [1.8745, 1.7251]
# Test Accuracy: [0.74, 0.82375]
# Start of Epoch 7
# Average Train Loss: [1.8509, 1.7085]
# Test Accuracy: [0.7325, 0.81875]
# Start of Epoch 8
# Average Train Loss: [1.8313, 1.6955]
# Test Accuracy: [0.75875, 0.8425]
# Start of Epoch 9
# Average Train Loss: [1.8109, 1.6837]
# Test Accuracy: [0.825, 0.86375]
# Finished Training
# Elapsed Test Time: 3.1758341789245605
# Elapsed Training Time: 11.381731986999512
# Final Test Accuracy: [0.8074, 0.8436]
# Start of Epoch 0
# Average Train Loss: [1.6065, 1.5756]
# Test Accuracy: [0.84125, 0.8225]
# Start of Epoch 1
# Average Train Loss: [1.5977, 1.5785]
# Test Accuracy: [0.8625, 0.83]
# Start of Epoch 2
# Average Train Loss: [1.5919, 1.5752]
# Test Accuracy: [0.835, 0.85875]
# Start of Epoch 3
# Average Train Loss: [1.5886, 1.5727]
# Test Accuracy: [0.8375, 0.83]
# Start of Epoch 4
# Average Train Loss: [1.5854, 1.5727]
# Test Accuracy: [0.84, 0.825]
# Start of Epoch 5
# Average Train Loss: [1.5826, 1.5719]
# Test Accuracy: [0.835, 0.84625]
# Start of Epoch 6
# Average Train Loss: [1.5805, 1.5711]
# Test Accuracy: [0.86, 0.84375]
# Start of Epoch 7
# Average Train Loss: [1.5788, 1.5703]
# Test Accuracy: [0.80875, 0.84375]
# Start of Epoch 8
# Average Train Loss: [1.5773, 1.57]
# Test Accuracy: [0.84375, 0.84]
# Start of Epoch 9
# Average Train Loss: [1.576, 1.5692]
# Test Accuracy: [0.85625, 0.8525]
# Finished Training
# Elapsed Test Time: 3.1607558727264404
# Elapsed Training Time: 6.556736469268799
# Final Test Accuracy: [0.8468, 0.8466]
# data slice [11736, ..., 44750]
# data slice [34858, ..., 24985]
# Start of Epoch 0
# Average Train Loss: [2.1606, 2.1186]
# Test Accuracy: [0.3675, 0.38875]
# Start of Epoch 1
# Average Train Loss: [2.0844, 2.0635]
# Test Accuracy: [0.46375, 0.485]
# Start of Epoch 2
# Average Train Loss: [2.0452, 2.0113]
# Test Accuracy: [0.4325, 0.5625]
# Start of Epoch 3
# Average Train Loss: [2.0232, 1.9778]
# Test Accuracy: [0.48625, 0.59375]
# Start of Epoch 4
# Average Train Loss: [2.0095, 1.9526]
# Test Accuracy: [0.48, 0.61375]
# Start of Epoch 5
# Average Train Loss: [1.9991, 1.9308]
# Test Accuracy: [0.495, 0.6375]
# Start of Epoch 6
# Average Train Loss: [1.9906, 1.9099]
# Test Accuracy: [0.50375, 0.75125]
# Start of Epoch 7
# Average Train Loss: [1.9848, 1.8866]
# Test Accuracy: [0.45875, 0.73375]
# Start of Epoch 8
# Average Train Loss: [1.9793, 1.8658]
# Test Accuracy: [0.485, 0.7325]
# Start of Epoch 9
# Average Train Loss: [1.9682, 1.8482]
# Test Accuracy: [0.59375, 0.71625]
# Finished Training
# Elapsed Test Time: 3.1643447875976562
# Elapsed Training Time: 11.39609670639038
# Final Test Accuracy: [0.5735, 0.7285]
# Start of Epoch 0
# Average Train Loss: [1.8483, 1.6895]
# Test Accuracy: [0.6075, 0.75375]
# Start of Epoch 1
# Average Train Loss: [1.8427, 1.6901]
# Test Accuracy: [0.61125, 0.75875]
# Start of Epoch 2
# Average Train Loss: [1.8182, 1.6885]
# Test Accuracy: [0.725, 0.755]
# Start of Epoch 3
# Average Train Loss: [1.7888, 1.6862]
# Test Accuracy: [0.73, 0.75125]
# Start of Epoch 4
# Average Train Loss: [1.7671, 1.6847]
# Test Accuracy: [0.7675, 0.75375]
# Start of Epoch 5
# Average Train Loss: [1.7518, 1.6834]
# Test Accuracy: [0.76375, 0.755]
# Start of Epoch 6
# Average Train Loss: [1.7403, 1.6821]
# Test Accuracy: [0.71625, 0.7625]
# Start of Epoch 7
# Average Train Loss: [1.7315, 1.6809]
# Test Accuracy: [0.73, 0.76]
# Start of Epoch 8
# Average Train Loss: [1.7246, 1.6804]
# Test Accuracy: [0.755, 0.7575]
# Start of Epoch 9
# Average Train Loss: [1.7183, 1.6772]
# Test Accuracy: [0.77875, 0.77375]
# Finished Training
# Elapsed Test Time: 3.150391101837158
# Elapsed Training Time: 6.553884744644165
# Final Test Accuracy: [0.7465, 0.7841]
# data slice [58209, ..., 43865]
# data slice [42165, ..., 32480]
# Start of Epoch 0
# Average Train Loss: [2.0919, 2.0713]
# Test Accuracy: [0.61875, 0.5]
# Start of Epoch 1
# Average Train Loss: [1.9712, 1.9984]
# Test Accuracy: [0.61125, 0.5575]
# Start of Epoch 2
# Average Train Loss: [1.9257, 1.9582]
# Test Accuracy: [0.60875, 0.64875]
# Start of Epoch 3
# Average Train Loss: [1.8979, 1.9235]
# Test Accuracy: [0.625, 0.675]
# Start of Epoch 4
# Average Train Loss: [1.879, 1.8987]
# Test Accuracy: [0.64, 0.685]
# Start of Epoch 5
# Average Train Loss: [1.8641, 1.8706]
# Test Accuracy: [0.62125, 0.725]
# Start of Epoch 6
# Average Train Loss: [1.8525, 1.8445]
# Test Accuracy: [0.62125, 0.74375]
# Start of Epoch 7
# Average Train Loss: [1.844, 1.8231]
# Test Accuracy: [0.64875, 0.78125]
# Start of Epoch 8
# Average Train Loss: [1.8364, 1.806]
# Test Accuracy: [0.66125, 0.75]
# Start of Epoch 9
# Average Train Loss: [1.8301, 1.792]
# Test Accuracy: [0.6825, 0.7525]
# Finished Training
# Elapsed Test Time: 3.1573984622955322
# Elapsed Training Time: 11.390866756439209
# Final Test Accuracy: [0.6764, 0.7637]
# Start of Epoch 0
# Average Train Loss: [1.7604, 1.6604]
# Test Accuracy: [0.7025, 0.74125]
# Start of Epoch 1
# Average Train Loss: [1.7406, 1.6587]
# Test Accuracy: [0.7, 0.76375]
# Start of Epoch 2
# Average Train Loss: [1.7346, 1.6581]
# Test Accuracy: [0.75375, 0.75875]
# Start of Epoch 3
# Average Train Loss: [1.7279, 1.656]
# Test Accuracy: [0.75875, 0.76625]
# Start of Epoch 4
# Average Train Loss: [1.72, 1.6542]
# Test Accuracy: [0.755, 0.755]
# Start of Epoch 5
# Average Train Loss: [1.714, 1.6529]
# Test Accuracy: [0.7525, 0.75375]
# Start of Epoch 6
# Average Train Loss: [1.7096, 1.6525]
# Test Accuracy: [0.715, 0.78875]
# Start of Epoch 7
# Average Train Loss: [1.7054, 1.6517]
# Test Accuracy: [0.74, 0.77625]
# Start of Epoch 8
# Average Train Loss: [1.7018, 1.6511]
# Test Accuracy: [0.755, 0.7825]
# Start of Epoch 9
# Average Train Loss: [1.6986, 1.6504]
# Test Accuracy: [0.7575, 0.7725]
# Finished Training
# Elapsed Test Time: 3.1635987758636475
# Elapsed Training Time: 6.579761028289795
# Final Test Accuracy: [0.7518, 0.78]
# data slice [17344, ..., 4411]
# data slice [37721, ..., 2895]
# Start of Epoch 0
# Average Train Loss: [2.2016, 2.1978]
# Test Accuracy: [0.3425, 0.34]
# Start of Epoch 1
# Average Train Loss: [2.0897, 2.1239]
# Test Accuracy: [0.56, 0.4425]
# Start of Epoch 2
# Average Train Loss: [2.014, 2.0642]
# Test Accuracy: [0.60125, 0.5025]
# Start of Epoch 3
# Average Train Loss: [1.9596, 2.0219]
# Test Accuracy: [0.6475, 0.57875]
# Start of Epoch 4
# Average Train Loss: [1.9214, 1.9876]
# Test Accuracy: [0.66375, 0.5725]
# Start of Epoch 5
# Average Train Loss: [1.894, 1.9556]
# Test Accuracy: [0.6425, 0.72]
# Start of Epoch 6
# Average Train Loss: [1.8721, 1.9261]
# Test Accuracy: [0.645, 0.7175]
# Start of Epoch 7
# Average Train Loss: [1.8545, 1.9024]
# Test Accuracy: [0.6725, 0.7125]
# Start of Epoch 8
# Average Train Loss: [1.8399, 1.8821]
# Test Accuracy: [0.69, 0.7825]
# Start of Epoch 9
# Average Train Loss: [1.8277, 1.8637]
# Test Accuracy: [0.6575, 0.75]
# Finished Training
# Elapsed Test Time: 3.1508216857910156
# Elapsed Training Time: 11.368752241134644
# Final Test Accuracy: [0.6623, 0.7665]
# Start of Epoch 0
# Average Train Loss: [1.722, 1.6987]
# Test Accuracy: [0.67625, 0.78]
# Start of Epoch 1
# Average Train Loss: [1.7172, 1.6958]
# Test Accuracy: [0.6575, 0.7575]
# Start of Epoch 2
# Average Train Loss: [1.7139, 1.6924]
# Test Accuracy: [0.66625, 0.75375]
# Start of Epoch 3
# Average Train Loss: [1.7124, 1.6882]
# Test Accuracy: [0.69125, 0.79625]
# Start of Epoch 4
# Average Train Loss: [1.7113, 1.6797]
# Test Accuracy: [0.6525, 0.79875]
# Start of Epoch 5
# Average Train Loss: [1.71, 1.6697]
# Test Accuracy: [0.69625, 0.7875]
# Start of Epoch 6
# Average Train Loss: [1.7092, 1.6648]
# Test Accuracy: [0.655, 0.78125]
# Start of Epoch 7
# Average Train Loss: [1.7083, 1.6583]
# Test Accuracy: [0.66625, 0.81625]
# Start of Epoch 8
# Average Train Loss: [1.7081, 1.6531]
# Test Accuracy: [0.6775, 0.79625]
# Start of Epoch 9
# Average Train Loss: [1.7077, 1.6489]
# Test Accuracy: [0.67125, 0.79875]
# Finished Training
# Elapsed Test Time: 3.1577436923980713
# Elapsed Training Time: 6.569568395614624
# Final Test Accuracy: [0.6598, 0.7955]
# data slice [54346, ..., 45591]
# data slice [29676, ..., 6159]
# Start of Epoch 0
# Average Train Loss: [2.1581, 2.205]
# Test Accuracy: [0.365, 0.33625]
# Start of Epoch 1
# Average Train Loss: [2.0699, 2.1327]
# Test Accuracy: [0.59, 0.345]
# Start of Epoch 2
# Average Train Loss: [1.99, 2.0812]
# Test Accuracy: [0.63875, 0.52875]
# Start of Epoch 3
# Average Train Loss: [1.9399, 2.0383]
# Test Accuracy: [0.66375, 0.56875]
# Start of Epoch 4
# Average Train Loss: [1.9061, 2.0101]
# Test Accuracy: [0.61, 0.59625]
# Start of Epoch 5
# Average Train Loss: [1.8831, 1.9886]
# Test Accuracy: [0.65125, 0.62625]
# Start of Epoch 6
# Average Train Loss: [1.8647, 1.9728]
# Test Accuracy: [0.625, 0.5875]
# Start of Epoch 7
# Average Train Loss: [1.8507, 1.9587]
# Test Accuracy: [0.62, 0.645]
# Start of Epoch 8
# Average Train Loss: [1.8394, 1.9469]
# Test Accuracy: [0.6375, 0.65875]
# Start of Epoch 9
# Average Train Loss: [1.8298, 1.9376]
# Test Accuracy: [0.66125, 0.6575]
# Finished Training
# Elapsed Test Time: 3.156937599182129
# Elapsed Training Time: 11.374338865280151
# Final Test Accuracy: [0.6446, 0.63]
# Start of Epoch 0
# Average Train Loss: [1.7381, 1.8429]
# Test Accuracy: [0.64125, 0.61875]
# Start of Epoch 1
# Average Train Loss: [1.7365, 1.8478]
# Test Accuracy: [0.6625, 0.595]
# Start of Epoch 2
# Average Train Loss: [1.736, 1.8465]
# Test Accuracy: [0.64875, 0.655]
# Start of Epoch 3
# Average Train Loss: [1.7353, 1.8452]
# Test Accuracy: [0.665, 0.65125]
# Start of Epoch 4
# Average Train Loss: [1.7352, 1.8436]
# Test Accuracy: [0.65125, 0.6375]
# Start of Epoch 5
# Average Train Loss: [1.7342, 1.8423]
# Test Accuracy: [0.6425, 0.64]
# Start of Epoch 6
# Average Train Loss: [1.734, 1.8416]
# Test Accuracy: [0.62875, 0.61125]
# Start of Epoch 7
# Average Train Loss: [1.7343, 1.841]
# Test Accuracy: [0.60625, 0.62875]
# Start of Epoch 8
# Average Train Loss: [1.7341, 1.8404]
# Test Accuracy: [0.6575, 0.63625]
# Start of Epoch 9
# Average Train Loss: [1.7334, 1.84]
# Test Accuracy: [0.64, 0.67625]
# Finished Training
# Elapsed Test Time: 3.141329765319824
# Elapsed Training Time: 6.525175094604492
# Final Test Accuracy: [0.6532, 0.6385]
# Average training time 18.062799334526062
# Average test accuracy 0.7520650000000001
# Median test accuracy 0.778
# Standard deviation test accuracy 0.1152851650256875

# %%
test_accs_dp5 = []
training_times_dp5 = []
for i in range(4):
    m = MultipleDecoder(5, separate_encoders=False)
    m.train(dp=True, epochs=15)
    m.fine_tune(epochs=5)
    test_accs_dp5.extend([x[-1] for x in m.test_accs])
    training_times_dp5.append(m.training_time)

print(f"Average training time", np.mean(training_times_dp5))
print(f"Average test accuracy", np.mean(test_accs_dp5))
print(f"Median test accuracy", np.median(test_accs_dp5))
print(f"Standard deviation test accuracy", np.std(test_accs_dp5))
# Out:
# data slice [16892, ..., 15936]
# data slice [54144, ..., 10471]
# data slice [11877, ..., 27188]
# data slice [47255, ..., 25254]
# data slice [31301, ..., 54184]
# Start of Epoch 0
# Average Train Loss: [2.0284, 2.1329, 2.2076, 2.0991, 2.0288]
# Test Accuracy: [0.515, 0.3525, 0.2925, 0.5975, 0.61375]
# Start of Epoch 1
# Average Train Loss: [1.9313, 2.085, 2.1308, 1.98, 1.9359]
# Test Accuracy: [0.65375, 0.38875, 0.39625, 0.605, 0.65125]
# Start of Epoch 2
# Average Train Loss: [1.8866, 2.0641, 2.0904, 1.9235, 1.8929]
# Test Accuracy: [0.63625, 0.3875, 0.49125, 0.6325, 0.69875]
# Start of Epoch 3
# Average Train Loss: [1.858, 2.0497, 2.0654, 1.8906, 1.8507]
# Test Accuracy: [0.67375, 0.375, 0.5025, 0.65125, 0.7675]
# Start of Epoch 4
# Average Train Loss: [1.8273, 2.0391, 2.0472, 1.869, 1.8208]
# Test Accuracy: [0.7775, 0.34375, 0.50875, 0.64125, 0.7175]
# Start of Epoch 5
# Average Train Loss: [1.801, 2.0312, 2.0328, 1.8542, 1.8012]
# Test Accuracy: [0.8, 0.35, 0.54375, 0.66375, 0.7475]
# Start of Epoch 6
# Average Train Loss: [1.7763, 2.0246, 2.0206, 1.843, 1.7849]
# Test Accuracy: [0.825, 0.37375, 0.54125, 0.66, 0.76125]
# Start of Epoch 7
# Average Train Loss: [1.7568, 2.0178, 2.0107, 1.834, 1.7729]
# Test Accuracy: [0.8125, 0.45375, 0.51125, 0.65875, 0.76125]
# Start of Epoch 8
# Average Train Loss: [1.7406, 2.0082, 2.0028, 1.8265, 1.7628]
# Test Accuracy: [0.81625, 0.44125, 0.5375, 0.6625, 0.7325]
# Start of Epoch 9
# Average Train Loss: [1.7271, 1.9979, 1.9959, 1.82, 1.7556]
# Test Accuracy: [0.80625, 0.4675, 0.56625, 0.63, 0.71375]
# Start of Epoch 10
# Average Train Loss: [1.7162, 1.9892, 1.9901, 1.8137, 1.7498]
# Test Accuracy: [0.85625, 0.49, 0.50375, 0.71125, 0.76375]
# Start of Epoch 11
# Average Train Loss: [1.7068, 1.9821, 1.9849, 1.8075, 1.7443]
# Test Accuracy: [0.82875, 0.43125, 0.52125, 0.71375, 0.765]
# Start of Epoch 12
# Average Train Loss: [1.6989, 1.9756, 1.9805, 1.8024, 1.7391]
# Test Accuracy: [0.82375, 0.4875, 0.51625, 0.745, 0.76]
# Start of Epoch 13
# Average Train Loss: [1.6915, 1.97, 1.9764, 1.7972, 1.7345]
# Test Accuracy: [0.8175, 0.47, 0.54375, 0.73625, 0.74125]
# Start of Epoch 14
# Average Train Loss: [1.6848, 1.9647, 1.973, 1.7925, 1.73]
# Test Accuracy: [0.82125, 0.48625, 0.52875, 0.7275, 0.7625]
# Finished Training
# Elapsed Test Time: 11.845759391784668
# Elapsed Training Time: 42.90537643432617
# Final Test Accuracy: [0.8408, 0.4653, 0.5492, 0.7329, 0.7719]
# Start of Epoch 0
# Average Train Loss: [1.5887, 1.8901, 1.9219, 1.732, 1.6379]
# Test Accuracy: [0.8625, 0.47625, 0.54125, 0.73125, 0.815]
# Start of Epoch 1
# Average Train Loss: [1.5864, 1.8895, 1.9207, 1.7276, 1.6196]
# Test Accuracy: [0.8225, 0.45875, 0.54625, 0.73125, 0.815]
# Start of Epoch 2
# Average Train Loss: [1.5848, 1.8883, 1.9207, 1.7245, 1.6103]
# Test Accuracy: [0.845, 0.48625, 0.525, 0.70875, 0.8475]
# Start of Epoch 3
# Average Train Loss: [1.5847, 1.8877, 1.9192, 1.7237, 1.604]
# Test Accuracy: [0.83, 0.47875, 0.555, 0.74125, 0.83625]
# Start of Epoch 4
# Average Train Loss: [1.5847, 1.8869, 1.9184, 1.7219, 1.601]
# Test Accuracy: [0.84875, 0.50125, 0.55625, 0.72875, 0.82]
# Finished Training
# Elapsed Test Time: 3.9682013988494873
# Elapsed Training Time: 8.166351795196533
# Final Test Accuracy: [0.8401, 0.4661, 0.5372, 0.7507, 0.8341]
# data slice [45484, ..., 56787]
# data slice [19222, ..., 17681]
# data slice [51112, ..., 43461]
# data slice [12114, ..., 28199]
# data slice [46517, ..., 43613]
# Start of Epoch 0
# Average Train Loss: [2.1047, 2.1346, 2.16, 2.1258, 2.1251]
# Test Accuracy: [0.4725, 0.42125, 0.3425, 0.385, 0.43125]
# Start of Epoch 1
# Average Train Loss: [2.0205, 2.0397, 2.1032, 2.0588, 2.0306]
# Test Accuracy: [0.55125, 0.53125, 0.44875, 0.40625, 0.615]
# Start of Epoch 2
# Average Train Loss: [1.9892, 1.9936, 2.0695, 2.0283, 1.9706]
# Test Accuracy: [0.54625, 0.53875, 0.43625, 0.3775, 0.55875]
# Start of Epoch 3
# Average Train Loss: [1.9689, 1.9586, 2.0471, 2.0118, 1.9362]
# Test Accuracy: [0.585, 0.59375, 0.45, 0.365, 0.65375]
# Start of Epoch 4
# Average Train Loss: [1.9543, 1.9209, 2.0297, 2.0004, 1.9136]
# Test Accuracy: [0.52625, 0.65875, 0.4925, 0.40875, 0.6275]
# Start of Epoch 5
# Average Train Loss: [1.9438, 1.8931, 2.0068, 1.9931, 1.8969]
# Test Accuracy: [0.59, 0.69625, 0.49625, 0.38, 0.635]
# Start of Epoch 6
# Average Train Loss: [1.9345, 1.8728, 1.9882, 1.9868, 1.8832]
# Test Accuracy: [0.57625, 0.67125, 0.57875, 0.4025, 0.65875]
# Start of Epoch 7
# Average Train Loss: [1.9267, 1.8574, 1.9724, 1.9819, 1.8722]
# Test Accuracy: [0.55125, 0.6525, 0.55875, 0.41375, 0.635]
# Start of Epoch 8
# Average Train Loss: [1.9199, 1.8445, 1.9595, 1.978, 1.863]
# Test Accuracy: [0.59625, 0.70375, 0.53125, 0.4325, 0.6375]
# Start of Epoch 9
# Average Train Loss: [1.9136, 1.8337, 1.9472, 1.9747, 1.8556]
# Test Accuracy: [0.6, 0.675, 0.56, 0.40875, 0.6675]
# Start of Epoch 10
# Average Train Loss: [1.9078, 1.8251, 1.9363, 1.9718, 1.8492]
# Test Accuracy: [0.65125, 0.66125, 0.6275, 0.39625, 0.6625]
# Start of Epoch 11
# Average Train Loss: [1.9005, 1.8178, 1.9264, 1.9694, 1.8436]
# Test Accuracy: [0.64, 0.67125, 0.6, 0.36875, 0.695]
# Start of Epoch 12
# Average Train Loss: [1.8911, 1.8116, 1.9176, 1.9673, 1.8389]
# Test Accuracy: [0.6775, 0.6525, 0.6375, 0.38625, 0.675]
# Start of Epoch 13
# Average Train Loss: [1.8823, 1.8061, 1.9098, 1.9654, 1.8347]
# Test Accuracy: [0.685, 0.71125, 0.62375, 0.4, 0.69]
# Start of Epoch 14
# Average Train Loss: [1.8734, 1.8008, 1.903, 1.9639, 1.8315]
# Test Accuracy: [0.69125, 0.645, 0.6325, 0.39125, 0.66]
# Finished Training
# Elapsed Test Time: 11.84836745262146
# Elapsed Training Time: 42.83789134025574
# Final Test Accuracy: [0.6964, 0.6786, 0.6251, 0.393, 0.6686]
# Start of Epoch 0
# Average Train Loss: [1.7461, 1.7227, 1.8059, 1.9412, 1.7861]
# Test Accuracy: [0.695, 0.72375, 0.6225, 0.37875, 0.66125]
# Start of Epoch 1
# Average Train Loss: [1.741, 1.7228, 1.806, 1.9417, 1.784]
# Test Accuracy: [0.69875, 0.64125, 0.63, 0.415, 0.67875]
# Start of Epoch 2
# Average Train Loss: [1.7385, 1.7225, 1.8052, 1.9417, 1.7822]
# Test Accuracy: [0.73875, 0.67125, 0.66875, 0.4, 0.64625]
# Start of Epoch 3
# Average Train Loss: [1.7355, 1.7228, 1.8041, 1.9416, 1.7802]
# Test Accuracy: [0.69625, 0.67125, 0.6475, 0.3875, 0.66875]
# Start of Epoch 4
# Average Train Loss: [1.7314, 1.7227, 1.8037, 1.9415, 1.779]
# Test Accuracy: [0.7175, 0.6225, 0.59875, 0.395, 0.7075]
# Finished Training
# Elapsed Test Time: 3.999074697494507
# Elapsed Training Time: 8.335540056228638
# Final Test Accuracy: [0.7137, 0.6756, 0.6202, 0.3931, 0.6773]
# data slice [6401, ..., 37419]
# data slice [28916, ..., 3844]
# data slice [4998, ..., 15997]
# data slice [8388, ..., 50502]
# data slice [21423, ..., 13250]
# Start of Epoch 0
# Average Train Loss: [2.1061, 2.1474, 2.0453, 2.1028, 2.0941]
# Test Accuracy: [0.475, 0.3875, 0.52625, 0.4325, 0.46875]
# Start of Epoch 1
# Average Train Loss: [2.0469, 2.0687, 1.919, 2.0413, 2.0336]
# Test Accuracy: [0.4775, 0.5175, 0.69875, 0.5025, 0.48625]
# Start of Epoch 2
# Average Train Loss: [2.0221, 2.0066, 1.8473, 1.9989, 2.0079]
# Test Accuracy: [0.49375, 0.6175, 0.6975, 0.52, 0.59625]
# Start of Epoch 3
# Average Train Loss: [2.0061, 1.9581, 1.8069, 1.9709, 1.9724]
# Test Accuracy: [0.505, 0.725, 0.76625, 0.5425, 0.615]
# Start of Epoch 4
# Average Train Loss: [1.9936, 1.9238, 1.7761, 1.9507, 1.936]
# Test Accuracy: [0.51, 0.7125, 0.85875, 0.555, 0.64]
# Start of Epoch 5
# Average Train Loss: [1.971, 1.8981, 1.749, 1.9356, 1.9085]
# Test Accuracy: [0.6425, 0.74, 0.825, 0.57, 0.63875]
# Start of Epoch 6
# Average Train Loss: [1.9436, 1.8783, 1.7259, 1.9255, 1.8872]
# Test Accuracy: [0.6625, 0.62875, 0.85, 0.58125, 0.68375]
# Start of Epoch 7
# Average Train Loss: [1.9198, 1.8623, 1.708, 1.9137, 1.87]
# Test Accuracy: [0.66375, 0.73625, 0.85625, 0.63, 0.66125]
# Start of Epoch 8
# Average Train Loss: [1.9003, 1.849, 1.6937, 1.8994, 1.8565]
# Test Accuracy: [0.67, 0.735, 0.84, 0.6775, 0.675]
# Start of Epoch 9
# Average Train Loss: [1.8837, 1.8381, 1.6824, 1.884, 1.845]
# Test Accuracy: [0.705, 0.745, 0.825, 0.74125, 0.68]
# Start of Epoch 10
# Average Train Loss: [1.8696, 1.8287, 1.6736, 1.8694, 1.8354]
# Test Accuracy: [0.6925, 0.74625, 0.84875, 0.6975, 0.70875]
# Start of Epoch 11
# Average Train Loss: [1.8577, 1.8208, 1.6658, 1.8544, 1.827]
# Test Accuracy: [0.68875, 0.75, 0.84625, 0.73125, 0.69625]
# Start of Epoch 12
# Average Train Loss: [1.8477, 1.814, 1.6588, 1.8399, 1.8198]
# Test Accuracy: [0.67375, 0.735, 0.855, 0.82, 0.6475]
# Start of Epoch 13
# Average Train Loss: [1.839, 1.808, 1.6526, 1.8238, 1.8137]
# Test Accuracy: [0.68375, 0.77625, 0.86, 0.88, 0.7025]
# Start of Epoch 14
# Average Train Loss: [1.8312, 1.8028, 1.6477, 1.8048, 1.8078]
# Test Accuracy: [0.69125, 0.73625, 0.8325, 0.9175, 0.72875]
# Finished Training
# Elapsed Test Time: 11.822037696838379
# Elapsed Training Time: 42.598108530044556
# Final Test Accuracy: [0.6735, 0.7481, 0.8487, 0.9056, 0.7142]
# Start of Epoch 0
# Average Train Loss: [1.7258, 1.7288, 1.5727, 1.5154, 1.6918]
# Test Accuracy: [0.69125, 0.73125, 0.865, 0.925, 0.765]
# Start of Epoch 1
# Average Train Loss: [1.7246, 1.7286, 1.5698, 1.5071, 1.6827]
# Test Accuracy: [0.66625, 0.76125, 0.82875, 0.9225, 0.75875]
# Start of Epoch 2
# Average Train Loss: [1.7259, 1.7285, 1.5691, 1.5038, 1.6764]
# Test Accuracy: [0.6375, 0.765, 0.8425, 0.91875, 0.77]
# Start of Epoch 3
# Average Train Loss: [1.7258, 1.7313, 1.5701, 1.5018, 1.6715]
# Test Accuracy: [0.6875, 0.74875, 0.83625, 0.91375, 0.75375]
# Start of Epoch 4
# Average Train Loss: [1.7278, 1.733, 1.5712, 1.5003, 1.6691]
# Test Accuracy: [0.69875, 0.73375, 0.84125, 0.90875, 0.7725]
# Finished Training
# Elapsed Test Time: 3.912879467010498
# Elapsed Training Time: 8.146146535873413
# Final Test Accuracy: [0.6739, 0.7138, 0.8477, 0.9187, 0.7601]
# data slice [57211, ..., 28589]
# data slice [35795, ..., 6183]
# data slice [13026, ..., 5686]
# data slice [47688, ..., 22937]
# data slice [19957, ..., 38374]
# Start of Epoch 0
# Average Train Loss: [2.186, 2.1194, 2.2464, 2.0793, 2.0916]
# Test Accuracy: [0.3875, 0.50375, 0.3275, 0.4575, 0.445]
# Start of Epoch 1
# Average Train Loss: [2.1096, 2.029, 2.1677, 2.0022, 2.0314]
# Test Accuracy: [0.41875, 0.55625, 0.45, 0.4725, 0.465]
# Start of Epoch 2
# Average Train Loss: [2.0715, 1.9858, 2.1083, 1.9407, 1.9946]
# Test Accuracy: [0.43625, 0.5625, 0.51375, 0.63, 0.555]
# Start of Epoch 3
# Average Train Loss: [2.0489, 1.9604, 2.0638, 1.9003, 1.9671]
# Test Accuracy: [0.4625, 0.59875, 0.5675, 0.67625, 0.535]
# Start of Epoch 4
# Average Train Loss: [2.0326, 1.9433, 2.0295, 1.8749, 1.9473]
# Test Accuracy: [0.445, 0.5575, 0.54625, 0.6275, 0.55625]
# Start of Epoch 5
# Average Train Loss: [2.0203, 1.932, 2.0038, 1.8573, 1.9323]
# Test Accuracy: [0.515, 0.53625, 0.58125, 0.66, 0.56625]
# Start of Epoch 6
# Average Train Loss: [2.0104, 1.9227, 1.9784, 1.8436, 1.92]
# Test Accuracy: [0.55, 0.57375, 0.6925, 0.66125, 0.5675]
# Start of Epoch 7
# Average Train Loss: [2.0025, 1.9146, 1.9479, 1.8347, 1.9099]
# Test Accuracy: [0.525, 0.575, 0.715, 0.67125, 0.59375]
# Start of Epoch 8
# Average Train Loss: [1.9921, 1.9085, 1.9211, 1.8265, 1.901]
# Test Accuracy: [0.545, 0.565, 0.73625, 0.62, 0.565]
# Start of Epoch 9
# Average Train Loss: [1.9811, 1.903, 1.8991, 1.8203, 1.8935]
# Test Accuracy: [0.56125, 0.58, 0.72875, 0.6775, 0.55375]
# Start of Epoch 10
# Average Train Loss: [1.9712, 1.898, 1.8805, 1.8141, 1.8873]
# Test Accuracy: [0.5425, 0.6025, 0.7375, 0.6475, 0.5775]
# Start of Epoch 11
# Average Train Loss: [1.963, 1.8919, 1.8644, 1.8086, 1.8816]
# Test Accuracy: [0.57375, 0.645, 0.74125, 0.6825, 0.59125]
# Start of Epoch 12
# Average Train Loss: [1.9558, 1.8812, 1.8503, 1.803, 1.8768]
# Test Accuracy: [0.56125, 0.67875, 0.7525, 0.72125, 0.59125]
# Start of Epoch 13
# Average Train Loss: [1.9492, 1.8707, 1.8379, 1.7966, 1.8724]
# Test Accuracy: [0.57875, 0.67875, 0.75, 0.72125, 0.56625]
# Start of Epoch 14
# Average Train Loss: [1.9435, 1.8604, 1.8268, 1.7889, 1.8689]
# Test Accuracy: [0.565, 0.65, 0.7975, 0.72875, 0.54625]
# Finished Training
# Elapsed Test Time: 11.894762992858887
# Elapsed Training Time: 42.628360986709595
# Final Test Accuracy: [0.5671, 0.6614, 0.7573, 0.733, 0.5783]
# Start of Epoch 0
# Average Train Loss: [1.8643, 1.7125, 1.668, 1.6745, 1.8157]
# Test Accuracy: [0.5875, 0.68875, 0.75875, 0.75, 0.5725]
# Start of Epoch 1
# Average Train Loss: [1.863, 1.7116, 1.6666, 1.6684, 1.814]
# Test Accuracy: [0.58375, 0.7075, 0.755, 0.72125, 0.595]
# Start of Epoch 2
# Average Train Loss: [1.862, 1.7094, 1.6653, 1.6667, 1.813]
# Test Accuracy: [0.605, 0.6525, 0.77, 0.75375, 0.59625]
# Start of Epoch 3
# Average Train Loss: [1.8622, 1.7079, 1.6641, 1.6641, 1.8124]
# Test Accuracy: [0.565, 0.6725, 0.775, 0.7475, 0.56]
# Start of Epoch 4
# Average Train Loss: [1.8617, 1.7067, 1.6637, 1.6621, 1.812]
# Test Accuracy: [0.57125, 0.645, 0.75375, 0.76875, 0.6]
# Finished Training
# Elapsed Test Time: 3.9428062438964844
# Elapsed Training Time: 8.160675525665283
# Final Test Accuracy: [0.5645, 0.6765, 0.7554, 0.7621, 0.5834]
# Average training time 50.94461280107498
# Average test accuracy 0.68821
# Median test accuracy 0.6955
# Standard deviation test accuracy 0.12923438745163765

# %%
test_accs_dp10 = []
training_times_dp10 = []
for i in range(2):
    m = MultipleDecoder(10, separate_encoders=False)
    m.train(dp=True, epochs=15)
    m.fine_tune(epochs=5)
    test_accs_dp10.extend([x[-1] for x in m.test_accs])
    training_times_dp10.append(m.training_time)
print(f"Average training time", np.mean(training_times_dp10))
print(f"Average test accuracy", np.mean(test_accs_dp10))
print(f"Median test accuracy", np.median(test_accs_dp10))
print(f"Standard deviation test accuracy", np.std(test_accs_dp10))
# Out:
# data slice [29957, ..., 33986]
# data slice [46014, ..., 53856]
# data slice [1204, ..., 8952]
# data slice [47374, ..., 57370]
# data slice [48104, ..., 46459]
# data slice [33418, ..., 14436]
# data slice [30013, ..., 36606]
# data slice [50100, ..., 52116]
# data slice [436, ..., 6761]
# data slice [47780, ..., 23722]
# Start of Epoch 0
# Average Train Loss: [2.1285, 2.0171, 2.1045, 2.0914, 2.0117, 2.0043, 2.105, 2.0332, 2.1361, 1.9452]
# Test Accuracy: [0.4875, 0.575, 0.445, 0.4975, 0.5825, 0.5425, 0.4575, 0.48375, 0.4375, 0.6825]
# Start of Epoch 1
# Average Train Loss: [2.0022, 1.9106, 2.0418, 1.9646, 1.9368, 1.9455, 2.0147, 1.9917, 2.0598, 1.8188]
# Test Accuracy: [0.6725, 0.70125, 0.5575, 0.6675, 0.6075, 0.565, 0.52875, 0.52625, 0.5025, 0.8375]
# Start of Epoch 2
# Average Train Loss: [1.9413, 1.8514, 1.9965, 1.8869, 1.9018, 1.9221, 1.9677, 1.974, 2.0048, 1.7556]
# Test Accuracy: [0.7375, 0.83875, 0.75375, 0.91125, 0.865, 0.67, 0.66, 0.69125, 0.56, 0.81875]
# Start of Epoch 13
# Average Train Loss: [1.7601, 1.6752, 1.7746, 1.6273, 1.6827, 1.8164, 1.7881, 1.826, 1.8691, 1.6277]
# Test Accuracy: [0.75, 0.84375, 0.775, 0.9175, 0.8375, 0.67875, 0.68625, 0.695, 0.57, 0.845]
# Start of Epoch 14
# Average Train Loss: [1.7523, 1.6683, 1.7683, 1.6181, 1.6741, 1.8111, 1.7841, 1.8179, 1.8655, 1.6248]
# Test Accuracy: [0.77125, 0.8575, 0.7475, 0.9075, 0.84875, 0.66625, 0.68, 0.725, 0.56875, 0.865]
# Finished Training
# Elapsed Test Time: 23.807503700256348
# Elapsed Training Time: 85.71429920196533
# Final Test Accuracy: [0.7588, 0.8493, 0.7658, 0.9024, 0.8463, 0.6743, 0.6649, 0.724, 0.5593, 0.853]
# Start of Epoch 0
# Average Train Loss: [1.6437, 1.5766, 1.6779, 1.4903, 1.554, 1.7252, 1.7261, 1.6626, 1.8126, 1.5804]
# Test Accuracy: [0.78625, 0.855, 0.77625, 0.91625, 0.8475, 0.6675, 0.66, 0.77625, 0.585, 0.85]
# Start of Epoch 1
# Average Train Loss: [1.6406, 1.5757, 1.6768, 1.4848, 1.5516, 1.7192, 1.7239, 1.6562, 1.8122, 1.5808]
# Test Accuracy: [0.73625, 0.8675, 0.7675, 0.91625, 0.8525, 0.7075, 0.7025, 0.74, 0.56875, 0.83]
# Start of Epoch 2
# Average Train Loss: [1.6377, 1.5742, 1.6753, 1.4826, 1.5496, 1.7129, 1.724, 1.6522, 1.8174, 1.5817]
# Test Accuracy: [0.73875, 0.8525, 0.75625, 0.92, 0.8425, 0.72875, 0.69125, 0.805, 0.5775, 0.83]
# Start of Epoch 3
# Average Train Loss: [1.6366, 1.5719, 1.6702, 1.4814, 1.5484, 1.7074, 1.7229, 1.6484, 1.8195, 1.5814]
# Test Accuracy: [0.7625, 0.85875, 0.81125, 0.93375, 0.85875, 0.75125, 0.695, 0.81, 0.5175, 0.87875]
# Start of Epoch 4
# Average Train Loss: [1.6368, 1.572, 1.6572, 1.4807, 1.5476, 1.7018, 1.722, 1.6416, 1.8186, 1.5798]
# Test Accuracy: [0.76875, 0.84875, 0.845, 0.92875, 0.865, 0.78, 0.66375, 0.88, 0.58375, 0.85]
# Finished Training
# Elapsed Test Time: 7.869086980819702
# Elapsed Training Time: 16.32977867126465
# Final Test Accuracy: [0.7544, 0.8478, 0.8301, 0.9258, 0.8548, 0.7486, 0.6711, 0.874, 0.5662, 0.8605]
# data slice [3203, ..., 12927]
# data slice [47728, ..., 15928]
# data slice [43508, ..., 34446]
# data slice [1408, ..., 10155]
# data slice [6829, ..., 6383]
# data slice [45286, ..., 5237]
# data slice [9445, ..., 30158]
# data slice [15823, ..., 53192]
# data slice [1177, ..., 18633]
# data slice [11313, ..., 34070]
# Start of Epoch 0
# Average Train Loss: [2.1251, 2.0116, 2.118, 2.1673, 2.058, 2.1121, 2.1103, 2.2066, 2.0881, 2.1026]
[]
for i in range(2):
    m = MultipleDecoder(10, separate_encoders=True, dataset="fashionmnist")
    m.train(dp=False, epochs=20)
    fashion_test_accs.extend([x[-1] for x in m.test_accs])
    fashion_training_times.append(m.training_time)

print(f"Average training time", np.mean(fashion_training_times))
print(f"Average test accuracy", np.mean(fashion_test_accs))
print(f"Median test accuracy", np.median(fashion_test_accs))
print(f"Standard deviation test accuracy", np.std(fashion_test_accs))
# Out:
# data slice [3727, ..., 54019]
# data slice [13485, ..., 25627]
# data slice [23935, ..., 6722]
# data slice [58849, ..., 54073]
# data slice [25174, ..., 25905]
# data slice [45770, ..., 29955]
# data slice [32628, ..., 50356]
# data slice [49300, ..., 57944]
# data slice [57056, ..., 59654]
# data slice [57894, ..., 39400]
# Start of Epoch 0
# Average Train Loss: [2.2058, 2.0464, 2.15, 2.1601, 2.1967, 2.2654, 2.141, 2.0973, 2.1315, 2.1118]
# Test Accuracy: [0.325, 0.50875, 0.37875, 0.3425, 0.45, 0.19625, 0.355, 0.43625, 0.4375, 0.5]
# Start of Epoch 1
# Average Train Loss: [2.1382, 1.9851, 2.0833, 2.1325, 2.1163, 2.227, 2.117, 2.0549, 2.0889, 2.0334]
# Test Accuracy: [0.3625, 0.52625, 0.47125, 0.37625, 0.4725, 0.22125, 0.3425, 0.5175, 0.44875, 0.575]
# Start of Epoch 2
# Average Train Loss: [2.1075, 1.9608, 2.0507, 2.1195, 2.0842, 2.2062, 2.1063, 2.0227, 2.0691, 1.9839]
# Test Accuracy: [0.43875, 0.5275, 0.48875, 0.37375, 0.46375, 0.2325, 0.38875, 0.48375, 0.44125, 0.62]
# Start of Epoch 3
# Average Train Loss: [2.0902, 1.9472, 2.0317, 2.1101, 2.0653, 2.1939, 2.1011, 2.0028, 2.056, 1.9558]
# Test Accuracy: [0.44375, 0.52125, 0.4325, 0.3825, 0.47875, 0.22875, 0.36625, 0.51375, 0.43375, 0.6325]
# Start of Epoch 4
# Average Train Loss: [2.0758, 1.9387, 2.0163, 2.105, 2.0495, 2.1854, 2.0954, 1.9874, 2.0468, 1.9349]
# Test Accuracy: [0.4775, 0.52375, 0.45875, 0.3675, 0.4425, 0.24125, 0.3775, 0.47125, 0.44125, 0.62]
# Start of Epoch 5
# Average Train Loss: [2.0584, 1.9322, 2.0059, 2.1001, 2.0399, 2.178, 2.091, 1.9758, 2.038, 1.9168]
# Test Accuracy: [0.56625, 0.53875, 0.5075, 0.3525, 0.50375, 0.32125, 0.3925, 0.5525, 0.48875, 0.67125]
# Start of Epoch 6
# Average Train Loss: [2.0427, 1.9265, 1.9981, 2.0956, 2.0303, 2.1725, 2.0855, 1.9664, 2.0244, 1.8952]
# Test Accuracy: [0.52125, 0.545, 0.5225, 0.3925, 0.48875, 0.315, 0.43875, 0.5425, 0.52125, 0.6775]
# Start of Epoch 7
# Average Train Loss: [2.0269, 1.9212, 1.9908, 2.0912, 2.0222, 2.1676, 2.0741, 1.9586, 2.0128, 1.878]
# Start of Epoch 18
# Average Train Loss: [1.9086, 1.889, 1.9513, 1.9741, 1.9811, 2.0992, 1.9371, 1.9157, 1.9206, 1.7943]
# Test Accuracy: [0.695, 0.55875, 0.5025, 0.61875, 0.51625, 0.365, 0.675, 0.56, 0.6825, 0.7075]
# Start of Epoch 19
# Average Train Loss: [1.9016, 1.8859, 1.9491, 1.965, 1.9787, 2.0962, 1.926, 1.9137, 1.9107, 1.7905]
# Test Accuracy: [0.70875, 0.54375, 0.5425, 0.63, 0.5025, 0.3525, 0.69875, 0.5525, 0.7025, 0.69]
# Finished Training
# Elapsed Test Time: 31.528411865234375
# Elapsed Training Time: 65.4125463962555
# Final Test Accuracy: [0.693, 0.5561, 0.5144, 0.6382, 0.5323, 0.3651, 0.6902, 0.5491, 0.7056, 0.694]
# data slice [13131, ..., 8454]
# data slice [18759, ..., 10662]
# data slice [54016, ..., 57225]
# data slice [46952, ..., 32995]
# data slice [40095, ..., 33974]
# data slice [38502, ..., 57388]
# data slice [2296, ..., 57315]
# data slice [41116, ..., 46658]
# data slice [13091, ..., 11092]
# data slice [45925, ..., 10934]
# Start of Epoch 0
# Average Train Loss: [2.1874, 2.0593, 2.1102, 2.1221, 2.0859, 2.195, 2.0596, 2.1238, 2.1885, 2.2038]
# Test Accuracy: [0.3175, 0.52625, 0.38625, 0.4075, 0.44375, 0.20375, 0.5, 0.51875, 0.35625, 0.3975]
# Start of Epoch 1
# Average Train Loss: [2.1503, 1.9939, 2.074, 2.0017, 2.0248, 2.2122, 1.9858, 2.0168, 2.1093, 2.1383]
# Test Accuracy: [0.34875, 0.58, 0.4575, 0.595, 0.52125, 0.345, 0.53875, 0.58, 0.5025, 0.39125]
# Start of Epoch 2
# Average Train Loss: [2.1099, 1.9668, 2.039, 1.9454, 1.9921, 2.1777, 1.9478, 1.964, 2.0556, 2.1098]
# Test Accuracy: [0.4925, 0.50625, 0.525, 0.60375, 0.5175, 0.355, 0.64125, 0.595, 0.51125, 0.34]
# Start of Epoch 3
# Average Train Loss: [2.0693, 1.9525, 2.0117, 1.914, 1.9708, 2.1545, 1.908, 1.936, 2.0207, 2.0978]
# Test Accuracy: [0.50875, 0.5325, 0.51375, 0.60625, 0.50125, 0.3475, 0.675, 0.57875, 0.555, 0.3125]
# Start of Epoch 4
# Average Train Loss: [2.0386, 1.9425, 1.9928, 1.8904, 1.9579, 2.1262, 1.8789, 1.9182, 2.0002, 2.0885]
# Test Accuracy: [0.555, 0.5675, 0.505, 0.61375, 0.55875, 0.47, 0.66875, 0.58875, 0.5, 0.36]
# Start of Epoch 5
# Average Train Loss: [2.0167, 1.9348, 1.981, 1.8754, 1.9484, 2.094, 1.8572, 1.9057, 1.9823, 2.0799]
# Test Accuracy: [0.5475, 0.545, 0.53, 0.65875, 0.52, 0.55875, 0.63625, 0.59875, 0.5125, 0.31125]
# Start of Epoch 6
# Average Train Loss: [2.0003, 1.929, 1.9706, 1.8631, 1.9418, 2.0663, 1.8417, 1.8957, 1.9673, 2.0738]
# Start of Epoch 17
# Average Train Loss: [1.9083, 1.8658, 1.8962, 1.7894, 1.8717, 1.8799, 1.7659, 1.847, 1.8467, 2.0214]
# Test Accuracy: [0.60625, 0.64, 0.68, 0.68, 0.6, 0.69875, 0.6975, 0.63625, 0.65875, 0.38125]
# Start of Epoch 18
# Average Train Loss: [1.9012, 1.8625, 1.8877, 1.7854, 1.8679, 1.8702, 1.7623, 1.8441, 1.8401, 2.0182]
# Test Accuracy: [0.63, 0.57875, 0.6675, 0.68625, 0.64, 0.68, 0.7, 0.6525, 0.7, 0.405]
# Start of Epoch 19
# Average Train Loss: [1.8947, 1.8597, 1.8796, 1.782, 1.8646, 1.8615, 1.7592, 1.843, 1.8339, 2.0151]
# Test Accuracy: [0.64875, 0.6525, 0.665, 0.675, 0.595, 0.68875, 0.7275, 0.645, 0.6575, 0.385]
# Finished Training
# Elapsed Test Time: 31.91350293159485
# Elapsed Training Time: 65.82590627670288
# Final Test Accuracy: [0.6299, 0.611, 0.6618, 0.6684, 0.6232, 0.6908, 0.7013, 0.6443, 0.6504, 0.3889]
# Average training time 65.61922633647919
# Average test accuracy 0.6103999999999999
# Median test accuracy 0.64125
# Standard deviation test accuracy 0.09625444405324879

# %%
fashion_test_accs_dp10 = []
fashion_training_times_dp10 = []
for i in range(2):
    m = MultipleDecoder(10, separate_encoders=False, dataset="fashionmnist")
    m.train(dp=True, epochs=15)
    m.fine_tune(epochs=5)
    fashion_test_accs_dp10.extend([x[-1] for x in m.test_accs])
    fashion_training_times_dp10.append(m.training_time)
print(f"Average training time", np.mean(fashion_training_times_dp10))
print(f"Average test accuracy", np.mean(fashion_test_accs_dp10))
print(f"Median test accuracy", np.median(fashion_test_accs_dp10))
print(f"Standard deviation test accuracy", np.std(fashion_test_accs_dp10))
# Out:
# data slice [22711, ..., 8166]
# data slice [8128, ..., 25808]
# data slice [52745, ..., 20581]
# data slice [55604, ..., 39027]
# data slice [34421, ..., 41712]
# data slice [10042, ..., 51753]
# data slice [3329, ..., 15414]
# data slice [28241, ..., 14988]
# data slice [10570, ..., 28244]
# data slice [4254, ..., 2750]
# Start of Epoch 0
# Average Train Loss: [2.1193, 2.1229, 2.1559, 2.1155, 2.1719, 2.1442, 2.1362, 2.1769, 2.0395, 2.1756]
# Test Accuracy: [0.395, 0.34875, 0.3725, 0.45625, 0.33375, 0.45875, 0.3175, 0.44625, 0.6625, 0.36375]
# Start of Epoch 1
# Average Train Loss: [2.054, 2.0764, 2.1024, 2.0344, 2.1312, 2.0734, 2.1064, 2.0821, 1.9319, 2.0896]
# Test Accuracy: [0.52125, 0.495, 0.42625, 0.5075, 0.4025, 0.4375, 0.3475, 0.515, 0.6775, 0.45875]
# Start of Epoch 2
# Average Train Loss: [2.0115, 2.0477, 2.0755, 1.9992, 2.0894, 2.0418, 2.0955, 2.0329, 1.8871, 2.0498]
# Test Accuracy: [0.50875, 0.5075, 0.44375, 0.4925, 0.4, 0.475, 0.39125, 0.50625, 0.67375, 0.4725]
# Start of Epoch 3
# Average Train Loss: [1.9823, 2.0254, 2.0602, 1.9713, 2.0555, 2.0251, 2.0883, 2.0013, 1.8601, 2.0241]
# Test Accuracy: [0.5375, 0.475, 0.4225, 0.545, 0.54125, 0.505, 0.3675, 0.56125, 0.68, 0.51375]
# Average Train Loss: [1.8736, 1.9314, 1.9524, 1.8701, 1.9315, 1.9596, 2.0618, 1.8812, 1.7684, 1.8691]
# Test Accuracy: [0.59875, 0.6575, 0.565, 0.58875, 0.51875, 0.58, 0.455, 0.66625, 0.69875, 0.63875]
# Finished Training
# Elapsed Test Time: 23.846502542495728
# Elapsed Training Time: 85.77581906318665
# Final Test Accuracy: [0.5991, 0.6519, 0.5767, 0.5945, 0.5381, 0.5712, 0.4596, 0.6546, 0.706, 0.6428]
# Start of Epoch 0
# Average Train Loss: [1.7945, 1.8276, 1.869, 1.8164, 1.8605, 1.8897, 1.9764, 1.7453, 1.7013, 1.7738]
# Test Accuracy: [0.6175, 0.6375, 0.57125, 0.59875, 0.56, 0.57, 0.48625, 0.6575, 0.70125, 0.6075]
# Start of Epoch 1
# Average Train Loss: [1.7967, 1.8341, 1.8645, 1.8151, 1.8574, 1.8884, 1.9744, 1.7446, 1.7009, 1.7724]
# Test Accuracy: [0.565, 0.66125, 0.5475, 0.595, 0.54, 0.5425, 0.44375, 0.63375, 0.72375, 0.62]
# Start of Epoch 2
# Average Train Loss: [1.7973, 1.8295, 1.862, 1.8143, 1.8605, 1.8892, 1.9713, 1.7415, 1.6986, 1.7645]
# Test Accuracy: [0.57375, 0.67, 0.585, 0.60625, 0.57375, 0.53875, 0.485, 0.67875, 0.67625, 0.6625]
# Start of Epoch 3
# Average Train Loss: [1.7962, 1.8246, 1.8634, 1.8149, 1.8587, 1.8881, 1.9697, 1.7321, 1.6993, 1.7568]
# Test Accuracy: [0.595, 0.6325, 0.5675, 0.59625, 0.53875, 0.57375, 0.49, 0.6725, 0.70875, 0.64625]
# Start of Epoch 4
# Average Train Loss: [1.7946, 1.826, 1.8623, 1.8147, 1.8557, 1.8854, 1.9685, 1.726, 1.6987, 1.7546]
# Test Accuracy: [0.61375, 0.62875, 0.5625, 0.57375, 0.53625, 0.59125, 0.4775, 0.68875, 0.72375, 0.6625]
# Finished Training
# Elapsed Test Time: 7.852745532989502
# Elapsed Training Time: 16.37667417526245
# Final Test Accuracy: [0.602, 0.6336, 0.5756, 0.5916, 0.5482, 0.5744, 0.46, 0.6808, 0.7078, 0.6503]
# data slice [20252, ..., 37622]
# data slice [47961, ..., 38134]
# data slice [37730, ..., 35841]
# data slice [22472, ..., 49751]
# data slice [50347, ..., 30483]
# data slice [30426, ..., 14751]
# data slice [58293, ..., 16030]
# data slice [20028, ..., 47606]
# data slice [18015, ..., 11725]
# data slice [4150, ..., 24947]
# Start of Epoch 0
# Average Train Loss: [2.0925, 2.1384, 2.0607, 2.0542, 2.1151, 2.1182, 2.1481, 2.0767, 2.1124, 2.1938]
# Test Accuracy: [0.52125, 0.43375, 0.48875, 0.515, 0.48875, 0.44, 0.375, 0.52375, 0.47625, 0.27375]
# Start of Epoch 1
# Average Train Loss: [2.0152, 2.0664, 1.9972, 1.9754, 2.0382, 2.0387, 2.0828, 2.0046, 2.0577, 2.1521]
# Test Accuracy: [0.53125, 0.55875, 0.55125, 0.57375, 0.52375, 0.51, 0.5325, 0.5475, 0.48, 0.42]
# Test Accuracy: [0.585, 0.6225, 0.58125, 0.66125, 0.69875, 0.54875, 0.7175, 0.575, 0.5575, 0.63625]
# Start of Epoch 13
# Average Train Loss: [1.9047, 1.8827, 1.9076, 1.7999, 1.8826, 1.8985, 1.8596, 1.8916, 1.9357, 1.8921]
# Test Accuracy: [0.50875, 0.56125, 0.63125, 0.6725, 0.64, 0.5175, 0.675, 0.53875, 0.5725, 0.65]
# Start of Epoch 14
# Average Train Loss: [1.9018, 1.8788, 1.9012, 1.7963, 1.877, 1.8959, 1.8506, 1.8875, 1.9331, 1.8872]
# Test Accuracy: [0.55375, 0.63625, 0.64125, 0.6725, 0.63375, 0.56375, 0.7275, 0.5975, 0.565, 0.59625]
# Finished Training
# Elapsed Test Time: 23.823232173919678
# Elapsed Training Time: 85.73860311508179
# Final Test Accuracy: [0.5742, 0.6081, 0.6539, 0.6736, 0.6667, 0.5594, 0.7123, 0.5813, 0.5489, 0.5835]
# Start of Epoch 0
# Average Train Loss: [1.8628, 1.8145, 1.7975, 1.7444, 1.7519, 1.8372, 1.7175, 1.8267, 1.894, 1.8104]
# Test Accuracy: [0.53875, 0.63, 0.665, 0.6775, 0.66125, 0.58, 0.73, 0.63875, 0.55625, 0.61625]
# Start of Epoch 1
# Average Train Loss: [1.864, 1.7952, 1.7909, 1.7442, 1.7503, 1.8377, 1.7178, 1.8116, 1.893, 1.8101]
# Test Accuracy: [0.59375, 0.635, 0.635, 0.665, 0.67, 0.585, 0.6825, 0.56125, 0.53875, 0.61]
# Start of Epoch 2
# Average Train Loss: [1.8603, 1.7869, 1.7807, 1.7485, 1.7435, 1.8396, 1.7169, 1.8032, 1.892, 1.8077]
# Test Accuracy: [0.58625, 0.65375, 0.63125, 0.6425, 0.6975, 0.56, 0.7025, 0.625, 0.5225, 0.61625]
# Start of Epoch 3
# Average Train Loss: [1.8575, 1.7844, 1.7745, 1.7474, 1.7395, 1.8394, 1.7178, 1.7953, 1.8934, 1.807]
# Test Accuracy: [0.5575, 0.69875, 0.64625, 0.69125, 0.675, 0.56, 0.7175, 0.6075, 0.5775, 0.59375]
# Start of Epoch 4
# Average Train Loss: [1.8556, 1.7775, 1.7693, 1.7468, 1.7361, 1.8402, 1.7167, 1.7896, 1.8929, 1.8064]
# Test Accuracy: [0.53, 0.66125, 0.66375, 0.6225, 0.67875, 0.555, 0.70625, 0.6275, 0.5275, 0.61]
# Finished Training
# Elapsed Test Time: 7.8943772315979
# Elapsed Training Time: 16.329524040222168
# Final Test Accuracy: [0.5554, 0.6684, 0.6691, 0.6249, 0.6791, 0.5652, 0.7177, 0.6392, 0.5418, 0.6144]
# Average training time 102.11031019687653
# Average test accuracy 0.614975
# Median test accuracy 0.61965
# Standard deviation test accuracy 0.06302656483578967

# %%
fashion_test_accs_dp5 = []
fashion_training_times_dp5 = []
for i in range(4):
    m = MultipleDecoder(5, separate_encoders=False, dataset="fashionmnist")
    m.train(dp=True, epochs=15)
    m.fine_tune(epochs=5)
    fashion_test_accs_dp5.extend([x[-1] for x in m.test_accs])
    fashion_training_times_dp5.append(m.training_time)
print(f"Average training time", np.mean(fashion_training_times_dp5))
print(f"Average test accuracy", np.mean(fashion_test_accs_dp5))
print(f"Median test accuracy", np.median(fashion_test_accs_dp5))
print(f"Standard deviation test accuracy", np.std(fashion_test_accs_dp5))
# Out:
# data slice [33731, ..., 32461]
# data slice [51560, ..., 36488]
# data slice [1378, ..., 43316]
# data slice [9374, ..., 40701]
# data slice [12715, ..., 48920]
# Start of Epoch 0
# Average Train Loss: [2.1512, 2.1927, 2.1242, 2.1877, 2.0491]
# Test Accuracy: [0.395, 0.29375, 0.50875, 0.3775, 0.47875]
# Start of Epoch 1
# Average Train Loss: [2.1048, 2.153, 2.0473, 2.1314, 1.9951]
# Test Accuracy: [0.33625, 0.3175, 0.4375, 0.42375, 0.47375]
# Start of Epoch 2
# Average Train Loss: [2.0838, 2.1173, 2.0096, 2.1007, 1.9644]
# Test Accuracy: [0.43, 0.39125, 0.52375, 0.42125, 0.505]
# Start of Epoch 3
# Average Train Loss: [2.0676, 2.0757, 1.9877, 2.0834, 1.9488]
# Test Accuracy: [0.41375, 0.555, 0.50875, 0.41375, 0.545]
# Start of Epoch 4
# Average Train Loss: [2.0566, 2.0384, 1.973, 2.0689, 1.9351]
# Test Accuracy: [0.385, 0.6075, 0.51625, 0.4725, 0.59875]
# Start of Epoch 5
# Average Train Loss: [2.049, 2.0109, 1.9624, 2.0586, 1.914]
# Test Accuracy: [0.41625, 0.59125, 0.54375, 0.47875, 0.62375]
# Start of Epoch 6
# Average Train Loss: [2.0426, 1.9899, 1.954, 2.0506, 1.897]
# Test Accuracy: [0.40625, 0.575, 0.52375, 0.43125, 0.61875]
# Start of Epoch 7
# Average Train Loss: [2.0373, 1.9725, 1.9496, 2.0436, 1.8841]
# Test Accuracy: [0.43, 0.6025, 0.5125, 0.44, 0.65625]
# Start of Epoch 8
# Average Train Loss: [2.0334, 1.9583, 1.9444, 2.0376, 1.8735]
# Test Accuracy: [0.40625, 0.5875, 0.5375, 0.44875, 0.61625]
# Start of Epoch 9
# Average Train Loss: [2.0298, 1.9479, 1.9405, 2.0326, 1.8652]
# Test Accuracy: [0.4375, 0.595, 0.535, 0.43625, 0.5975]
# Start of Epoch 10
# Average Train Loss: [2.0269, 1.9374, 1.9365, 2.0256, 1.8574]
# Test Accuracy: [0.425, 0.5925, 0.55875, 0.49125, 0.6375]
# Start of Epoch 11
# Average Train Loss: [2.0172, 1.9281, 1.9333, 2.0198, 1.8482]
# Test Accuracy: [0.605, 0.56375, 0.535, 0.485, 0.63625]
# Start of Epoch 12
# Average Train Loss: [2.0046, 1.9196, 1.9306, 2.0148, 1.8417]
# Test Accuracy: [0.57, 0.59875, 0.50875, 0.53125, 0.66]
# Start of Epoch 13
# Average Train Loss: [1.9928, 1.9123, 1.9281, 2.0088, 1.8338]
# Test Accuracy: [0.57, 0.58125, 0.5525, 0.53875, 0.655]
# Start of Epoch 14
# Average Train Loss: [1.9821, 1.9052, 1.926, 2.0029, 1.8273]
# Test Accuracy: [0.595, 0.60625, 0.54, 0.53375, 0.6775]
# Finished Training
# Elapsed Test Time: 11.874844789505005
# Elapsed Training Time: 43.579657316207886
# Final Test Accuracy: [0.5974, 0.595, 0.5424, 0.5371, 0.6663]
# Start of Epoch 0
# Average Train Loss: [1.8304, 1.7924, 1.8921, 1.9197, 1.725]
# Test Accuracy: [0.6175, 0.60125, 0.51625, 0.5875, 0.6475]
# Start of Epoch 1
# Average Train Loss: [1.8296, 1.7873, 1.8945, 1.9205, 1.7248]
# Test Accuracy: [0.58, 0.61, 0.51125, 0.5175, 0.655]
# Start of Epoch 2
# Average Train Loss: [1.8279, 1.7944, 1.8935, 1.915, 1.7194]
# Test Accuracy: [0.6125, 0.61625, 0.5525, 0.50875, 0.68]
# Start of Epoch 3
# Average Train Loss: [1.8256, 1.7961, 1.8925, 1.9111, 1.7148]
# Test Accuracy: [0.59125, 0.6575, 0.5175, 0.59, 0.67875]
# Start of Epoch 4
# Average Train Loss: [1.8257, 1.795, 1.8927, 1.9065, 1.7117]
# Test Accuracy: [0.57, 0.59625, 0.53625, 0.5775, 0.64375]
# Finished Training
# Elapsed Test Time: 3.9750289916992188
# Elapsed Training Time: 8.22738265991211
# Final Test Accuracy: [0.5902, 0.6135, 0.5299, 0.5716, 0.6663]
# data slice [57465, ..., 15056]
# data slice [17035, ..., 26248]
# data slice [10806, ..., 15708]
# data slice [5320, ..., 38543]
# data slice [3591, ..., 39100]
# Start of Epoch 0
# Average Train Loss: [2.1403, 2.0961, 2.0756, 2.1182, 2.1592]
# Test Accuracy: [0.44125, 0.4725, 0.41875, 0.49, 0.34375]
# Start of Epoch 1
# Average Train Loss: [2.0873, 2.0331, 2.0373, 2.0538, 2.1264]
# Test Accuracy: [0.515, 0.51, 0.48125, 0.49875, 0.34]
# Start of Epoch 2
# Average Train Loss: [2.0367, 1.9995, 2.0201, 2.0154, 2.1141]
# Test Accuracy: [0.51, 0.50625, 0.4975, 0.5375, 0.38375]
# Start of Epoch 3
# Average Train Loss: [2.006, 1.9822, 2.0053, 1.9939, 2.0979]
# Test Accuracy: [0.5775, 0.5, 0.515, 0.5175, 0.425]
# Start of Epoch 4
# Average Train Loss: [1.9821, 1.9648, 1.9839, 1.9798, 2.0846]
# Test Accuracy: [0.58875, 0.60375, 0.52625, 0.53, 0.40625]
# Start of Epoch 5
# Average Train Loss: [1.9614, 1.9402, 1.9681, 1.9706, 2.074]
# Test Accuracy: [0.62875, 0.605, 0.55375, 0.51625, 0.395]
# Start of Epoch 6
# Average Train Loss: [1.945, 1.9167, 1.955, 1.962, 2.0665]
# Test Accuracy: [0.63375, 0.64625, 0.5725, 0.525, 0.41]
# Start of Epoch 7
# Average Train Loss: [1.9288, 1.8969, 1.9444, 1.9553, 2.0604]
# Test Accuracy: [0.67625, 0.6475, 0.57125, 0.5575, 0.4025]
# Start of Epoch 8
# Average Train Loss: [1.9143, 1.88, 1.9355, 1.9494, 2.0553]
# Test Accuracy: [0.6675, 0.65625, 0.56875, 0.53, 0.42]
# Start of Epoch 9
# Average Train Loss: [1.9006, 1.8667, 1.9291, 1.9446, 2.0503]
# Test Accuracy: [0.6625, 0.6525, 0.55625, 0.54625, 0.42875]
# Start of Epoch 10
# Average Train Loss: [1.8882, 1.8538, 1.9231, 1.9403, 2.0432]
# Test Accuracy: [0.72375, 0.64125, 0.5575, 0.52875, 0.42625]
# Start of Epoch 11
# Average Train Loss: [1.8768, 1.8434, 1.919, 1.9362, 2.0384]
# Test Accuracy: [0.69875, 0.68875, 0.55, 0.56125, 0.40875]
# Start of Epoch 12
# Average Train Loss: [1.8662, 1.8343, 1.9148, 1.9329, 2.0331]
# Test Accuracy: [0.7275, 0.66875, 0.59125, 0.5475, 0.405]
# Start of Epoch 13
# Average Train Loss: [1.8579, 1.8264, 1.9106, 1.9298, 2.0288]
# Test Accuracy: [0.69375, 0.67875, 0.57625, 0.525, 0.41]
# Start of Epoch 14
# Average Train Loss: [1.8499, 1.8192, 1.9064, 1.9274, 2.0202]
# Test Accuracy: [0.6975, 0.6875, 0.58, 0.55, 0.51625]
# Finished Training
# Elapsed Test Time: 11.875589847564697
# Elapsed Training Time: 42.730584144592285
# Final Test Accuracy: [0.7142, 0.6794, 0.583, 0.545, 0.4939]
# Start of Epoch 0
# Average Train Loss: [1.7355, 1.7141, 1.8525, 1.8896, 1.8838]
# Test Accuracy: [0.7075, 0.69125, 0.5825, 0.575, 0.51]
# Start of Epoch 1
# Average Train Loss: [1.7287, 1.7083, 1.8497, 1.8882, 1.8809]
# Test Accuracy: [0.71375, 0.68, 0.55875, 0.56125, 0.51875]
# Start of Epoch 2
# Average Train Loss: [1.7266, 1.7085, 1.8509, 1.8887, 1.8823]
# Test Accuracy: [0.69, 0.66625, 0.5925, 0.54125, 0.50875]
# Start of Epoch 3
# Average Train Loss: [1.7219, 1.7085, 1.8505, 1.8896, 1.8826]
# Test Accuracy: [0.71, 0.67625, 0.585, 0.5425, 0.47375]
# Start of Epoch 4
# Average Train Loss: [1.717, 1.7091, 1.8481, 1.8911, 1.8804]
# Test Accuracy: [0.7075, 0.6675, 0.59375, 0.55, 0.5025]
# Finished Training
# Elapsed Test Time: 3.908391237258911
# Elapsed Training Time: 8.150707483291626
# Final Test Accuracy: [0.7133, 0.6745, 0.5858, 0.5476, 0.4984]
# data slice [24118, ..., 38908]
# data slice [26535, ..., 11254]
# data slice [26518, ..., 44807]
# data slice [34452, ..., 54788]
# data slice [13902, ..., 34972]
# Start of Epoch 0
# Average Train Loss: [2.1945, 2.0612, 2.1734, 2.0915, 2.1535]
# Test Accuracy: [0.18, 0.515, 0.35125, 0.4875, 0.3625]
# Start of Epoch 1
# Average Train Loss: [2.1614, 2.0099, 2.1396, 2.0253, 2.1193]
# Test Accuracy: [0.265, 0.5525, 0.38125, 0.52625, 0.38625]
# Start of Epoch 2
# Average Train Loss: [2.1373, 1.9804, 2.1249, 1.996, 2.0879]
# Test Accuracy: [0.275, 0.5475, 0.35625, 0.54375, 0.45875]
# Start of Epoch 3
# Average Train Loss: [2.1238, 1.9563, 2.1124, 1.9767, 2.0659]
# Test Accuracy: [0.29625, 0.555, 0.42625, 0.53375, 0.46375]
# Start of Epoch 4
# Average Train Loss: [2.1142, 1.9379, 2.0981, 1.9683, 2.0516]
# Test Accuracy: [0.275, 0.59125, 0.43, 0.53125, 0.47]
# Start of Epoch 5
# Average Train Loss: [2.1074, 1.9215, 2.0852, 1.9586, 2.0399]
# Test Accuracy: [0.285, 0.64375, 0.50125, 0.5575, 0.44375]
# Start of Epoch 6
# Average Train Loss: [2.1015, 1.909, 2.0736, 1.9519, 2.0247]
# Test Accuracy: [0.2975, 0.64, 0.44875, 0.56375, 0.52625]
# Start of Epoch 7
# Average Train Loss: [2.0972, 1.8985, 2.0635, 1.9461, 2.0118]
# Test Accuracy: [0.27875, 0.63875, 0.455, 0.55, 0.5]
# Start of Epoch 8
# Average Train Loss: [2.0933, 1.8908, 2.0552, 1.9408, 2.001]
# Test Accuracy: [0.2975, 0.635, 0.49375, 0.54125, 0.5425]
# Start of Epoch 9
# Average Train Loss: [2.09, 1.8836, 2.0482, 1.9366, 1.9916]
# Test Accuracy: [0.28, 0.65, 0.50375, 0.53625, 0.53375]
# Start of Epoch 10
# Average Train Loss: [2.0874, 1.8781, 2.0415, 1.9334, 1.9835]
# Test Accuracy: [0.26375, 0.59625, 0.49375, 0.54, 0.53375]
# Start of Epoch 11
# Average Train Loss: [2.0851, 1.873, 2.0357, 1.9302, 1.9771]
# Test Accuracy: [0.255, 0.62, 0.50875, 0.53125, 0.5375]
# Start of Epoch 12
# Average Train Loss: [2.0834, 1.8685, 2.0304, 1.9276, 1.9713]
# Test Accuracy: [0.27125, 0.63375, 0.535, 0.55375, 0.54]
# Start of Epoch 13
# Average Train Loss: [2.0817, 1.864, 2.0255, 1.925, 1.9657]
# Test Accuracy: [0.25625, 0.615, 0.51375, 0.53625, 0.53625]
# Start of Epoch 14
# Average Train Loss: [2.0802, 1.8599, 2.0207, 1.9225, 1.9614]
# Test Accuracy: [0.31625, 0.6475, 0.50875, 0.505, 0.52375]
# Finished Training
# Elapsed Test Time: 11.85909390449524
# Elapsed Training Time: 42.717543840408325
# Final Test Accuracy: [0.2834, 0.6329, 0.5073, 0.5417, 0.537]
# Start of Epoch 0
# Average Train Loss: [2.0578, 1.8007, 1.9509, 1.8889, 1.9046]
# Test Accuracy: [0.2675, 0.625, 0.51375, 0.52875, 0.52125]
# Start of Epoch 1
# Average Train Loss: [2.0598, 1.804, 1.9491, 1.8898, 1.8978]
# Test Accuracy: [0.27625, 0.6, 0.51625, 0.51625, 0.56625]
# Start of Epoch 2
# Average Train Loss: [2.0599, 1.8055, 1.9455, 1.8898, 1.8874]
# Test Accuracy: [0.235, 0.65625, 0.56625, 0.55, 0.58375]
# Start of Epoch 3
# Average Train Loss: [2.0599, 1.8039, 1.9377, 1.8888, 1.8787]
# Test Accuracy: [0.26375, 0.625, 0.55375, 0.55, 0.56625]
# Start of Epoch 4
# Average Train Loss: [2.0596, 1.8027, 1.9315, 1.888, 1.8725]
# Test Accuracy: [0.29375, 0.63875, 0.535, 0.555, 0.555]
# Finished Training
# Elapsed Test Time: 3.9188883304595947
# Elapsed Training Time: 8.159927129745483
# Final Test Accuracy: [0.2818, 0.6353, 0.5634, 0.5411, 0.5915]
# data slice [4007, ..., 16736]
# data slice [20926, ..., 27759]
# data slice [24535, ..., 11161]
# data slice [590, ..., 46311]
# data slice [20523, ..., 46176]
# Start of Epoch 0
# Average Train Loss: [2.0956, 2.0824, 2.1695, 2.078, 2.1215]
# Test Accuracy: [0.48875, 0.49, 0.27125, 0.42625, 0.4275]
# Start of Epoch 1
# Average Train Loss: [2.0417, 2.0027, 2.1569, 2.041, 2.04]
# Test Accuracy: [0.455, 0.52625, 0.31875, 0.485, 0.5975]
# Start of Epoch 2
# Average Train Loss: [2.0076, 1.9713, 2.1496, 2.008, 1.992]
# Test Accuracy: [0.55375, 0.54625, 0.26625, 0.5025, 0.545]
# Start of Epoch 3
# Average Train Loss: [1.9862, 1.9489, 2.1445, 1.9888, 1.9664]
# Test Accuracy: [0.55375, 0.5625, 0.28625, 0.46625, 0.57625]
# Start of Epoch 4
# Average Train Loss: [1.9674, 1.9338, 2.1221, 1.9781, 1.9436]
# Test Accuracy: [0.5775, 0.58625, 0.46625, 0.50375, 0.5975]
# Start of Epoch 5
# Average Train Loss: [1.9503, 1.9171, 2.0883, 1.9707, 1.9291]
# Test Accuracy: [0.55125, 0.61375, 0.53, 0.5075, 0.5975]
# Start of Epoch 6
# Average Train Loss: [1.9363, 1.904, 2.0622, 1.9637, 1.9159]
# Test Accuracy: [0.5825, 0.6125, 0.54, 0.5275, 0.59875]
# Start of Epoch 7
# Average Train Loss: [1.9232, 1.8932, 2.0388, 1.9589, 1.9054]
# Test Accuracy: [0.6075, 0.6, 0.57625, 0.535, 0.57375]
# Start of Epoch 8
# Average Train Loss: [1.9107, 1.8822, 2.0157, 1.955, 1.8965]
# Test Accuracy: [0.59375, 0.685, 0.585, 0.50625, 0.6525]
# Start of Epoch 9
# Average Train Loss: [1.8994, 1.8706, 1.9962, 1.9514, 1.8892]
# Test Accuracy: [0.665, 0.6725, 0.605, 0.55375, 0.59375]
# Start of Epoch 10
# Average Train Loss: [1.8901, 1.8598, 1.9802, 1.9481, 1.8841]
# Test Accuracy: [0.66, 0.70625, 0.62, 0.54875, 0.645]
# Start of Epoch 11
# Average Train Loss: [1.8821, 1.8508, 1.9653, 1.9402, 1.8779]
# Test Accuracy: [0.63, 0.675, 0.6275, 0.635, 0.6375]
# Start of Epoch 12
# Average Train Loss: [1.874, 1.8428, 1.9522, 1.9321, 1.8728]
# Test Accuracy: [0.60875, 0.73125, 0.63, 0.61625, 0.65375]
# Start of Epoch 13
# Average Train Loss: [1.8671, 1.8364, 1.9403, 1.924, 1.868]
# Test Accuracy: [0.6, 0.69125, 0.59625, 0.59125, 0.6375]
# Start of Epoch 14
# Average Train Loss: [1.8606, 1.8295, 1.9293, 1.9171, 1.8633]
# Test Accuracy: [0.6, 0.71875, 0.62125, 0.62375, 0.65375]
# Finished Training
# Elapsed Test Time: 11.878476619720459
# Elapsed Training Time: 42.679006814956665
# Final Test Accuracy: [0.6214, 0.6943, 0.6214, 0.6142, 0.6644]
# Start of Epoch 0
# Average Train Loss: [1.7725, 1.7363, 1.7654, 1.8217, 1.7746]
# Test Accuracy: [0.65625, 0.6975, 0.62125, 0.66, 0.65625]
# Start of Epoch 1
# Average Train Loss: [1.7642, 1.739, 1.7678, 1.8163, 1.7685]
# Test Accuracy: [0.64, 0.7125, 0.66, 0.59125, 0.63125]
# Start of Epoch 2
# Average Train Loss: [1.7573, 1.7358, 1.7673, 1.8055, 1.7658]
# Test Accuracy: [0.65625, 0.71, 0.6125, 0.6875, 0.65875]
# Start of Epoch 3
# Average Train Loss: [1.7536, 1.7305, 1.7664, 1.7882, 1.7634]
# Test Accuracy: [0.655, 0.70375, 0.685, 0.6925, 0.635]
# Start of Epoch 4
# Average Train Loss: [1.7496, 1.7258, 1.7602, 1.7782, 1.7618]
# Test Accuracy: [0.6825, 0.725, 0.72625, 0.69, 0.6825]
# Finished Training
# Elapsed Test Time: 3.926605463027954
# Elapsed Training Time: 8.160513877868652
# Final Test Accuracy: [0.6489, 0.7122, 0.7005, 0.686, 0.6517]
# Average training time 51.10133081674576
# Average test accuracy 0.6001749999999999
# Median test accuracy 0.6025
# Standard deviation test accuracy 0.09606731429055358

# %%
fashion_test_accs_dp2 = []
fashion_training_times_dp2 = []
for i in range(10):
    m = MultipleDecoder(2, separate_encoders=False, dataset="fashionmnist")
    m.train(dp=True, epochs=10)
    m.fine_tune(epochs=10)
    fashion_test_accs_dp2.extend([x[-1] for x in m.test_accs])
    fashion_training_times_dp2.append(m.training_time)
print(f"Average training time", np.mean(fashion_training_times_dp2))
print(f"Average test accuracy", np.mean(fashion_test_accs_dp2))
print(f"Median test accuracy", np.median(fashion_test_accs_dp2))
print(f"Standard deviation test accuracy", np.std(fashion_test_accs_dp2))
# Out:
# data slice [50038, ..., 55242]
# data slice [16154, ..., 30514]
# Start of Epoch 0
# Average Train Loss: [2.0735, 2.1326]
# Test Accuracy: [0.3425, 0.3825]
# Start of Epoch 1
# Average Train Loss: [2.0239, 2.0757]
# Test Accuracy: [0.4875, 0.4825]
# Start of Epoch 2
# Average Train Loss: [1.9786, 2.0388]
# Test Accuracy: [0.635, 0.525]
# Start of Epoch 3
# Average Train Loss: [1.9463, 2.016]
# Test Accuracy: [0.61375, 0.495]
# Start of Epoch 4
# Average Train Loss: [1.924, 2.001]
# Test Accuracy: [0.62875, 0.51875]
# Start of Epoch 5
# Average Train Loss: [1.9088, 1.989]
# Test Accuracy: [0.59875, 0.4925]
# Start of Epoch 6
# Average Train Loss: [1.8966, 1.9763]
# Test Accuracy: [0.6725, 0.5075]
# Start of Epoch 7
# Average Train Loss: [1.8865, 1.9671]
# Test Accuracy: [0.62375, 0.54]
# Start of Epoch 8
# Average Train Loss: [1.8781, 1.9585]
# Test Accuracy: [0.64125, 0.51625]
# Start of Epoch 9
# Average Train Loss: [1.8707, 1.9507]
# Test Accuracy: [0.6325, 0.60125]
# Finished Training
# Elapsed Test Time: 3.166701316833496
# Elapsed Training Time: 11.383253574371338
# Final Test Accuracy: [0.6472, 0.5751]
# Start of Epoch 0
# Average Train Loss: [1.7936, 1.8168]
# Test Accuracy: [0.625, 0.63875]
# Start of Epoch 1
# Average Train Loss: [1.7911, 1.81]
# Test Accuracy: [0.675, 0.62625]
# Start of Epoch 2
# Average Train Loss: [1.7912, 1.801]
# Test Accuracy: [0.645, 0.61125]
# Start of Epoch 3
# Average Train Loss: [1.7902, 1.798]
# Test Accuracy: [0.635, 0.61125]
# Start of Epoch 4
# Average Train Loss: [1.7891, 1.7959]
# Test Accuracy: [0.66375, 0.65875]
# Start of Epoch 5
# Average Train Loss: [1.7873, 1.7947]
# Test Accuracy: [0.65125, 0.6125]
# Start of Epoch 6
# Average Train Loss: [1.7855, 1.7914]
# Test Accuracy: [0.64625, 0.62125]
# Start of Epoch 7
# Average Train Loss: [1.785, 1.7888]
# Test Accuracy: [0.67625, 0.63125]
# Start of Epoch 8
# Average Train Loss: [1.7834, 1.7856]
# Test Accuracy: [0.64625, 0.63375]
# Start of Epoch 9
# Average Train Loss: [1.7826, 1.783]
# Test Accuracy: [0.6375, 0.65625]
# Finished Training
# Elapsed Test Time: 3.14608097076416
# Elapsed Training Time: 6.543086528778076
# Final Test Accuracy: [0.6509, 0.6448]
# data slice [41900, ..., 23876]
# data slice [12780, ..., 12205]
# Start of Epoch 0
# Average Train Loss: [2.1121, 2.1039]
# Test Accuracy: [0.38625, 0.39125]
# Start of Epoch 1
# Average Train Loss: [2.0701, 2.0715]
# Test Accuracy: [0.42375, 0.42875]
# Start of Epoch 2
# Average Train Loss: [2.0536, 2.0419]
# Test Accuracy: [0.4225, 0.46125]
# Start of Epoch 3
# Average Train Loss: [2.044, 2.0238]
# Test Accuracy: [0.41625, 0.4175]
# Start of Epoch 4
# Average Train Loss: [2.0389, 2.0116]
# Test Accuracy: [0.41625, 0.4875]
# Start of Epoch 5
# Average Train Loss: [2.0347, 2.0029]
# Test Accuracy: [0.3975, 0.4725]
# Start of Epoch 6
# Average Train Loss: [2.0318, 1.9959]
# Test Accuracy: [0.40875, 0.46625]
# Start of Epoch 7
# Average Train Loss: [2.0299, 1.9913]
# Test Accuracy: [0.37125, 0.5]
# Start of Epoch 8
# Average Train Loss: [2.0268, 1.9836]
# Test Accuracy: [0.42625, 0.51875]
# Start of Epoch 9
# Average Train Loss: [2.024, 1.9759]
# Test Accuracy: [0.44375, 0.51375]
# Finished Training
# Elapsed Test Time: 3.171909809112549
# Elapsed Training Time: 11.413291454315186
# Final Test Accuracy: [0.4529, 0.5312]
# Start of Epoch 0
# Average Train Loss: [1.9706, 1.8725]
# Test Accuracy: [0.47, 0.60875]
# Start of Epoch 1
# Average Train Loss: [1.9643, 1.8231]
# Test Accuracy: [0.5225, 0.6325]
# Start of Epoch 2
# Average Train Loss: [1.9554, 1.8022]
# Test Accuracy: [0.53375, 0.67375]
# Start of Epoch 3
# Average Train Loss: [1.941, 1.7861]
# Test Accuracy: [0.525, 0.6975]
# Start of Epoch 4
# Average Train Loss: [1.9279, 1.7745]
# Test Accuracy: [0.56125, 0.68]
# Start of Epoch 5
# Average Train Loss: [1.9178, 1.7655]
# Test Accuracy: [0.54625, 0.7]
# Start of Epoch 6
# Average Train Loss: [1.9098, 1.7587]
# Test Accuracy: [0.54625, 0.71875]
# Start of Epoch 7
# Average Train Loss: [1.9018, 1.7525]
# Test Accuracy: [0.535, 0.6825]
# Start of Epoch 8
# Average Train Loss: [1.8958, 1.7479]
# Test Accuracy: [0.56375, 0.6875]
# Start of Epoch 9
# Average Train Loss: [1.8908, 1.7444]
# Test Accuracy: [0.57625, 0.6875]
# Finished Training
# Elapsed Test Time: 3.136599063873291
# Elapsed Training Time: 6.53810715675354
# Final Test Accuracy: [0.5578, 0.6996]
# data slice [42557, ..., 36913]
# data slice [14195, ..., 57501]
# Start of Epoch 0
# Average Train Loss: [2.1661, 2.1455]
# Test Accuracy: [0.40875, 0.35875]
# Start of Epoch 1
# Average Train Loss: [2.0654, 2.1133]
# Test Accuracy: [0.54875, 0.395]
# Start of Epoch 2
# Average Train Loss: [2.0131, 2.0806]
# Test Accuracy: [0.58875, 0.43375]
# Start of Epoch 3
# Average Train Loss: [1.976, 2.0585]
# Test Accuracy: [0.58375, 0.4325]
# Start of Epoch 4
# Average Train Loss: [1.9475, 2.0432]
# Test Accuracy: [0.62125, 0.445]
# Start of Epoch 5
# Average Train Loss: [1.928, 2.0282]
# Test Accuracy: [0.63, 0.5325]
# Start of Epoch 6
# Average Train Loss: [1.912, 2.0093]
# Test Accuracy: [0.5925, 0.53875]
# Start of Epoch 7
# Average Train Loss: [1.9012, 1.9844]
# Test Accuracy: [0.6225, 0.67]
# Start of Epoch 8
# Average Train Loss: [1.8913, 1.9596]
# Test Accuracy: [0.62, 0.6725]
# Start of Epoch 9
# Average Train Loss: [1.8827, 1.938]
# Test Accuracy: [0.61625, 0.69375]
# Finished Training
# Elapsed Test Time: 3.1477463245391846
# Elapsed Training Time: 11.372649669647217
# Final Test Accuracy: [0.6258, 0.6886]
# Start of Epoch 0
# Average Train Loss: [1.8005, 1.7218]
# Test Accuracy: [0.60625, 0.73375]
# Start of Epoch 1
# Average Train Loss: [1.8009, 1.7053]
# Test Accuracy: [0.595, 0.7175]
# Start of Epoch 2
# Average Train Loss: [1.7996, 1.7021]
# Test Accuracy: [0.64125, 0.725]
# Start of Epoch 3
# Average Train Loss: [1.7968, 1.6928]
# Test Accuracy: [0.625, 0.70375]
# Start of Epoch 4
# Average Train Loss: [1.795, 1.6866]
# Test Accuracy: [0.65625, 0.74]
# Start of Epoch 5
# Average Train Loss: [1.7914, 1.6802]
# Test Accuracy: [0.6425, 0.72625]
# Start of Epoch 6
# Average Train Loss: [1.7901, 1.6752]
# Test Accuracy: [0.63875, 0.72375]
# Start of Epoch 7
# Average Train Loss: [1.7873, 1.6708]
# Test Accuracy: [0.6675, 0.7225]
# Start of Epoch 8
# Average Train Loss: [1.7854, 1.667]
# Test Accuracy: [0.65625, 0.74625]
# Start of Epoch 9
# Average Train Loss: [1.7835, 1.6636]
# Test Accuracy: [0.62625, 0.7225]
# Finished Training
# Elapsed Test Time: 3.1587507724761963
# Elapsed Training Time: 6.570533752441406
# Final Test Accuracy: [0.6282, 0.7296]
# data slice [4138, ..., 9448]
# data slice [29102, ..., 2347]
# Start of Epoch 0
# Average Train Loss: [2.1776, 2.0772]
# Test Accuracy: [0.3975, 0.58125]
# Start of Epoch 1
# Average Train Loss: [2.1135, 1.9855]
# Test Accuracy: [0.455, 0.6025]
# Start of Epoch 2
# Average Train Loss: [2.0693, 1.9462]
# Test Accuracy: [0.51, 0.615]
# Start of Epoch 3
# Average Train Loss: [2.0351, 1.9252]
# Test Accuracy: [0.52875, 0.6175]
# Start of Epoch 4
# Average Train Loss: [2.0089, 1.9083]
# Test Accuracy: [0.62625, 0.6225]
# Start of Epoch 5
# Average Train Loss: [1.9809, 1.8974]
# Test Accuracy: [0.615, 0.61875]
# Start of Epoch 6
# Average Train Loss: [1.9593, 1.8887]
# Test Accuracy: [0.6075, 0.62625]
# Start of Epoch 7
# Average Train Loss: [1.9424, 1.8815]
# Test Accuracy: [0.61, 0.61125]
# Start of Epoch 8
# Average Train Loss: [1.9249, 1.8758]
# Test Accuracy: [0.71375, 0.62875]
# Start of Epoch 9
# Average Train Loss: [1.907, 1.8703]
# Test Accuracy: [0.72875, 0.63125]
# Finished Training
# Elapsed Test Time: 3.162416696548462
# Elapsed Training Time: 11.397807359695435
# Final Test Accuracy: [0.7006, 0.6322]
# Start of Epoch 0
# Average Train Loss: [1.7324, 1.8146]
# Test Accuracy: [0.72125, 0.65375]
# Start of Epoch 1
# Average Train Loss: [1.7257, 1.8118]
# Test Accuracy: [0.7225, 0.59875]
# Start of Epoch 2
# Average Train Loss: [1.7261, 1.8116]
# Test Accuracy: [0.7, 0.6]
# Start of Epoch 3
# Average Train Loss: [1.725, 1.8102]
# Test Accuracy: [0.71875, 0.63375]
# Start of Epoch 4
# Average Train Loss: [1.7226, 1.8088]
# Test Accuracy: [0.7, 0.67375]
# Start of Epoch 5
# Average Train Loss: [1.7203, 1.8057]
# Test Accuracy: [0.72875, 0.65375]
# Start of Epoch 6
# Average Train Loss: [1.7186, 1.7997]
# Test Accuracy: [0.74125, 0.67625]
# Start of Epoch 7
# Average Train Loss: [1.718, 1.797]
# Test Accuracy: [0.72375, 0.6125]
# Start of Epoch 8
# Average Train Loss: [1.7162, 1.7931]
# Test Accuracy: [0.7275, 0.66625]
# Start of Epoch 9
# Average Train Loss: [1.7148, 1.7876]
# Test Accuracy: [0.7325, 0.6825]
# Finished Training
# Elapsed Test Time: 3.159214973449707
# Elapsed Training Time: 6.5690155029296875
# Final Test Accuracy: [0.7224, 0.6825]
# data slice [41836, ..., 55109]
# data slice [27139, ..., 56366]
# Start of Epoch 0
# Average Train Loss: [2.1308, 2.1571]
# Test Accuracy: [0.39375, 0.37]
# Start of Epoch 1
# Average Train Loss: [2.0851, 2.1008]
# Test Accuracy: [0.40375, 0.48625]
# Start of Epoch 2
# Average Train Loss: [2.0632, 2.0642]
# Test Accuracy: [0.395, 0.5125]
# Start of Epoch 3
# Average Train Loss: [2.0479, 2.0361]
# Test Accuracy: [0.43625, 0.55875]
# Start of Epoch 4
# Average Train Loss: [2.0365, 2.0095]
# Test Accuracy: [0.41875, 0.59625]
# Start of Epoch 5
# Average Train Loss: [2.0297, 1.9903]
# Test Accuracy: [0.4225, 0.6025]
# Start of Epoch 6
# Average Train Loss: [2.024, 1.9768]
# Test Accuracy: [0.44375, 0.61375]
# Start of Epoch 7
# Average Train Loss: [2.0192, 1.966]
# Test Accuracy: [0.43, 0.60875]
# Start of Epoch 8
# Average Train Loss: [2.0148, 1.9562]
# Test Accuracy: [0.4, 0.5575]
# Start of Epoch 9
# Average Train Loss: [2.0118, 1.9481]
# Test Accuracy: [0.44375, 0.6075]
# Finished Training
# Elapsed Test Time: 3.157956838607788
# Elapsed Training Time: 11.393393278121948
# Final Test Accuracy: [0.4212, 0.6199]
# Start of Epoch 0
# Average Train Loss: [1.9789, 1.8704]
# Test Accuracy: [0.4125, 0.63375]
# Start of Epoch 1
# Average Train Loss: [1.98, 1.8699]
# Test Accuracy: [0.4325, 0.5675]
# Start of Epoch 2
# Average Train Loss: [1.9779, 1.8697]
# Test Accuracy: [0.41125, 0.6225]
# Start of Epoch 3
# Average Train Loss: [1.9769, 1.8706]
# Test Accuracy: [0.45, 0.605]
# Start of Epoch 4
# Average Train Loss: [1.976, 1.8697]
# Test Accuracy: [0.395, 0.61625]
# Start of Epoch 5
# Average Train Loss: [1.9737, 1.869]
# Test Accuracy: [0.42125, 0.62375]
# Start of Epoch 6
# Average Train Loss: [1.9726, 1.8676]
# Test Accuracy: [0.44875, 0.64]
# Start of Epoch 7
# Average Train Loss: [1.9713, 1.8665]
# Test Accuracy: [0.42, 0.6425]
# Start of Epoch 8
# Average Train Loss: [1.9701, 1.8658]
# Test Accuracy: [0.45, 0.63125]
# Start of Epoch 9
# Average Train Loss: [1.9688, 1.8648]
# Test Accuracy: [0.4325, 0.61375]
# Finished Training
# Elapsed Test Time: 3.136526107788086
# Elapsed Training Time: 6.5382080078125
# Final Test Accuracy: [0.4236, 0.6234]
# data slice [23603, ..., 46645]
# data slice [55232, ..., 37446]
# Start of Epoch 0
# Average Train Loss: [2.1403, 2.1212]
# Test Accuracy: [0.37625, 0.36125]
# Start of Epoch 1
# Average Train Loss: [2.115, 2.0735]
# Test Accuracy: [0.33875, 0.39875]
# Start of Epoch 2
# Average Train Loss: [2.0981, 2.0449]
# Test Accuracy: [0.37, 0.46875]
# Start of Epoch 3
# Average Train Loss: [2.0623, 2.0073]
# Test Accuracy: [0.5475, 0.60875]
# Start of Epoch 4
# Average Train Loss: [2.03, 1.9786]
# Test Accuracy: [0.555, 0.6275]
# Start of Epoch 5
# Average Train Loss: [2.0053, 1.9565]
# Test Accuracy: [0.58, 0.63125]
# Start of Epoch 6
# Average Train Loss: [1.9883, 1.939]
# Test Accuracy: [0.51625, 0.585]
# Start of Epoch 7
# Average Train Loss: [1.975, 1.9263]
# Test Accuracy: [0.55375, 0.59125]
# Start of Epoch 8
# Average Train Loss: [1.9627, 1.9148]
# Test Accuracy: [0.545, 0.60875]
# Start of Epoch 9
# Average Train Loss: [1.9545, 1.9048]
# Test Accuracy: [0.525, 0.6]
# Finished Training
# Elapsed Test Time: 3.1484079360961914
# Elapsed Training Time: 11.345571756362915
# Final Test Accuracy: [0.5216, 0.6053]
# Start of Epoch 0
# Average Train Loss: [1.8448, 1.7878]
# Test Accuracy: [0.5975, 0.66]
# Start of Epoch 1
# Average Train Loss: [1.8239, 1.7547]
# Test Accuracy: [0.63375, 0.72875]
# Start of Epoch 2
# Average Train Loss: [1.8052, 1.7352]
# Test Accuracy: [0.61875, 0.705]
# Start of Epoch 3
# Average Train Loss: [1.7958, 1.7192]
# Test Accuracy: [0.64625, 0.72]
# Start of Epoch 4
# Average Train Loss: [1.7894, 1.7088]
# Test Accuracy: [0.65, 0.71]
# Start of Epoch 5
# Average Train Loss: [1.7832, 1.7015]
# Test Accuracy: [0.65, 0.69125]
# Start of Epoch 6
# Average Train Loss: [1.7782, 1.6972]
# Test Accuracy: [0.65, 0.72875]
# Start of Epoch 7
# Average Train Loss: [1.7741, 1.6949]
# Test Accuracy: [0.655, 0.7475]
# Start of Epoch 8
# Average Train Loss: [1.7716, 1.6908]
# Test Accuracy: [0.62875, 0.70375]
# Start of Epoch 9
# Average Train Loss: [1.7688, 1.6874]
# Test Accuracy: [0.6475, 0.745]
# Finished Training
# Elapsed Test Time: 3.1562118530273438
# Elapsed Training Time: 6.574646711349487
# Final Test Accuracy: [0.6574, 0.7339]
# data slice [31788, ..., 20705]
# data slice [56153, ..., 38149]
# Start of Epoch 0
# Average Train Loss: [2.163, 2.137]
# Test Accuracy: [0.4125, 0.4175]
# Start of Epoch 1
# Average Train Loss: [2.0915, 2.0577]
# Test Accuracy: [0.52, 0.4875]
# Start of Epoch 2
# Average Train Loss: [2.0361, 2.0123]
# Test Accuracy: [0.54125, 0.5375]
# Start of Epoch 3
# Average Train Loss: [2.0055, 1.9844]
# Test Accuracy: [0.53875, 0.52625]
# Start of Epoch 4
# Average Train Loss: [1.9865, 1.969]
# Test Accuracy: [0.54625, 0.53]
# Start of Epoch 5
# Average Train Loss: [1.9729, 1.9563]
# Test Accuracy: [0.5325, 0.55625]
# Start of Epoch 6
# Average Train Loss: [1.9621, 1.9464]
# Test Accuracy: [0.52875, 0.53875]
# Start of Epoch 7
# Average Train Loss: [1.9549, 1.9389]
# Test Accuracy: [0.5375, 0.555]
# Start of Epoch 8
# Average Train Loss: [1.9477, 1.9324]
# Test Accuracy: [0.52625, 0.5375]
# Start of Epoch 9
# Average Train Loss: [1.9421, 1.9268]
# Test Accuracy: [0.55125, 0.57375]
# Finished Training
# Elapsed Test Time: 3.164274215698242
# Elapsed Training Time: 11.397415161132812
# Final Test Accuracy: [0.5419, 0.5407]
# Start of Epoch 0
# Average Train Loss: [1.886, 1.8854]
# Test Accuracy: [0.565, 0.545]
# Start of Epoch 1
# Average Train Loss: [1.8829, 1.8796]
# Test Accuracy: [0.55125, 0.5325]
# Start of Epoch 2
# Average Train Loss: [1.8814, 1.8781]
# Test Accuracy: [0.5625, 0.55625]
# Start of Epoch 3
# Average Train Loss: [1.8797, 1.8756]
# Test Accuracy: [0.54875, 0.52875]
# Start of Epoch 4
# Average Train Loss: [1.8779, 1.8747]
# Test Accuracy: [0.5575, 0.56375]
# Start of Epoch 5
# Average Train Loss: [1.876, 1.8752]
# Test Accuracy: [0.56375, 0.52125]
# Start of Epoch 6
# Average Train Loss: [1.8738, 1.8741]
# Test Accuracy: [0.64, 0.57875]
# Start of Epoch 7
# Average Train Loss: [1.8658, 1.8731]
# Test Accuracy: [0.65125, 0.5275]
# Start of Epoch 8
# Average Train Loss: [1.8582, 1.8723]
# Test Accuracy: [0.63875, 0.54625]
# Start of Epoch 9
# Average Train Loss: [1.8515, 1.8715]
# Test Accuracy: [0.63875, 0.54625]
# Finished Training
# Elapsed Test Time: 3.139925241470337
# Elapsed Training Time: 6.537336349487305
# Final Test Accuracy: [0.6338, 0.5477]
# data slice [28000, ..., 50788]
# data slice [21521, ..., 34146]
# Start of Epoch 0
# Average Train Loss: [2.1807, 2.1474]
# Test Accuracy: [0.33375, 0.43125]
# Start of Epoch 1
# Average Train Loss: [2.1115, 2.0675]
# Test Accuracy: [0.4275, 0.515]
# Start of Epoch 2
# Average Train Loss: [2.0738, 2.0288]
# Test Accuracy: [0.44625, 0.50875]
# Start of Epoch 3
# Average Train Loss: [2.05, 1.9985]
# Test Accuracy: [0.44375, 0.54875]
# Start of Epoch 4
# Average Train Loss: [2.0343, 1.9666]
# Test Accuracy: [0.4975, 0.61375]
# Start of Epoch 5
# Average Train Loss: [2.0165, 1.9437]
# Test Accuracy: [0.51375, 0.5925]
# Start of Epoch 6
# Average Train Loss: [2.002, 1.9282]
# Test Accuracy: [0.515, 0.53375]
# Start of Epoch 7
# Average Train Loss: [1.9895, 1.9144]
# Test Accuracy: [0.52, 0.6]
# Start of Epoch 8
# Average Train Loss: [1.9793, 1.9034]
# Test Accuracy: [0.525, 0.63625]
# Start of Epoch 9
# Average Train Loss: [1.9706, 1.8933]
# Test Accuracy: [0.53125, 0.615]
# Finished Training
# Elapsed Test Time: 3.1473402976989746
# Elapsed Training Time: 11.37572693824768
# Final Test Accuracy: [0.5241, 0.603]
# Start of Epoch 0
# Average Train Loss: [1.8782, 1.8027]
# Test Accuracy: [0.5375, 0.63375]
# Start of Epoch 1
# Average Train Loss: [1.8783, 1.799]
# Test Accuracy: [0.5075, 0.63]
# Start of Epoch 2
# Average Train Loss: [1.8786, 1.7961]
# Test Accuracy: [0.52875, 0.6225]
# Start of Epoch 3
# Average Train Loss: [1.8776, 1.7945]
# Test Accuracy: [0.535, 0.625]
# Start of Epoch 4
# Average Train Loss: [1.876, 1.7939]
# Test Accuracy: [0.5325, 0.645]
# Start of Epoch 5
# Average Train Loss: [1.8741, 1.7932]
# Test Accuracy: [0.555, 0.6425]
# Start of Epoch 6
# Average Train Loss: [1.873, 1.7914]
# Test Accuracy: [0.53375, 0.63875]
# Start of Epoch 7
# Average Train Loss: [1.8721, 1.7904]
# Test Accuracy: [0.5225, 0.64375]
# Start of Epoch 8
# Average Train Loss: [1.8702, 1.7904]
# Test Accuracy: [0.535, 0.59]
# Start of Epoch 9
# Average Train Loss: [1.8683, 1.7908]
# Test Accuracy: [0.51625, 0.59375]
# Finished Training
# Elapsed Test Time: 3.142749309539795
# Elapsed Training Time: 6.533517360687256
# Final Test Accuracy: [0.5345, 0.6011]
# data slice [24528, ..., 54309]
# data slice [17624, ..., 52656]
# Start of Epoch 0
# Average Train Loss: [2.1541, 2.1367]
# Test Accuracy: [0.34125, 0.3325]
# Start of Epoch 1
# Average Train Loss: [2.0674, 2.0895]
# Test Accuracy: [0.4675, 0.4425]
# Start of Epoch 2
# Average Train Loss: [2.0154, 2.0668]
# Test Accuracy: [0.53875, 0.45125]
# Start of Epoch 3
# Average Train Loss: [1.9832, 2.0515]
# Test Accuracy: [0.59375, 0.4225]
# Start of Epoch 4
# Average Train Loss: [1.9595, 2.0405]
# Test Accuracy: [0.58625, 0.445]
# Start of Epoch 5
# Average Train Loss: [1.9428, 2.0276]
# Test Accuracy: [0.62125, 0.51625]
# Start of Epoch 6
# Average Train Loss: [1.9298, 2.0135]
# Test Accuracy: [0.59125, 0.56125]
# Start of Epoch 7
# Average Train Loss: [1.9173, 1.9973]
# Test Accuracy: [0.595, 0.605]
# Start of Epoch 8
# Average Train Loss: [1.9071, 1.9826]
# Test Accuracy: [0.59625, 0.59375]
# Start of Epoch 9
# Average Train Loss: [1.8983, 1.9703]
# Test Accuracy: [0.59875, 0.54625]
# Finished Training
# Elapsed Test Time: 3.1514856815338135
# Elapsed Training Time: 11.344313621520996
# Final Test Accuracy: [0.6211, 0.5539]
# Start of Epoch 0
# Average Train Loss: [1.818, 1.8484]
# Test Accuracy: [0.615, 0.56625]
# Start of Epoch 1
# Average Train Loss: [1.8153, 1.8434]
# Test Accuracy: [0.5875, 0.62875]
# Start of Epoch 2
# Average Train Loss: [1.8145, 1.8393]
# Test Accuracy: [0.60875, 0.565]
# Start of Epoch 3
# Average Train Loss: [1.8125, 1.8365]
# Test Accuracy: [0.65625, 0.5675]
# Start of Epoch 4
# Average Train Loss: [1.8107, 1.8327]
# Test Accuracy: [0.59875, 0.56625]
# Start of Epoch 5
# Average Train Loss: [1.8094, 1.8322]
# Test Accuracy: [0.62125, 0.5975]
# Start of Epoch 6
# Average Train Loss: [1.8081, 1.83]
# Test Accuracy: [0.60625, 0.5925]
# Start of Epoch 7
# Average Train Loss: [1.8084, 1.8276]
# Test Accuracy: [0.60375, 0.58875]
# Start of Epoch 8
# Average Train Loss: [1.8078, 1.8264]
# Test Accuracy: [0.605, 0.6]
# Start of Epoch 9
# Average Train Loss: [1.8076, 1.8255]
# Test Accuracy: [0.63875, 0.60625]
# Finished Training
# Elapsed Test Time: 3.168653964996338
# Elapsed Training Time: 6.523680210113525
# Final Test Accuracy: [0.6149, 0.5912]
# data slice [3800, ..., 41842]
# data slice [22629, ..., 22518]
# Start of Epoch 0
# Average Train Loss: [2.2077, 2.0987]
# Test Accuracy: [0.28625, 0.47375]
# Start of Epoch 1
# Average Train Loss: [2.193, 2.0221]
# Test Accuracy: [0.30625, 0.515]
# Start of Epoch 2
# Average Train Loss: [2.1869, 1.9852]
# Test Accuracy: [0.2775, 0.51625]
# Start of Epoch 3
# Average Train Loss: [2.1817, 1.9608]
# Test Accuracy: [0.27625, 0.56125]
# Start of Epoch 4
# Average Train Loss: [2.16, 1.9395]
# Test Accuracy: [0.47375, 0.5575]
# Start of Epoch 5
# Average Train Loss: [2.1245, 1.9233]
# Test Accuracy: [0.525, 0.57125]
# Start of Epoch 6
# Average Train Loss: [2.0933, 1.9123]
# Test Accuracy: [0.54625, 0.57625]
# Start of Epoch 7
# Average Train Loss: [2.0659, 1.9024]
# Test Accuracy: [0.56125, 0.56875]
# Start of Epoch 8
# Average Train Loss: [2.0422, 1.896]
# Test Accuracy: [0.57, 0.58]
# Start of Epoch 9
# Average Train Loss: [2.0226, 1.889]
# Test Accuracy: [0.60875, 0.55375]
# Finished Training
# Elapsed Test Time: 3.1469662189483643
# Elapsed Training Time: 11.33689546585083
# Final Test Accuracy: [0.598, 0.5752]
# Start of Epoch 0
# Average Train Loss: [1.8453, 1.831]
# Test Accuracy: [0.61625, 0.61125]
# Start of Epoch 1
# Average Train Loss: [1.8235, 1.8258]
# Test Accuracy: [0.63125, 0.57]
# Start of Epoch 2
# Average Train Loss: [1.8055, 1.8213]
# Test Accuracy: [0.67625, 0.5725]
# Start of Epoch 3
# Average Train Loss: [1.7952, 1.8209]
# Test Accuracy: [0.67125, 0.60375]
# Start of Epoch 4
# Average Train Loss: [1.7875, 1.8182]
# Test Accuracy: [0.62625, 0.56875]
# Start of Epoch 5
# Average Train Loss: [1.7802, 1.8181]
# Test Accuracy: [0.64125, 0.57125]
# Start of Epoch 6
# Average Train Loss: [1.7742, 1.8176]
# Test Accuracy: [0.65, 0.61375]
# Start of Epoch 7
# Average Train Loss: [1.7673, 1.8162]
# Test Accuracy: [0.65125, 0.605]
# Start of Epoch 8
# Average Train Loss: [1.7631, 1.815]
# Test Accuracy: [0.66125, 0.58875]
# Start of Epoch 9
# Average Train Loss: [1.7591, 1.814]
# Test Accuracy: [0.67375, 0.5875]
# Finished Training
# Elapsed Test Time: 3.1460461616516113
# Elapsed Training Time: 6.518884658813477
# Final Test Accuracy: [0.6788, 0.5964]
# Average training time 17.92073345184326
# Average test accuracy 0.6276250000000001
# Median test accuracy 0.631
# Standard deviation test accuracy 0.07348298357443035

# %%
fashion_test_accs_dp10_same = []
fashion_training_times_dp10_same = []
for i in range(2):
    m = MultipleDecoder(10, separate_encoders=False, dataset="fashionmnist", same_decoder_init=True)
    m.train(dp=True, epochs=15)
    m.fine_tune(epochs=5)
    fashion_test_accs_dp10_same.extend([x[-1] for x in m.test_accs])
    fashion_training_times_dp10_same.append(m.training_time)
print(f"Average training time", np.mean(fashion_training_times_dp10_same))
print(f"Average test accuracy", np.mean(fashion_test_accs_dp10_same))
print(f"Median test accuracy", np.median(fashion_test_accs_dp10_same))
print(f"Standard deviation test accuracy", np.std(fashion_test_accs_dp10_same))
# Out:
# data slice [43432, ..., 24959]
# data slice [33567, ..., 7406]
# data slice [58272, ..., 2226]
# data slice [25471, ..., 39206]
# data slice [16835, ..., 9715]
# data slice [2042, ..., 42968]
# data slice [7904, ..., 34047]
# data slice [13484, ..., 2886]
# data slice [21330, ..., 8317]
# data slice [29160, ..., 35670]
# Start of Epoch 0
# Average Train Loss: [2.0855, 2.2079, 2.1509, 2.0917, 2.1869, 2.121, 2.1748, 2.1884, 2.1953, 2.1361]
# Test Accuracy: [0.44875, 0.37, 0.31875, 0.455, 0.38125, 0.35875, 0.315, 0.33125, 0.33875, 0.3575]
# Start of Epoch 1
# Average Train Loss: [2.045, 2.1494, 2.1129, 2.041, 2.1331, 2.0599, 2.1258, 2.0929, 2.1233, 2.0939]
# Test Accuracy: [0.44375, 0.36625, 0.33875, 0.46625, 0.385, 0.46875, 0.39625, 0.54375, 0.415, 0.43375]
# Start of Epoch 2
# Average Train Loss: [2.0286, 2.127, 2.0969, 2.0111, 2.1059, 2.025, 2.0997, 2.0392, 2.0786, 2.048]
# Test Accuracy: [0.43375, 0.40375, 0.37, 0.51125, 0.39125, 0.50375, 0.375, 0.535, 0.54125, 0.53875]
# Start of Epoch 3
# Average Train Loss: [2.0185, 2.1109, 2.0872, 1.994, 2.064, 2.0061, 2.0848, 2.008, 2.0423, 2.0212]
# Test Accuracy: [0.48, 0.425, 0.3625, 0.525, 0.52875, 0.45875, 0.39625, 0.555, 0.50375, 0.5225]
# Start of Epoch 4
# Average Train Loss: [2.0119, 2.0863, 2.0812, 1.9805, 2.0288, 1.9928, 2.0749, 1.9875, 2.0197, 2.0029]
# Test Accuracy: [0.45, 0.4525, 0.3975, 0.51625, 0.56625, 0.485, 0.375, 0.52375, 0.50875, 0.525]
# Start of Epoch 5
# Average Train Loss: [2.0084, 2.0696, 2.0764, 1.9706, 2.001, 1.9846, 2.0679, 1.9721, 2.003, 1.9904]
# Test Accuracy: [0.46125, 0.4925, 0.37875, 0.56375, 0.5975, 0.495, 0.37875, 0.56625, 0.51375, 0.52]
# Start of Epoch 6
# Average Train Loss: [2.0045, 2.0564, 2.0738, 1.9533, 1.9791, 1.9782, 2.0619, 1.9618, 1.9879, 1.9799]
# Test Accuracy: [0.4725, 0.4375, 0.37375, 0.66875, 0.59375, 0.52375, 0.38375, 0.57125, 0.58, 0.53875]
# Start of Epoch 7
# Average Train Loss: [1.9995, 2.0476, 2.0708, 1.9347, 1.962, 1.9713, 2.0572, 1.9531, 1.9726, 1.9659]
# Test Accuracy: [0.48, 0.44375, 0.3725, 0.65, 0.63125, 0.51875, 0.41125, 0.58375, 0.59, 0.5725]
# Start of Epoch 8
# Average Train Loss: [1.9946, 2.0399, 2.0682, 1.9203, 1.9489, 1.9657, 2.0533, 1.9464, 1.9606, 1.9537]
# Test Accuracy: [0.52125, 0.45875, 0.34875, 0.62375, 0.595, 0.54, 0.3775, 0.57125, 0.5625, 0.59875]
# Start of Epoch 9
# Average Train Loss: [1.9898, 2.0333, 2.0662, 1.9074, 1.9372, 1.9607, 2.0496, 1.9387, 1.9494, 1.9431]
# Average Train Loss: [1.8529, 1.9523, 1.8559, 1.765, 1.8176, 1.9042, 1.9278, 1.8394, 1.8337, 1.8386]
# Test Accuracy: [0.59125, 0.48375, 0.5675, 0.65375, 0.57875, 0.49625, 0.5125, 0.6, 0.595, 0.5975]
# Finished Training
# Elapsed Test Time: 7.850252389907837
# Elapsed Training Time: 16.36532235145569
# Final Test Accuracy: [0.5822, 0.4719, 0.5817, 0.659, 0.6018, 0.5402, 0.4911, 0.5796, 0.5899, 0.591]
# data slice [24954, ..., 27944]
# data slice [37311, ..., 34683]
# data slice [7733, ..., 56522]
# data slice [17639, ..., 16696]
# data slice [40049, ..., 35862]
# data slice [45247, ..., 25494]
# data slice [13416, ..., 35252]
# data slice [49019, ..., 14220]
# data slice [17360, ..., 59987]
# data slice [49705, ..., 46578]
# Start of Epoch 0
# Average Train Loss: [2.1384, 2.1721, 2.1161, 2.1804, 2.1612, 2.13, 2.1291, 2.1131, 2.1134, 2.1608]
# Test Accuracy: [0.40125, 0.28625, 0.39375, 0.34, 0.3275, 0.365, 0.3725, 0.47375, 0.40125, 0.35625]
# Start of Epoch 1
# Average Train Loss: [2.1092, 2.1498, 2.0614, 2.1447, 2.1214, 2.0754, 2.0733, 2.0235, 2.0595, 2.0873]
# Test Accuracy: [0.36875, 0.40125, 0.42125, 0.34125, 0.39625, 0.46875, 0.465, 0.53125, 0.44, 0.4675]
# Start of Epoch 2
# Average Train Loss: [2.097, 2.1278, 2.0351, 2.118, 2.0997, 2.0222, 2.0508, 1.9754, 2.0379, 2.0566]
# Test Accuracy: [0.42875, 0.3825, 0.41875, 0.46, 0.40625, 0.51375, 0.46125, 0.5875, 0.4575, 0.4575]
# Start of Epoch 3
# Average Train Loss: [2.0644, 2.1161, 2.0047, 2.0824, 2.0876, 1.9911, 2.0341, 1.9496, 2.0251, 2.0392]
# Test Accuracy: [0.44625, 0.38125, 0.59, 0.49375, 0.41125, 0.5675, 0.45625, 0.5675, 0.46875, 0.48125]
# Start of Epoch 4
# Average Train Loss: [2.0251, 2.1074, 1.9749, 2.0449, 2.0789, 1.9706, 2.0145, 1.9344, 2.0176, 2.0284]
# Test Accuracy: [0.5925, 0.38625, 0.565, 0.56875, 0.42125, 0.5225, 0.54875, 0.5825, 0.4275, 0.45625]
# Start of Epoch 5
# Average Train Loss: [1.9877, 2.1011, 1.9511, 2.0108, 2.0711, 1.9565, 1.9934, 1.9239, 2.0119, 2.0206]
# Test Accuracy: [0.635, 0.37, 0.5625, 0.58625, 0.3875, 0.56125, 0.5325, 0.56, 0.42875, 0.45375]
# Start of Epoch 6
# Average Train Loss: [1.9599, 2.0964, 1.933, 1.9847, 2.0659, 1.9463, 1.9761, 1.9129, 2.0075, 2.0127]
# Test Accuracy: [0.655, 0.375, 0.5725, 0.61375, 0.39375, 0.55625, 0.5575, 0.5825, 0.42875, 0.50125]
# Start of Epoch 7
# Average Train Loss: [1.9367, 2.0875, 1.9143, 1.9643, 2.0603, 1.9375, 1.9624, 1.9045, 2.0049, 2.0057]
# Test Accuracy: [0.705, 0.73125, 0.785, 0.67125, 0.455, 0.565, 0.56125, 0.58875, 0.42875, 0.61875]
# Start of Epoch 3
# Average Train Loss: [1.7189, 1.6714, 1.6276, 1.7955, 1.9429, 1.8331, 1.8158, 1.8125, 1.9771, 1.8182]
# Test Accuracy: [0.70125, 0.75, 0.7875, 0.60125, 0.43375, 0.5525, 0.56625, 0.5975, 0.47625, 0.61125]
# Start of Epoch 4
# Average Train Loss: [1.7156, 1.6643, 1.6256, 1.7951, 1.9434, 1.8334, 1.8142, 1.8116, 1.9772, 1.8159]
# Test Accuracy: [0.6875, 0.7325, 0.7825, 0.6225, 0.46625, 0.50625, 0.60125, 0.595, 0.46875, 0.5975]
# Finished Training
# Elapsed Test Time: 7.919258117675781
# Elapsed Training Time: 16.42612862586975
# Final Test Accuracy: [0.6824, 0.7404, 0.7729, 0.6229, 0.4489, 0.525, 0.5645, 0.5817, 0.4437, 0.6133]
# Average training time 101.72916758060455
# Average test accuracy 0.5842050000000001
# Median test accuracy 0.58195
# Standard deviation test accuracy 0.08460763248667345

# %%
fashion_test_accs_dp5_same = []
fashion_training_times_dp5_same = []
for i in range(4):
    m = MultipleDecoder(5, separate_encoders=False, dataset="fashionmnist", same_decoder_init=True)
    m.train(dp=True, epochs=15)
    m.fine_tune(epochs=5)
    fashion_test_accs_dp5_same.extend([x[-1] for x in m.test_accs])
    fashion_training_times_dp5_same.append(m.training_time)
print(f"Average training time", np.mean(fashion_training_times_dp5_same))
print(f"Average test accuracy", np.mean(fashion_test_accs_dp5_same))
print(f"Median test accuracy", np.median(fashion_test_accs_dp5_same))
print(f"Standard deviation test accuracy", np.std(fashion_test_accs_dp5_same))
# Out:
# data slice [29336, ..., 58232]
# data slice [47210, ..., 14346]
# data slice [40770, ..., 5904]
# data slice [50822, ..., 53889]
# data slice [50191, ..., 42718]
# Start of Epoch 0
# Average Train Loss: [2.1445, 2.1885, 2.1421, 2.1372, 2.1485]
# Test Accuracy: [0.35625, 0.35625, 0.41375, 0.4125, 0.4475]
# Start of Epoch 1
# Average Train Loss: [2.0942, 2.1278, 2.1076, 2.0785, 2.0697]
# Test Accuracy: [0.4625, 0.36, 0.37875, 0.4125, 0.46]
# Start of Epoch 2
# Average Train Loss: [2.0735, 2.072, 2.0867, 2.0534, 2.0293]
# Test Accuracy: [0.47875, 0.515, 0.37875, 0.43875, 0.5325]
# Start of Epoch 3
# Average Train Loss: [2.0615, 2.0395, 2.0731, 2.0326, 2.0059]
# Test Accuracy: [0.4425, 0.4925, 0.39, 0.55, 0.51875]
# Start of Epoch 4
# Average Train Loss: [2.0519, 2.018, 2.0649, 2.0033, 1.9894]
# Test Accuracy: [0.4625, 0.53, 0.42375, 0.6125, 0.52125]
# Start of Epoch 5
# Average Train Loss: [2.0442, 2.0014, 2.0594, 1.98, 1.9757]
# Test Accuracy: [0.45, 0.54875, 0.37125, 0.58125, 0.60875]
# Start of Epoch 6
# Average Train Loss: [2.038, 1.9874, 2.0526, 1.9638, 1.9569]
# Test Accuracy: [0.4725, 0.5325, 0.4125, 0.61625, 0.585]
# Start of Epoch 7
# Average Train Loss: [2.0329, 1.9755, 2.0469, 1.9495, 1.94]
# Test Accuracy: [0.4625, 0.52125, 0.40125, 0.5975, 0.605]
# Start of Epoch 8
# Average Train Loss: [2.0284, 1.9657, 2.0416, 1.9378, 1.9267]
# Test Accuracy: [0.46875, 0.525, 0.44125, 0.6125, 0.635]
# Start of Epoch 9
# Average Train Loss: [2.025, 1.9578, 2.0371, 1.9275, 1.9151]
# Test Accuracy: [0.48625, 0.52375, 0.43, 0.6075, 0.61625]
# Start of Epoch 10
# Average Train Loss: [2.0219, 1.9505, 2.0327, 1.9193, 1.9048]
# Test Accuracy: [0.49375, 0.5325, 0.42375, 0.6375, 0.6225]
# Start of Epoch 11
# Average Train Loss: [2.0191, 1.9441, 2.0258, 1.912, 1.8955]
# Test Accuracy: [0.4775, 0.51375, 0.49625, 0.62625, 0.6425]
# Start of Epoch 12
# Average Train Loss: [2.0167, 1.9384, 2.0186, 1.906, 1.8878]
# Test Accuracy: [0.46125, 0.5725, 0.50875, 0.58125, 0.63875]
# Start of Epoch 13
# Average Train Loss: [2.0144, 1.9333, 2.0119, 1.9015, 1.8813]
# Test Accuracy: [0.4725, 0.5175, 0.525, 0.62875, 0.6425]
# Start of Epoch 14
# Average Train Loss: [2.0119, 1.929, 2.0052, 1.8964, 1.8753]
# Test Accuracy: [0.51625, 0.54875, 0.58125, 0.60875, 0.65]
# Finished Training
# Elapsed Test Time: 11.862985134124756
# Elapsed Training Time: 42.75273084640503
# Final Test Accuracy: [0.5145, 0.5421, 0.5691, 0.6236, 0.6339]
# Start of Epoch 0
# Average Train Loss: [1.9145, 1.8748, 1.8131, 1.8136, 1.7878]
# Test Accuracy: [0.5575, 0.54125, 0.67625, 0.62, 0.63375]
# Start of Epoch 1
# Average Train Loss: [1.9116, 1.8716, 1.8021, 1.8108, 1.7848]
# Test Accuracy: [0.54625, 0.5275, 0.63, 0.67, 0.61125]
# Start of Epoch 2
# Average Train Loss: [1.9088, 1.8699, 1.7954, 1.8103, 1.7787]
# Test Accuracy: [0.5325, 0.51, 0.65625, 0.66375, 0.71375]
# Start of Epoch 3
# Average Train Loss: [1.9058, 1.8699, 1.7868, 1.8088, 1.7654]
# Test Accuracy: [0.54375, 0.56, 0.7, 0.62125, 0.7375]
# Start of Epoch 4
# Average Train Loss: [1.904, 1.8675, 1.7746, 1.8088, 1.7549]
# Test Accuracy: [0.565, 0.5575, 0.64375, 0.6375, 0.68375]
# Finished Training
# Elapsed Test Time: 3.9286139011383057
# Elapsed Training Time: 8.198327779769897
# Final Test Accuracy: [0.5481, 0.5454, 0.6699, 0.6341, 0.6986]
# data slice [41048, ..., 53780]
# data slice [55068, ..., 55035]
# data slice [32582, ..., 49523]
# data slice [14995, ..., 14086]
# data slice [57148, ..., 50073]
# Start of Epoch 0
# Average Train Loss: [2.1684, 2.2108, 2.2072, 2.2593, 2.2275]
# Test Accuracy: [0.4125, 0.33, 0.42125, 0.205, 0.4275]
# Start of Epoch 1
# Average Train Loss: [2.099, 2.1376, 2.1259, 2.2499, 2.1324]
# Test Accuracy: [0.43625, 0.4025, 0.415, 0.20875, 0.4275]
# Start of Epoch 2
# Average Train Loss: [2.0705, 2.0945, 2.0908, 2.2467, 2.0933]
# Test Accuracy: [0.47, 0.4525, 0.47375, 0.22125, 0.465]
# Start of Epoch 3
# Average Train Loss: [2.0498, 2.0702, 2.0708, 2.2448, 2.0699]
# Test Accuracy: [0.44875, 0.455, 0.38125, 0.1775, 0.42625]
# Start of Epoch 4
# Average Train Loss: [2.0358, 2.0523, 2.0562, 2.241, 2.0512]
# Test Accuracy: [0.4875, 0.44375, 0.42, 0.26, 0.47]
# Start of Epoch 5
# Average Train Loss: [2.0254, 2.0382, 2.0439, 2.2149, 2.0299]
# Test Accuracy: [0.45875, 0.55625, 0.4875, 0.3725, 0.57625]
# Start of Epoch 6
# Average Train Loss: [2.0171, 2.0205, 2.0327, 2.19, 2.0068]
# Test Accuracy: [0.4575, 0.54, 0.42375, 0.39375, 0.56625]
# Start of Epoch 7
# Average Train Loss: [2.0107, 2.0049, 2.0223, 2.1706, 1.9889]
# Test Accuracy: [0.47875, 0.605, 0.465, 0.3575, 0.65]
# Start of Epoch 8
# Average Train Loss: [2.0045, 1.9855, 2.0109, 2.1505, 1.974]
# Test Accuracy: [0.51625, 0.57875, 0.6125, 0.425, 0.585]
# Start of Epoch 9
# Average Train Loss: [1.9984, 1.9687, 1.9977, 2.1292, 1.9605]
# Test Accuracy: [0.5025, 0.61, 0.5925, 0.5175, 0.61375]
# Start of Epoch 10
# Average Train Loss: [1.9918, 1.9554, 1.9846, 2.109, 1.949]
# Test Accuracy: [0.54125, 0.61, 0.60375, 0.5075, 0.5825]
# Start of Epoch 11
# Average Train Loss: [1.9822, 1.9436, 1.9699, 2.0911, 1.9391]
# Test Accuracy: [0.54375, 0.59875, 0.62, 0.4975, 0.59375]
# Start of Epoch 12
# Average Train Loss: [1.9742, 1.9329, 1.9554, 2.0765, 1.9297]
# Test Accuracy: [0.5275, 0.6025, 0.6375, 0.5425, 0.59375]
# Start of Epoch 13
# Average Train Loss: [1.9666, 1.9236, 1.9438, 2.0627, 1.9181]
# Test Accuracy: [0.57875, 0.5825, 0.6225, 0.56625, 0.67375]
# Start of Epoch 14
# Average Train Loss: [1.9595, 1.9153, 1.932, 2.0508, 1.9057]
# Test Accuracy: [0.62375, 0.60875, 0.61, 0.53875, 0.6575]
# Finished Training
# Elapsed Test Time: 11.848871946334839
# Elapsed Training Time: 42.68184781074524
# Final Test Accuracy: [0.5601, 0.6052, 0.6071, 0.5487, 0.6915]
# Start of Epoch 0
# Average Train Loss: [1.8559, 1.7966, 1.7708, 1.889, 1.7125]
# Test Accuracy: [0.565, 0.61875, 0.62375, 0.56125, 0.72875]
# Start of Epoch 1
# Average Train Loss: [1.8545, 1.793, 1.7659, 1.8815, 1.7061]
# Test Accuracy: [0.5725, 0.62375, 0.62875, 0.5675, 0.69375]
# Start of Epoch 2
# Average Train Loss: [1.8527, 1.7988, 1.7631, 1.8731, 1.7041]
# Test Accuracy: [0.5625, 0.59375, 0.66875, 0.53125, 0.6975]
# Start of Epoch 3
# Average Train Loss: [1.8504, 1.7964, 1.7611, 1.8708, 1.7013]
# Test Accuracy: [0.57, 0.60125, 0.62875, 0.5575, 0.72125]
# Start of Epoch 4
# Average Train Loss: [1.8489, 1.7941, 1.7603, 1.8661, 1.6979]
# Test Accuracy: [0.55875, 0.60625, 0.64, 0.5925, 0.6525]
# Finished Training
# Elapsed Test Time: 3.9401776790618896
# Elapsed Training Time: 8.193586587905884
# Final Test Accuracy: [0.5672, 0.6164, 0.6414, 0.5711, 0.6836]
# data slice [7885, ..., 47459]
# data slice [52093, ..., 37024]
# data slice [55247, ..., 31084]
# data slice [1538, ..., 13650]
# data slice [32946, ..., 51932]
# Start of Epoch 0
# Average Train Loss: [2.1183, 2.1857, 2.1809, 2.096, 2.1269]
# Test Accuracy: [0.4775, 0.43375, 0.39875, 0.3575, 0.40875]
# Start of Epoch 1
# Average Train Loss: [2.0774, 2.1093, 2.0856, 2.0682, 2.0468]
# Test Accuracy: [0.455, 0.4575, 0.5375, 0.41, 0.49125]
# Start of Epoch 2
# Average Train Loss: [2.0478, 2.0535, 2.0315, 2.0449, 2.0121]
# Test Accuracy: [0.45375, 0.58125, 0.61125, 0.4725, 0.4925]
# Start of Epoch 3
# Average Train Loss: [2.0301, 2.0178, 1.9988, 2.0248, 1.9892]
# Test Accuracy: [0.47, 0.5475, 0.59125, 0.4675, 0.505]
# Start of Epoch 4
# Average Train Loss: [2.0185, 1.9927, 1.9765, 1.998, 1.9727]
# Test Accuracy: [0.45625, 0.56875, 0.54125, 0.555, 0.56625]
# Start of Epoch 5
# Average Train Loss: [2.0108, 1.9749, 1.9547, 1.9724, 1.9589]
# Test Accuracy: [0.47125, 0.58375, 0.665, 0.5825, 0.55625]
# Start of Epoch 6
# Average Train Loss: [2.0044, 1.9612, 1.9347, 1.9539, 1.9477]
# Test Accuracy: [0.48375, 0.59, 0.68625, 0.58, 0.61]
# Start of Epoch 7
# Average Train Loss: [1.9997, 1.9492, 1.9196, 1.9402, 1.9381]
# Test Accuracy: [0.475, 0.585, 0.66875, 0.575, 0.57375]
# Start of Epoch 8
# Average Train Loss: [1.9945, 1.939, 1.9056, 1.9281, 1.9297]
# Test Accuracy: [0.51, 0.6, 0.71625, 0.55375, 0.6125]
# Start of Epoch 9
# Average Train Loss: [1.9886, 1.9304, 1.8918, 1.9191, 1.9224]
# Test Accuracy: [0.53125, 0.5725, 0.7225, 0.56375, 0.585]
# Start of Epoch 10
# Average Train Loss: [1.9831, 1.9233, 1.8763, 1.9113, 1.9165]
# Test Accuracy: [0.54375, 0.58625, 0.72125, 0.575, 0.58125]
# Start of Epoch 11
# Average Train Loss: [1.9787, 1.9165, 1.8627, 1.9046, 1.9105]
# Test Accuracy: [0.515, 0.5775, 0.67375, 0.57125, 0.59625]
# Start of Epoch 12
# Average Train Loss: [1.9745, 1.9107, 1.8516, 1.8987, 1.9046]
# Test Accuracy: [0.55, 0.5775, 0.74875, 0.62625, 0.6025]
# Start of Epoch 13
# Average Train Loss: [1.9708, 1.9063, 1.8403, 1.8937, 1.8974]
# Test Accuracy: [0.54625, 0.5875, 0.72, 0.59625, 0.585]
# Start of Epoch 14
# Average Train Loss: [1.9673, 1.9014, 1.8314, 1.889, 1.8903]
# Test Accuracy: [0.57, 0.59375, 0.72625, 0.57125, 0.5825]
# Finished Training
# Elapsed Test Time: 11.817070722579956
# Elapsed Training Time: 42.65782833099365
# Final Test Accuracy: [0.5512, 0.6035, 0.729, 0.5931, 0.6036]
# Start of Epoch 0
# Average Train Loss: [1.9189, 1.8363, 1.6888, 1.817, 1.7877]
# Test Accuracy: [0.57125, 0.60875, 0.7075, 0.61, 0.6025]
# Start of Epoch 1
# Average Train Loss: [1.9173, 1.8274, 1.6865, 1.82, 1.7853]
# Test Accuracy: [0.5575, 0.60875, 0.72, 0.605, 0.6025]
# Start of Epoch 2
# Average Train Loss: [1.9161, 1.8271, 1.6835, 1.8197, 1.7832]
# Test Accuracy: [0.51375, 0.59375, 0.72875, 0.56125, 0.595]
# Start of Epoch 3
# Average Train Loss: [1.9148, 1.8272, 1.6835, 1.8195, 1.7812]
# Test Accuracy: [0.49, 0.59375, 0.7375, 0.6, 0.61375]
# Start of Epoch 4
# Average Train Loss: [1.9198, 1.8244, 1.683, 1.8197, 1.7786]
# Test Accuracy: [0.5325, 0.585, 0.74375, 0.59, 0.585]
# Finished Training
# Elapsed Test Time: 3.947669267654419
# Elapsed Training Time: 8.215381383895874
# Final Test Accuracy: [0.5358, 0.5844, 0.7269, 0.5854, 0.6117]
# data slice [37968, ..., 20917]
# data slice [59606, ..., 29102]
# data slice [51134, ..., 44698]
# data slice [3706, ..., 1994]
# data slice [43570, ..., 54511]
# Start of Epoch 0
# Average Train Loss: [2.1096, 2.1328, 2.0208, 2.1076, 2.1069]
# Test Accuracy: [0.4525, 0.5525, 0.59, 0.42375, 0.49125]
# Start of Epoch 1
# Average Train Loss: [2.0578, 1.991, 1.941, 2.0615, 2.0008]
# Test Accuracy: [0.455, 0.615, 0.54375, 0.41625, 0.59]
# Start of Epoch 2
# Average Train Loss: [2.0308, 1.9206, 1.9075, 2.0434, 1.939]
# Test Accuracy: [0.4675, 0.64125, 0.61125, 0.46875, 0.685]
# Start of Epoch 3
# Average Train Loss: [2.0168, 1.8772, 1.8905, 2.0331, 1.9023]
# Test Accuracy: [0.52375, 0.66625, 0.59875, 0.43625, 0.68375]
# Start of Epoch 4
# Average Train Loss: [2.0025, 1.8478, 1.8777, 2.0263, 1.8771]
# Test Accuracy: [0.4625, 0.6375, 0.625, 0.46875, 0.665]
# Start of Epoch 5
# Average Train Loss: [1.9949, 1.8261, 1.8689, 2.0207, 1.8589]
# Test Accuracy: [0.53, 0.7125, 0.63375, 0.445, 0.6725]
# Start of Epoch 6
# Average Train Loss: [1.9865, 1.8129, 1.8607, 2.0159, 1.8444]
# Test Accuracy: [0.51625, 0.735, 0.63375, 0.47875, 0.6475]
# Start of Epoch 7
# Average Train Loss: [1.9795, 1.8003, 1.856, 2.0123, 1.8325]
# Test Accuracy: [0.51875, 0.66125, 0.5325, 0.4425, 0.695]
# Start of Epoch 8
# Average Train Loss: [1.9737, 1.7915, 1.8555, 2.0092, 1.8226]
# Test Accuracy: [0.525, 0.69125, 0.655, 0.49875, 0.68625]
# Start of Epoch 9
# Average Train Loss: [1.9686, 1.7835, 1.8523, 2.0061, 1.8145]
# Test Accuracy: [0.5325, 0.7225, 0.5925, 0.4675, 0.69625]
# Start of Epoch 10
# Average Train Loss: [1.9641, 1.7778, 1.8481, 2.004, 1.8081]
# Test Accuracy: [0.4925, 0.7, 0.6275, 0.48375, 0.6975]
# Start of Epoch 11
# Average Train Loss: [1.9601, 1.7726, 1.8445, 2.002, 1.803]
# Test Accuracy: [0.5175, 0.7175, 0.6325, 0.47, 0.69875]
# Start of Epoch 12
# Average Train Loss: [1.9563, 1.7673, 1.8408, 2.0, 1.7969]
# Test Accuracy: [0.505, 0.7075, 0.5975, 0.47625, 0.7]
# Start of Epoch 13
# Average Train Loss: [1.9535, 1.7622, 1.8376, 1.9981, 1.7918]
# Test Accuracy: [0.51625, 0.71125, 0.61875, 0.46125, 0.715]
# Start of Epoch 14
# Average Train Loss: [1.9502, 1.7577, 1.8345, 1.9963, 1.7893]
# Test Accuracy: [0.53125, 0.71375, 0.63625, 0.48375, 0.67375]
# Finished Training
# Elapsed Test Time: 11.815828323364258
# Elapsed Training Time: 42.618730306625366
# Final Test Accuracy: [0.5181, 0.711, 0.6371, 0.4753, 0.701]
# Start of Epoch 0
# Average Train Loss: [1.9025, 1.7082, 1.7912, 1.9709, 1.7211]
# Test Accuracy: [0.51125, 0.70125, 0.60875, 0.435, 0.69375]
# Start of Epoch 1
# Average Train Loss: [1.9015, 1.6981, 1.7919, 1.969, 1.7187]
# Test Accuracy: [0.51125, 0.71875, 0.65375, 0.44, 0.72125]
# Start of Epoch 2
# Average Train Loss: [1.9012, 1.6937, 1.7917, 1.9647, 1.7153]
# Test Accuracy: [0.55, 0.68375, 0.6425, 0.58, 0.725]
# Start of Epoch 3
# Average Train Loss: [1.9007, 1.694, 1.7927, 1.942, 1.7145]
# Test Accuracy: [0.48625, 0.7, 0.64, 0.5525, 0.69875]
# Start of Epoch 4
# Average Train Loss: [1.9004, 1.6943, 1.7918, 1.9278, 1.7152]
# Test Accuracy: [0.53375, 0.68625, 0.62375, 0.5475, 0.71875]
# Finished Training
# Elapsed Test Time: 3.9340319633483887
# Elapsed Training Time: 8.186052322387695
# Final Test Accuracy: [0.5229, 0.7176, 0.6267, 0.5647, 0.7202]
# Average training time 50.87612134218216
# Average test accuracy 0.618605
# Median test accuracy 0.61405
# Standard deviation test accuracy 0.06418933303127551

# %%
test_accs_unbalanced = []
training_times_unbalanced = []
for i in range(2):
    m = MultipleDecoder(10, separate_encoders=True, dataset="mnist", unbalanced=True)
    m.train(dp=False, epochs=20)
    test_accs_unbalanced.extend([x[-1] for x in m.test_accs])
    training_times_unbalanced.append(m.training_time)

print(f"Average training time", np.mean(training_times_unbalanced))
print(f"Average test accuracy", np.mean(test_accs_unbalanced))
print(f"Median test accuracy", np.median(test_accs_unbalanced))
print(f"Standard deviation test accuracy", np.std(test_accs_unbalanced))
# Out:
# [660  60  60  60  60  60  60  60  60  60]
# [ 60 660  60  60  60  60  60  60  60  60]
# [ 60  60 660  60  60  60  60  60  60  60]
# [ 60  60  60 660  60  60  60  60  60  60]
# [ 60  60  60  60 660  60  60  60  60  60]
# [ 60  60  60  60  60 660  60  60  60  60]
# [ 60  60  60  60  60  60 660  60  60  60]
# [ 60  60  60  60  60  60  60 660  60  60]
# [ 60  60  60  60  60  60  60  60 660  60]
# [ 60  60  60  60  60  60  60  60  60 660]
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# Start of Epoch 0
# Average Train Loss:
# Average Train Loss: [1.9131, 1.9137, 2.1299, 2.0539, 1.9128, 2.2345, 1.9128, 1.9129, 1.9141, 1.913]
# Test Accuracy: [0.105, 0.11875, 0.47125, 0.66875, 0.09375, 0.2975, 0.0925, 0.09625, 0.09, 0.11]
# Start of Epoch 11
# Average Train Loss: [1.913, 1.9135, 2.1274, 2.0509, 1.9127, 2.2337, 1.9127, 1.9127, 1.9139, 1.9128]
# Test Accuracy: [0.09, 0.11625, 0.47875, 0.64875, 0.0875, 0.29875, 0.10125, 0.12, 0.09, 0.09875]
# Start of Epoch 12
# Average Train Loss: [1.9128, 1.9133, 2.1256, 2.0491, 1.9126, 2.233, 1.9126, 1.9126, 1.9137, 1.9127]
# Test Accuracy: [0.105, 0.1075, 0.44, 0.59125, 0.1025, 0.27375, 0.1025, 0.1275, 0.10625, 0.09625]
# Start of Epoch 13
# Average Train Loss: [1.9127, 1.9131, 2.1239, 2.0475, 1.9125, 2.2324, 1.9125, 1.9125, 1.9135, 1.9126]
# Test Accuracy: [0.0825, 0.13375, 0.47, 0.645, 0.09125, 0.2475, 0.0875, 0.1175, 0.11, 0.105]
# Start of Epoch 14
# Average Train Loss: [1.9126, 1.913, 2.1223, 2.0456, 1.9124, 2.2317, 1.9124, 1.9124, 1.9133, 1.9125]
# Test Accuracy: [0.09375, 0.12125, 0.48625, 0.63875, 0.0925, 0.2875, 0.085, 0.0975, 0.0825, 0.0975]
# Start of Epoch 15
# Average Train Loss: [1.9125, 1.9129, 2.1208, 2.0438, 1.9123, 2.2311, 1.9123, 1.9123, 1.9132, 1.9124]
# Test Accuracy: [0.11375, 0.1075, 0.46125, 0.67625, 0.0875, 0.3125, 0.0925, 0.10875, 0.105, 0.1175]
# Start of Epoch 16
# Average Train Loss: [1.9124, 1.9128, 2.1194, 2.042, 1.9122, 2.2306, 1.9122, 1.9123, 1.9131, 1.9123]
# Test Accuracy: [0.09625, 0.11125, 0.4725, 0.64375, 0.09125, 0.30375, 0.09125, 0.11625, 0.085, 0.095]
# Start of Epoch 17
# Average Train Loss: [1.9124, 1.9127, 2.1182, 2.0406, 1.9122, 2.2301, 1.9122, 1.9122, 1.913, 1.9123]
# Test Accuracy: [0.09, 0.10375, 0.5175, 0.65, 0.10875, 0.28875, 0.10875, 0.10125, 0.0925, 0.10375]
# Start of Epoch 18
# Average Train Loss: [1.9123, 1.9126, 2.117, 2.0395, 1.9121, 2.2296, 1.9121, 1.9121, 1.9129, 1.9122]
# Test Accuracy: [0.1025, 0.095, 0.4825, 0.6825, 0.09375, 0.3, 0.0975, 0.1, 0.095, 0.11]
# Start of Epoch 19
# Average Train Loss: [1.9122, 1.9125, 2.116, 2.0383, 1.9121, 2.2291, 1.9121, 1.9121, 1.9128, 1.9122]
# Test Accuracy: [0.1025, 0.115, 0.48875, 0.625, 0.11, 0.2975, 0.09875, 0.09, 0.085, 0.08625]
# Finished Training
# Elapsed Test Time: 31.470797061920166
# Elapsed Training Time: 65.19641065597534
# Final Test Accuracy: [0.0976, 0.115, 0.4784, 0.6437, 0.1002, 0.2886, 0.0968, 0.0999, 0.0998, 0.1006]
# Average training time 65.16312444210052
# Average test accuracy 0.194795
# Median test accuracy 0.10225000000000001
# Standard deviation test accuracy 0.1727540201413559

# %%
fashion_test_accs_unbalanced = []
fashion_training_times_unbalanced = []
for i in range(2):
    m = MultipleDecoder(10, separate_encoders=True, dataset="fashionmnist", unbalanced=True)
    m.train(dp=False, epochs=20)
    fashion_test_accs_unbalanced.extend([x[-1] for x in m.test_accs])
    fashion_training_times_unbalanced.append(m.training_time)

print(f"Average training time", np.mean(fashion_training_times_unbalanced))
print(f"Average test accuracy", np.mean(fashion_test_accs_unbalanced))
print(f"Median test accuracy", np.median(fashion_test_accs_unbalanced))
print(f"Standard deviation test accuracy", np.std(fashion_test_accs_unbalanced))
# Out:
# [660  60  60  60  60  60  60  60  60  60]
# [ 60 660  60  60  60  60  60  60  60  60]
# [ 60  60 660  60  60  60  60  60  60  60]
# [ 60  60  60 660  60  60  60  60  60  60]
# [ 60  60  60  60 660  60  60  60  60  60]
# [ 60  60  60  60  60 660  60  60  60  60]
# [ 60  60  60  60  60  60 660  60  60  60]
# [ 60  60  60  60  60  60  60 660  60  60]
# [ 60  60  60  60  60  60  60  60 660  60]
# [ 60  60  60  60  60  60  60  60  60 660]
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# Start of Epoch 0
# Average Train Loss: [1.9314, 1.9276, 1.9311, 1.9384, 1.9365, 1.9297, 1.941, 1.9423, 1.9247, 1.8861]
# Test Accuracy: [0.095, 0.10625, 0.09125, 0.1, 0.1, 0.1, 0.105, 0.115, 0.08875, 0.16625]
# Start of Epoch 1
# Average Train Loss: [1.9213, 1.9194, 1.9211, 1.9248, 1.9238, 1.9204, 1.9261, 1.9267, 1.9179, 1.8694]
# Test Accuracy: [0.11625, 0.10625, 0.07625, 0.0975, 0.09, 0.09875, 0.09875, 0.09, 0.09125, 0.3325]
# Start of Epoch 2
# Average Train Loss: [1.9179, 1.9166, 1.9178, 1.9202, 1.9196, 1.9173, 1.9211, 1.9215, 1.9157, 1.8451]
# Test Accuracy: [0.08875, 0.09, 0.09875, 0.085, 0.09125, 0.07375, 0.08125, 0.10125, 0.11125, 0.36125]
# Start of Epoch 3
# Average Train Loss: [1.9162, 1.9153, 1.9161, 1.918, 1.9175, 1.9158, 1.9186, 1.9189, 1.9145, 1.832]
# Test Accuracy: [0.1, 0.11, 0.105, 0.11125, 0.1225, 0.11875, 0.09, 0.08625, 0.08875, 0.3425]
# Start of Epoch 4
# Average Train Loss: [1.9152, 1.9144, 1.9151, 1.9166, 1.9162, 1.9149, 1.9171, 1.9174, 1.9139, 1.8212]
# Test Accuracy: [0.0825, 0.0875, 0.09, 0.10125, 0.1125, 0.1125, 0.09625, 0.1075, 0.09875, 0.315]
# Start of Epoch 5
# Average Train Loss: [1.9145, 1.9139, 1.9145, 1.9157, 1.9154, 1.9142, 1.9161, 1.9163, 1.9134, 1.8096]
# Test Accuracy: [0.11, 0.11375, 0.09875, 0.09, 0.105, 0.08625, 0.10625, 0.10625, 0.09375, 0.425]
# Start of Epoch 6
# Average Train Loss: [1.914, 1.9135, 1.914, 1.915, 1.9148, 1.9138, 1.9154, 1.9156, 1.9131, 1.7989]
# Test Accuracy: [0.10875, 0.09875, 0.1225, 0.1125, 0.09375, 0.08375, 0.1025, 0.095, 0.105, 0.45375]
# Start of Epoch 7
# Average Train Loss: [1.9137, 1.9132, 1.9136, 1.9146, 1.9143, 1.9135, 1.9149, 1.915, 1.9128, 1.79]
# Test Accuracy: [0.105, 0.10375, 0.1075, 0.09375, 0.105, 0.095, 0.0825, 0.095, 0.10125, 0.4625]
# Start of Epoch 8
# Average Train Loss: [1.9134, 1.913, 1.9134, 1.9142, 1.914, 1.9132, 1.9145, 1.9146, 1.9127, 1.7829]
# Start of Epoch 19
# Average Train Loss: [1.9133, 1.9124, 2.2354, 1.9121, 1.9132, 1.9118, 1.8385, 1.9119, 1.9152, 1.9216]
# Test Accuracy: [0.10625, 0.0975, 0.27375, 0.085, 0.09375, 0.095, 0.3475, 0.08625, 0.1025, 0.09]
# Finished Training
# Elapsed Test Time: 31.434542179107666
# Elapsed Training Time: 65.11511278152466
# Final Test Accuracy: [0.1002, 0.1008, 0.2767, 0.102, 0.0991, 0.0953, 0.334, 0.1012, 0.1022, 0.1022]
# Average training time 65.17281973361969
# Average test accuracy 0.14286499999999996
# Median test accuracy 0.1005
# Standard deviation test accuracy 0.1130525288306281

# %%
test_accs_dp_unbalanced = []
training_times_dp_unbalanced = []
for i in range(2):
    m = MultipleDecoder(10, separate_encoders=False, dataset="mnist", unbalanced=True)
    m.train(dp=True, epochs=15)
    m.fine_tune(epochs=5)
    test_accs_dp_unbalanced.extend([x[-1] for x in m.test_accs])
    training_times_dp_unbalanced.append(m.training_time)

print(f"Average training time", np.mean(training_times_dp_unbalanced))
print(f"Average test accuracy", np.mean(test_accs_dp_unbalanced))
print(f"Median test accuracy", np.median(test_accs_dp_unbalanced))
print(f"Standard deviation test accuracy", np.std(test_accs_dp_unbalanced))
# Out:
# [660  60  60  60  60  60  60  60  60  60]
# [ 60 660  60  60  60  60  60  60  60  60]
# [ 60  60 660  60  60  60  60  60  60  60]
# [ 60  60  60 660  60  60  60  60  60  60]
# [ 60  60  60  60 660  60  60  60  60  60]
# [ 60  60  60  60  60 660  60  60  60  60]
# [ 60  60  60  60  60  60 660  60  60  60]
# [ 60  60  60  60  60  60  60 660  60  60]
# [ 60  60  60  60  60  60  60  60 660  60]
# [ 60  60  60  60  60  60  60  60  60 660]
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# Start of Epoch 0
# Average Train Loss: [1.9258, 1.9297, 1.9327, 2.3036, 2.2493, 1.928, 1.9346, 1.9186, 1.925, 1.9307]
# Test Accuracy: [0.09625, 0.1075, 0.10875, 0.08125, 0.3275, 0.1, 0.09375, 0.11375, 0.09875, 0.09625]
# Start of Epoch 1
# Average Train Loss: [1.9185, 1.9204, 1.9219, 2.3031, 2.2268, 1.9196, 1.9229, 1.9149, 1.9181, 1.9209]
# Test Accuracy: [0.0925, 0.105, 0.09, 0.12, 0.27625, 0.0875, 0.08875, 0.1075, 0.09625, 0.1]
# Start of Epoch 2
# Average Train Loss: [1.916, 1.9173, 1.9183, 2.3029, 2.2186, 1.9168, 1.919, 1.9137, 1.9158, 1.9177]
# Test Accuracy: [0.09625, 0.11875, 0.1025, 0.08, 0.3025, 0.08125, 0.08, 0.1175, 0.08125, 0.1175]
# Start of Epoch 3
# Average Train Loss: [1.9148, 1.9158, 1.9165, 2.3028, 2.214, 1.9154, 1.917, 1.913, 1.9146, 1.916]
# Test Accuracy: [0.10625, 0.1225, 0.10375, 0.09625, 0.35375, 0.0875, 0.0875, 0.10625, 0.10375, 0.11125]
# Start of Epoch 4
# Average Train Loss: [1.9141, 1.9149, 1.9155, 2.3028, 2.211, 1.9145, 1.9158, 1.9127, 1.9139, 1.9151]
# Test Accuracy: [0.105, 0.11375, 0.1, 0.10125, 0.34625, 0.0925, 0.08375, 0.09875, 0.075, 0.09875]
# Start of Epoch 5
# Average Train Loss: [1.9136, 1.9142, 1.9147, 2.3028, 2.2075, 1.914, 1.9151, 1.9124, 1.9135, 1.9144]
# Test Accuracy: [0.1075, 0.1075, 0.10375, 0.1025, 0.3825, 0.075, 0.09375, 0.10625, 0.1, 0.0975]
# Start of Epoch 6
# Average Train Loss: [1.9132, 1.9138, 1.9142, 2.3027, 2.205, 1.9136, 1.9145, 1.9122, 1.9131, 1.9139]
# Test Accuracy: [0.08625, 0.13, 0.105, 0.10875, 0.345, 0.08625, 0.08625, 0.095, 0.08375, 0.10375]
# Start of Epoch 7
# Average Train Loss: [1.913, 1.9135, 1.9138, 2.3027, 2.2027, 1.9133, 1.9141, 1.9121, 1.9129, 1.9136]
# Test Accuracy: [0.105, 0.11, 0.09125, 0.09875, 0.395, 0.1075, 0.10375, 0.1025, 0.1225, 0.08875]
# Start of Epoch 8
# Average Train Loss: [1.9128, 1.9132, 1.9135, 2.3027, 2.2007, 1.913, 1.9138, 1.912, 1.9127, 1.9133]
# Test Accuracy: [0.095, 0.09375, 0.10875, 0.095, 0.37875, 0.07875, 0.09625, 0.08375, 0.11125, 0.095]
# Start of Epoch 9
# Average Train Loss: [1.9126, 1.913, 1.9133, 2.3027, 2.1992, 1.9128, 1.9135, 1.9119, 1.9125, 1.9131]
# Test Accuracy: [0.10625, 0.11125, 0.11125, 0.08125, 0.39875, 0.09875, 0.1125, 0.1, 0.095, 0.10875]
# Start of Epoch 10
# Average Train Loss: [1.9125, 1.9128, 1.9131, 2.3027, 2.1978, 1.9127, 1.9133, 1.9118, 1.9124, 1.9129]
# Test Accuracy: [0.09125, 0.105, 0.0975, 0.095, 0.38125, 0.0825, 0.11, 0.1, 0.105, 0.08875]
# Start of Epoch 11
# Average Train Loss: [1.9124, 1.9127, 1.9129, 2.3027, 2.1966, 1.9126, 1.9131, 1.9118, 1.9123, 1.9128]
# Test Accuracy: [0.09, 0.1225, 0.11125, 0.11875, 0.3775, 0.08875, 0.10625, 0.10625, 0.1, 0.10125]
# Start of Epoch 12
# Average Train Loss: [1.9123, 1.9126, 1.9128, 2.3027, 2.1956, 1.9124, 1.913, 1.9117, 1.9122, 1.9127]
# Test Accuracy: [0.085, 0.1225, 0.105, 0.09625, 0.39375, 0.08875, 0.09125, 0.09875, 0.0975, 0.09625]
# Start of Epoch 13
# Average Train Loss: [1.9122, 1.9125, 1.9127, 2.3027, 2.1948, 1.9124, 1.9128, 1.9117, 1.9121, 1.9125]
# Test Accuracy: [0.09875, 0.1175, 0.08125, 0.10625, 0.37125, 0.07625, 0.10125, 0.09625, 0.08375, 0.1225]
# Start of Epoch 14
# Average Train Loss: [1.9121, 1.9124, 1.9126, 2.3027, 2.1938, 1.9123, 1.9127, 1.9117, 1.9121, 1.9125]
# Test Accuracy: [0.0925, 0.09375, 0.1125, 0.09625, 0.37125, 0.09625, 0.11375, 0.08875, 0.10875, 0.0825]
# Finished Training
# Elapsed Test Time: 23.579118251800537
# Elapsed Training Time: 84.91832542419434
# Final Test Accuracy: [0.1009, 0.1174, 0.1024, 0.0973, 0.3744, 0.0903, 0.0951, 0.1046, 0.0963, 0.1021]
# Start of Epoch 0
# Average Train Loss: [1.9112, 1.9112, 1.9112, 2.3026, 2.1805, 1.9112, 1.9112, 1.9112, 1.9112, 1.9112]
# Test Accuracy: [0.10375, 0.09, 0.09625, 0.09125, 0.36875, 0.06875, 0.0925, 0.1, 0.10375, 0.10375]
# Start of Epoch 1
# Average Train Loss: [1.9112, 1.9112, 1.9112, 2.3026, 2.1812, 1.9112, 1.9112, 1.9112, 1.9112, 1.9112]
# Test Accuracy: [0.1, 0.11625, 0.1225, 0.095, 0.3875, 0.09375, 0.08375, 0.1025, 0.11, 0.0825]
# Start of Epoch 2
# Average Train Loss: [1.9112, 1.9112, 1.9112, 2.3026, 2.1808, 1.9112, 1.9112, 1.9112, 1.9112, 1.9112]
# Test Accuracy: [0
# Average Train Loss: [1.9112, 1.9112, 1.9112, 1.9112, 1.9112, 1.9112, 1.9112, 1.9112, 1.9112, 1.9112]
# Test Accuracy: [0.10125, 0.11375, 0.0975, 0.10875, 0.09625, 0.09875, 0.105, 0.09875, 0.0825, 0.105]
# Finished Training
# Elapsed Test Time: 7.845372200012207
# Elapsed Training Time: 16.230340480804443
# Final Test Accuracy: [0.0978, 0.1166, 0.1017, 0.1009, 0.0974, 0.0883, 0.0943, 0.1023, 0.0983, 0.102]
# Average training time 101.19906675815582
# Average test accuracy 0.11359999999999999
# Median test accuracy 0.09935
# Standard deviation test accuracy 0.060893431501271154

# %%
fashion_test_accs_dp_unbalanced = []
fashion_training_times_dp_unbalanced = []
for i in range(2):
    m = MultipleDecoder(10, separate_encoders=False, dataset="fashionmnist", unbalanced=True)
    m.train(dp=True, epochs=15)
    m.fine_tune(epochs=5)
    fashion_test_accs_dp_unbalanced.extend([x[-1] for x in m.test_accs])
    fashion_training_times_dp_unbalanced.append(m.training_time)

print(f"Average training time", np.mean(fashion_training_times_dp_unbalanced))
print(f"Average test accuracy", np.mean(fashion_test_accs_dp_unbalanced))
print(f"Median test accuracy", np.median(fashion_test_accs_dp_unbalanced))
print(f"Standard deviation test accuracy", np.std(fashion_test_accs_dp_unbalanced))
# Out:
# [660  60  60  60  60  60  60  60  60  60]
# [ 60 660  60  60  60  60  60  60  60  60]
# [ 60  60 660  60  60  60  60  60  60  60]
# [ 60  60  60 660  60  60  60  60  60  60]
# [ 60  60  60  60 660  60  60  60  60  60]
# [ 60  60  60  60  60 660  60  60  60  60]
# [ 60  60  60  60  60  60 660  60  60  60]
# [ 60  60  60  60  60  60  60 660  60  60]
# [ 60  60  60  60  60  60  60  60 660  60]
# [ 60  60  60  60  60  60  60  60  60 660]
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# 1200
# 10000
# Start of Epoch 0
# Average Train Loss: [1.9345, 1.9265, 1.9275, 1.9317, 1.9306, 1.9757, 1.9193, 1.9264, 1.921, 1.9052]
# Test Accuracy: [0.1075, 0.0875, 0.11625, 0.08875, 0.105, 0.0975, 0.0975, 0.09875, 0.10875, 0.2775]
# Start of Epoch 1
# Average Train Loss: [1.9228, 1.9188, 1.9193, 1.9214, 1.9209, 1.9434, 1.9152, 1.9188, 1.9161, 1.8688]
# Test Accuracy: [0.08375, 0.0825, 0.095, 0.09875, 0.08875, 0.1025, 0.12375, 0.09, 0.11625, 0.18375]
# Start of Epoch 2
# Average Train Loss: [1.9189, 1.9163, 1.9166, 1.918, 1.9176, 1.9327, 1.9139, 1.9162, 1.9144, 1.8665]
# Test Accuracy: [0.09625, 0.11125, 0.0975, 0.11125, 0.105, 0.10375, 0.1, 0.09875, 0.0975, 0.2025]
# Start of Epoch 3
# Average Train Loss: [1.917, 1.915, 1.9152, 1.9163, 1.916, 1.9273, 1.9132, 1.915, 1.9136, 1.8668]
# Test Accuracy: [0.10625, 0.09625, 0.1125, 0.10125, 0.09875, 0.11625, 0.09, 0.095, 0.07625, 0.1325]
# Start of Epoch 4
# Average Train Loss: [1.9158, 1.9142, 1.9144, 1.9153, 1.915, 1.9241, 1.9128, 1.9142, 1.9131, 1.8669]
# Test Accuracy: [0.1025, 0.10375, 0.09625, 0.10375, 0.10625, 0.08375, 0.09, 0.1025, 0.10875, 0.21125]
# Start of Epoch 5
# Average Train Loss: [1.915, 1.9137, 1.9139, 1.9146, 1.9144, 1.9219, 1.9125, 1.9137, 1.9128, 1.866]
# Test Accuracy: [0.09625, 0.105, 0.10875, 0.0925, 0.10125, 0.10375, 0.1075, 0.095, 0.1, 0.18875]
# Start of Epoch 6
# Average Train Loss: [1.9145, 1.9133, 1.9135, 1.9141, 1.9139, 1.9204, 1.9123, 1.9133, 1.9126, 1.8654]
# Test Accuracy: [0.095, 0.11375, 0.08625, 0.10625, 0.1025, 0.095, 0.1, 0.0825, 0.0925, 0.2]
# Start of Epoch 7
# Average Train Loss: [1.9141, 1.9131, 1.9132, 1.9137, 1.9136, 1.9192, 1.9122, 1.9131, 1.9124, 1.8619]
# Test Accuracy: [0.10625, 0.08, 0.1025, 0.10125, 0.105, 0.09375, 0.10625, 0.11875, 0.08875, 0.27375]
# Average Train Loss: [1.9112, 1.9112, 1.9112, 2.229, 1.9112, 2.2173, 1.9112, 1.9112, 1.9112, 1.9112]
# Test Accuracy: [0.085, 0.09625, 0.09875, 0.21125, 0.0875, 0.27375, 0.10875, 0.095, 0.09, 0.1175]
# Start of Epoch 3
# Average Train Loss: [1.9112, 1.9112, 1.9112, 2.2287, 1.9112, 2.2142, 1.9112, 1.9112, 1.9111, 1.9112]
# Test Accuracy: [0.10875, 0.11, 0.09875, 0.175, 0.10375, 0.23125, 0.0925, 0.10875, 0.08625, 0.1]
# Start of Epoch 4
# Average Train Loss: [1.9112, 1.9112, 1.9112, 2.2285, 1.9112, 2.2121, 1.9112, 1.9112, 1.9113, 1.9112]
# Test Accuracy: [0.12, 0.10125, 0.1175, 0.19625, 0.10875, 0.24875, 0.09375, 0.0775, 0.10625, 0.0875]
# Finished Training
# Elapsed Test Time: 7.891706466674805
# Elapsed Training Time: 16.328547954559326
# Final Test Accuracy: [0.0988, 0.1004, 0.0976, 0.1858, 0.1035, 0.2629, 0.0998, 0.0996, 0.1011, 0.101]
# Average training time 101.53763377666473
# Average test accuracy 0.13573500000000002
# Median test accuracy 0.10105
# Standard deviation test accuracy 0.06557132967234995

# %%
test_accs_dp50 = []
training_times_dp50 = []
for i in range(1):
    m = MultipleDecoder(50, separate_encoders=False, separate_decoders=False)
    m.train(dp=True, epochs=20)
    #m.fine_tune(epochs=5)
    test_accs_dp50.extend([x[-1] for x in m.test_accs])
    training_times_dp50.append(m.training_time)
print(f"Average training time", np.mean(training_times_dp50))
print(f"Average test accuracy", np.mean(test_accs_dp50))
print(f"Median test accuracy", np.median(test_accs_dp50))
print(f"Standard deviation test accuracy", np.std(test_accs_dp50))
# Out:
# data slice [5741, ..., 39095]
# data slice [10556, ..., 10595]
# data slice [24713, ..., 20261]
# data slice [284, ..., 51443]
# data slice [9303, ..., 25893]
# data slice [11041, ..., 8656]
# data slice [19335, ..., 40281]
# data slice [5724, ..., 17180]
# data slice [1463, ..., 58063]
# data slice [57553, ..., 37155]
# data slice [2977, ..., 29181]
# data slice [2082, ..., 15769]
# data slice [20986, ..., 6257]
# data slice [36067, ..., 7924]
# data slice [51302, ..., 10306]
# data slice [29597, ..., 40087]
# data slice [33555, ..., 6780]
# data slice [45772, ..., 57534]
# data slice [3066, ..., 8092]
# data slice [53606, ..., 29401]
# data slice [2862, ..., 37293]
# data slice [8480, ..., 13963]
# data slice [37957, ..., 6341]
# data slice [17912, ..., 33918]
# data slice [26143, ..., 39162]
# data slice [13637, ..., 58716]
# data slice [46469, ..., 35030]
# data slice [57241, ..., 29512]
# data slice [19921, ..., 12522]
# data slice [16303, ..., 2120]
# data slice [18242, ..., 22252]
# data slice [3121, ..., 42728]
# data slice [55566, ..., 17121]
# data slice [47969, ..., 16126]
# data slice [54036, ..., 16445]
# data slice [58791, ..., 50031]
# data slice [17046, ..., 55196]
# data slice [37161, ..., 36216]
# data slice [44150, ..., 54735]
# data slice [52683, ..., 11405]
# data slice [27207, ..., 31390]
# data slice [48268, ..., 6280]
# data slice [53514, ..., 37601]
# data slice [7936, ..., 1713]
# data slice [25370, ..., 42322]
# data slice [21772, ..., 51321]
# data slice [54088, ..., 18617]
# data slice [44651, ..., 3877]
# data slice [21333, ..., 10062]
# data slice [28628, ..., 26255]
# Start of Epoch 0
# Average Train Loss: [1.6128, 1.6111, 1.6179, 1.6144, 1.6293, 1.6158, 1.6281, 1.6104, 1.615, 1.6279, 1.6061, 1.6138, 1.6108, 1.6141, 1.6045, 1.6234, 1.6139, 1.6012, 1.6094, 1.609, 1.6218, 1.6187, 1.6145, 1.6183, 1.5993, 1.6195, 1.6184, 1.6189, 1.6231, 1.622, 1.6069, 1.6096, 1.6181, 1.6158, 1.6049, 1.6128, 1.6324, 1.617, 1.616, 1.6144, 1.6206, 1.6044, 1.6124, 1.6064, 1.6226, 1.6163, 1.6237, 1.6146, 1.6033, 1.6198]
# Test Accuracy: [0.98625, 0.9825, 0.98875, 0.9825, 0.98, 0.98375, 0.98875, 0.98625, 0.99, 0.98, 0.98625, 0.98125, 0.98375, 0.9825, 0.99375, 0.98875, 0.9825, 0.98, 0.98875, 0.985, 0.98375, 0.97875, 0.97375, 0.9825, 0.97875, 0.98, 0.98375, 0.98375, 0.98125, 0.9875, 0.98, 0.975, 0.98125, 0.98375, 0.97375, 0.9825, 0.9875, 0.9775, 0.9875, 0.99, 0.98375, 0.98375, 0.98125, 0.99, 0.97875, 0.97875, 0.9875, 0.98125, 0.98125, 0.9875]
# Start of Epoch 6
# Average Train Loss: [1.5935, 1.5923, 1.598, 1.594, 1.6081, 1.596, 1.6074, 1.5909, 1.5952, 1.6073, 1.5881, 1.5949, 1.591, 1.5956, 1.5859, 1.6019, 1.5959, 1.5834, 1.5908, 1.5902, 1.6013, 1.5991, 1.5942, 1.5984, 1.5815, 1.5995, 1.5991, 1.5981, 1.6023, 1.6015, 1.5883, 1.5916, 1.5991, 1.5966, 1.5866, 1.5936, 1.6114, 1.5975, 1.5966, 1.5941, 1.6005, 1.5858, 1.5929, 1.5881, 1.6022, 1.5962, 1.6019, 1.5948, 1.5855, 1.6]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-9c4504013ee4> in <module>
#       3 for i in range(1):
#       4     m = MultipleDecoder(50, separate_encoders=False, separate_decoders=False)
# ----> 5     m.train(dp=True, epochs=20)
#       6     #m.fine_tune(epochs=5)
#       7     test_accs_dp50.extend([x[-1] for x in m.test_accs])
#
# <ipython-input-39-a707d6752f70> in train(self, epochs, train_steps_per_epoch, test_steps_per_epoch, final_test_steps, randomize_order, dp)
#      85                         else:
#      86                             decoder = self.decoder
# ---> 87                         self.test_accs[i].append(encdec_accuracy(encoder, decoder, self.test_data_generators[i], self.test_steps_per_epoch, device=self.device))
#      88
#      89                     test_accs = [x[-1] for x in self.test_accs]
#
# <ipython-input-3-94a596447c4f> in encdec_accuracy(encoder, decoder, inf_gen, test_steps, device)
#       5     #grab a batch from the test loader
#       6     for j in range(test_steps):
# ----> 7         examples, labels = next(inf_gen)
#       8         embedding = encoder.forward(examples.to(device))
#       9         outputs = decoder.forward(embedding.to(device))
#
# <ipython-input-4-d044b9ce010e> in inf_loader_generator(dataloader)
#       4     '''
#       5     while True:
# ----> 6         for x, y in dataloader:
#       7             yield x, y
#
# ~/.conda/envs/csl/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     361
#     362     def __next__(self):
# --> 363         data = self._next_data()
#     364         self._num_yielded += 1
#     365         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/.conda/envs/csl/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     401     def _next_data(self):
#     402         index = self._next_index()  # may raise StopIteration
# --> 403         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     404         if self._pin_memory:
#     405             data = _utils.pin_memory.pin_memory(data)
#
# ~/.conda/envs/csl/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/.conda/envs/csl/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/.conda/envs/csl/lib/python3.7/site-packages/torchvision/datasets/mnist.py in __getitem__(self, index)
#      95
#      96         if self.transform is not None:
# ---> 97             img = self.transform(img)
#      98
#      99         if self.target_transform is not None:
#
# ~/.conda/envs/csl/lib/python3.7/site-packages/torchvision/transforms/transforms.py in __call__(self, pic)
#      90             Tensor: Converted image.
#      91         """
# ---> 92         return F.to_tensor(pic)
#      93
#      94     def __repr__(self):
#
# ~/.conda/envs/csl/lib/python3.7/site-packages/torchvision/transforms/functional.py in to_tensor(pic)
#      71     elif pic.mode == 'I;16':
#      72         img = torch.from_numpy(np.array(pic, np.int16, copy=False))
# ---> 73     elif pic.mode == 'F':
#      74         img = torch.from_numpy(np.array(pic, np.float32, copy=False))
#      75     elif pic.mode == '1':
#
# KeyboardInterrupt:

# %%
test_accs_dp50 = []
training_times_dp50 = []
for i in range(1):
    m = MultipleDecoder(50, separate_encoders=False, separate_decoders=True)
    m.train(dp=True, epochs=15)
    m.fine_tune(epochs=5)
    test_accs_dp50.extend([x[-1] for x in m.test_accs])
    training_times_dp50.append(m.training_time)
print(f"Average training time", np.mean(training_times_dp50))
print(f"Average test accuracy", np.mean(test_accs_dp50))
print(f"Median test accuracy", np.median(test_accs_dp50))
print(f"Standard deviation test accuracy", np.std(test_accs_dp50))

# %%
test_accs_dp50_model2 = []
training_times_dp50_model2 = []
for i in range(1):
    m = MultipleDecoder(50, separate_encoders=False, separate_decoders=True, first_models=False)
    m.train(dp=True, epochs=10)
    #m.fine_tune(epochs=5)
    test_accs_dp50_model2.extend([x[-1] for x in m.test_accs])
    training_times_dp50_model2.append(m.training_time)
print(f"Average training time", np.mean(training_times_dp50_model2))
print(f"Average test accuracy", np.mean(test_accs_dp50_model2))
print(f"Median test accuracy", np.median(test_accs_dp50_model2))
print(f"Standard deviation test accuracy", np.std(test_accs_dp50_model2))
# Out:
# Second Models
# <class '__main__.EncoderCNN2'>
# <class '__main__.DecoderCNN2'>
# data slice [59777, ..., 37279]
# data slice [41248, ..., 45637]
# data slice [15168, ..., 54969]
# data slice [10195, ..., 21091]
# data slice [41456, ..., 14622]
# data slice [37525, ..., 25592]
# data slice [12347, ..., 45574]
# data slice [8652, ..., 18556]
# data slice [34738, ..., 17517]
# data slice [10270, ..., 3954]
# data slice [19384, ..., 50780]
# data slice [52044, ..., 12710]
# data slice [50291, ..., 51349]
# data slice [33569, ..., 71]
# data slice [24889, ..., 9777]
# data slice [37978, ..., 8065]
# data slice [13147, ..., 494]
# data slice [8181, ..., 13964]
# data slice [37635, ..., 10193]
# data slice [36098, ..., 44051]
# data slice [34847, ..., 42279]
# data slice [19829, ..., 30986]
# data slice [46516, ..., 497]
# data slice [13728, ..., 35331]
# data slice [58696, ..., 51614]
# data slice [11451, ..., 14766]
# data slice [49805, ..., 58196]
# data slice [34117, ..., 41212]
# data slice [26638, ..., 28394]
# data slice [48011, ..., 23695]
# data slice [49991, ..., 45852]
# data slice [29863, ..., 20121]
# data slice [50510, ..., 19467]
# data slice [10425, ..., 5787]
# data slice [12512, ..., 40405]
# data slice [44516, ..., 50975]
# data slice [15826, ..., 53568]
# data slice [5583, ..., 28245]
# data slice [44264, ..., 10316]
# data slice [27498, ..., 11805]
# data slice [24775, ..., 13954]
# data slice [10329, ..., 19443]
# data slice [56341, ..., 22020]
# data slice [45214, ..., 56878]
# data slice [3504, ..., 52461]
# data slice [48688, ..., 38963]
# data slice [55415, ..., 17188]
# data slice [9948, ..., 37314]
# data slice [17733, ..., 16170]
# data slice [52288, ..., 30223]
# Start of Epoch 0
# Average Train Loss: [1.9182, 1.8768, 2.0343, 1.913, 1.9345, 2.0433, 2.0531, 2.0271, 2.0945, 1.999, 2.0136, 2.109, 2.0202, 2.0619, 2.0821, 2.0129, 2.1881, 2.0701, 2.0466, 1.9332, 2.167, 1.9293, 2.0434, 2.0482, 2.0074, 2.199, 1.9974, 2.0843, 1.924, 2.1924, 1.9484, 2.0755, 2.1488, 2.1105, 1.9651, 2.0282, 1.9143, 2.0835, 1.8741, 1.9275, 2.0402, 2.0313, 1.9819, 1.9584, 2.0725, 2.1449, 1.8934, 1.9796, 2.0873, 1.9928]
# Test Accuracy: [0.62625, 0.7, 0.47875, 0.68, 0.61625, 0.45625, 0.49375, 0.5075, 0.49, 0.555, 0.61875, 0.445, 0.46375, 0.43375, 0.48625, 0.5975, 0.46875, 0.51875, 0.53, 0.5975, 0.3875, 0.68125, 0.47625, 0.48375, 0.5225, 0.2825, 0.55125, 0.56625, 0.62625, 0.32625, 0.6375, 0.50375, 0.2775, 0.57125, 0.585, 0.465, 0.7725, 0.47625, 0.6525, 0.59125, 0.49375, 0.655, 0.5775, 0.65875, 0.53625, 0.345, 0.6675, 0.51, 0.465, 0.61125]

    #m.fine_tune(epochs=5)
    test_accs_dp50.extend([x[-1] for x in m.test_accs])
    training_times_dp50.append(m.training_time)
print(f"Average training time", np.mean(training_times_dp50))
print(f"Average test accuracy", np.mean(test_accs_dp50))
print(f"Median test accuracy", np.median(test_accs_dp50))
print(f"Standard deviation test accuracy", np.std(test_accs_dp50))
# Out:
# Second Models
# <class '__main__.EncoderCNN2'>
# <class '__main__.DecoderCNN2'>
# data slice [47387, ..., 50411]
# data slice [38402, ..., 11526]
# data slice [34259, ..., 31960]
# data slice [55124, ..., 46603]
# data slice [14784, ..., 7840]
# data slice [19025, ..., 34650]
# data slice [40248, ..., 4900]
# data slice [27165, ..., 6902]
# data slice [31486, ..., 23430]
# data slice [22183, ..., 56559]
# data slice [13332, ..., 56538]
# data slice [16903, ..., 12997]
# data slice [43440, ..., 19179]
# data slice [6403, ..., 6641]
# data slice [47579, ..., 24518]
# data slice [40815, ..., 53825]
# data slice [59186, ..., 10152]
# data slice [17392, ..., 39594]
# data slice [49178, ..., 42996]
# data slice [7488, ..., 16110]
# data slice [30477, ..., 18050]
# data slice [17576, ..., 33427]
# data slice [42399, ..., 57708]
# data slice [17659, ..., 17510]
# data slice [45679, ..., 31855]
# data slice [9445, ..., 44348]
# data slice [39660, ..., 1626]
# data slice [15229, ..., 30402]
# data slice [49767, ..., 17347]
# data slice [16723, ..., 32576]
# data slice [19496, ..., 11751]
# data slice [54755, ..., 51785]
# data slice [9930, ..., 28246]
# data slice [15632, ..., 30775]
# data slice [40803, ..., 21011]
# data slice [50005, ..., 44329]
# data slice [22249, ..., 15044]
# data slice [19811, ..., 21996]
# data slice [9294, ..., 9534]
# data slice [26210, ..., 15089]
# data slice [14655, ..., 13190]
# data slice [34749, ..., 20765]
# data slice [1859, ..., 38731]
# data slice [35984, ..., 18703]
# data slice [38605, ..., 38453]
# data slice [38007, ..., 23713]
# data slice [22359, ..., 11315]
# data slice [4383, ..., 13447]
# data slice [36110, ..., 45598]
# data slice [50307, ..., 10858]
# Start of Epoch 0
# Average Train Loss: [2.033, 2.0516, 2.1097, 1.9696, 2.0038, 1.9768, 2.0642, 2.03, 1.976, 2.1392, 1.9318, 2.0045, 2.0485, 1.922, 2.1139, 2.0132, 2.0453, 1.9883, 1.9249, 2.0538, 2.0135, 1.9909, 2.0634, 1.9821, 2.0261, 2.0541, 2.0123, 2.101, 2.0149, 2.1259, 2.1047, 1.9822, 1.9691, 1.9492, 2.0666, 1.9922, 1.9985, 2.0955, 1.9721, 2.1322, 1.971, 2.0719, 2.0995, 1.9873, 1.9686, 1.9732, 1.9952, 1.9952, 1.913, 1.9565]
# Test Accuracy: [0.62625, 0.62875, 0.445, 0.60875, 0.58875, 0.60625, 0.455, 0.55625, 0.6625, 0.52875, 0.58375, 0.57625, 0.4775, 0.7, 0.46375, 0.6275, 0.47125, 0.62375, 0.64375, 0.575, 0.64625, 0.67875, 0.5275, 0.57, 0.54125, 0.515, 0.52125, 0.43375, 0.6475, 0.455, 0.4325, 0.56, 0.60125, 0.63375, 0.4425, 0.59125, 0.53125, 0.42875, 0.56875, 0.4475, 0.645, 0.40125, 0.49625, 0.59375, 0.615, 0.55375, 0.5975, 0.58125, 0.785, 0.51625]
# Start of Epoch 1
# Average Train Loss: [1.8762, 1.9802, 2.0233, 1.8527, 1.9115, 1.913, 2.0097, 1.9275, 1.8993, 1.9949, 1.8733, 1.9196, 2.0296, 1.8386, 2.0183, 1.9095, 1.9774, 1.9097, 1.8658, 1.9621, 1.8819, 1.852, 1.9575, 1.9189, 1.9324, 1.9689, 1.9834, 2.0397, 1.9036, 2.0298, 2.0561, 1.9239, 1.9011, 1.871, 2.0122, 1.9103, 1.9284, 2.0552, 1.919, 1.995, 1.8923, 2.021, 1.9874, 1.9203, 1.897, 1.9012, 1.9128, 1.9338, 1.7908, 1.8996]
# Start of Epoch 4
# Average Train Loss: [1.7278, 1.9132, 1.9346, 1.7156, 1.8263, 1.8486, 1.9272, 1.798, 1.813, 1.7844, 1.7935, 1.8386, 1.9753, 1.7638, 1.8041, 1.8044, 1.8642, 1.8441, 1.8088, 1.8381, 1.7504, 1.7154, 1.8465, 1.8038, 1.8398, 1.858, 1.9622, 1.9304, 1.7948, 1.8407, 2.0179, 1.784, 1.841, 1.8035, 1.8769, 1.8129, 1.8432, 2.0115, 1.7978, 1.8064, 1.8147, 1.9402, 1.8407, 1.8427, 1.8113, 1.8245, 1.8369, 1.8682, 1.7022, 1.8229]
# Test Accuracy: [0.83, 0.6225, 0.59, 0.83, 0.7175, 0.64375, 0.68875, 0.83, 0.71875, 0.8, 0.7375, 0.68, 0.62, 0.7725, 0.83625, 0.71625, 0.81875, 0.67125, 0.68, 0.7225, 0.81125, 0.8325, 0.65125, 0.785, 0.64875, 0.70625, 0.48875, 0.61625, 0.745, 0.8525, 0.46125, 0.845, 0.6475, 0.66, 0.68125, 0.85125, 0.7375, 0.515, 0.7575, 0.82875, 0.74125, 0.61625, 0.7425, 0.6575, 0.67625, 0.66125, 0.66875, 0.6825, 0.83125, 0.63]
# Finished Training
# Elapsed Test Time: 39.6666305065155
# Elapsed Training Time: 82.29905390739441
# Final Test Accuracy: [0.8247, 0.6398, 0.5781, 0.829, 0.6853, 0.6515, 0.6431, 0.8003, 0.7364, 0.7966, 0.7356, 0.6382, 0.5795, 0.7472, 0.8225, 0.7463, 0.8031, 0.663, 0.6757, 0.73, 0.8146, 0.8327, 0.6572, 0.7611, 0.6725, 0.7354, 0.4943, 0.645, 0.7318, 0.8298, 0.4563, 0.8327, 0.6567, 0.668, 0.6648, 0.8329, 0.739, 0.5204, 0.7511, 0.816, 0.7517, 0.6487, 0.7323, 0.6708, 0.7184, 0.6753, 0.6546, 0.6612, 0.8309, 0.6412]
# Average training time 82.29905390739441
# Average test accuracy 0.7084659999999999
# Median test accuracy 0.7242
# Standard deviation test accuracy 0.0903938883111021

# %%
test_accs_dp50 = []
training_times_dp50 = []
for i in range(1):
    m = MultipleDecoder(50, separate_encoders=False, separate_decoders=False, first_models=False)
    m.train(dp=False, epochs=5)
    #m.fine_tune(epochs=5)
    test_accs_dp50.extend([x[-1] for x in m.test_accs])
    training_times_dp50.append(m.training_time)
print(f"Average training time", np.mean(training_times_dp50))
print(f"Average test accuracy", np.mean(test_accs_dp50))
print(f"Median test accuracy", np.median(test_accs_dp50))
print(f"Standard deviation test accuracy", np.std(test_accs_dp50))
# Out:
# Second Models
# <class '__main__.EncoderCNN2'>
# <class '__main__.DecoderCNN2'>
# data slice [48951, ..., 51895]
# data slice [288, ..., 28838]
# data slice [44617, ..., 21906]
# data slice [48743, ..., 7754]
# data slice [19662, ..., 27489]
# data slice [45624, ..., 49295]
# data slice [4051, ..., 14852]
# data slice [39420, ..., 37271]
# data slice [39689, ..., 47073]
# data slice [20887, ..., 7802]
# data slice [42985, ..., 48375]
# data slice [5392, ..., 34999]
# data slice [9972, ..., 36040]
# data slice [2869, ..., 6763]
# data slice [28842, ..., 32444]
# data slice [35699, ..., 27398]
# data slice [21472, ..., 38715]
# data slice [53107, ..., 11227]
# data slice [22461, ..., 57300]
# data slice [5065, ..., 52706]
# data slice [6894, ..., 52505]
# data slice [26498, ..., 16571]
# data slice [36814, ..., 21050]
# data slice [51510, ..., 54366]
# data slice [8054, ..., 25817]
# data slice [18960, ..., 1233]
# data slice [7190, ..., 16605]
# data slice [50142, ..., 19033]
# data slice [51322, ..., 27584]
# data slice [37068, ..., 7364]
# data slice [1528, ..., 3317]
# data slice [29253, ..., 3090]
# data slice [59506, ..., 23059]
# data slice [47959, ..., 48477]
# data slice [37446, ..., 8999]
# data slice [54062, ..., 22139]
# data slice [23399, ..., 17396]
# data slice [57516, ..., 42944]
# data slice [52311, ..., 17351]
# data slice [41316, ..., 44736]
# data slice [29797, ..., 52322]
# data slice [29129, ..., 36275]
# data slice [25080, ..., 14895]
# data slice [21704, ..., 14363]
# data slice [13960, ..., 28947]
# data slice [29204, ..., 41017]
# data slice [147, ..., 14431]
# data slice [6704, ..., 29296]
# data slice [30547, ..., 43659]
# data slice [12429, ..., 36999]
# Start of Epoch 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-f8f9afc22001> in <module>
#       3 for i in range(1):
#       4     m = MultipleDecoder(50, separate_encoders=False, separate_decoders=False, first_models=False)
# ----> 5     m.train(dp=False, epochs=5)
#       6     #m.fine_tune(epochs=5)
#       7     test_accs_dp50.extend([x[-1] for x in m.test_accs])
#
# <ipython-input-60-2be0eeab1281> in train(self, epochs, train_steps_per_epoch, test_steps_per_epoch, final_test_steps, randomize_order, dp)
#      76                 print("Start of Epoch", (self.model_steps // self.train_steps_per_epoch))
#      77
# ---> 78             self._train_batch(dp=dp)
#      79
#      80             if self.model_steps % self.train_steps_per_epoch == 0:
#
# <ipython-input-60-2be0eeab1281> in _train_batch(self, dp)
#     148                 self._train_decoder_batch_dp(i)
#     149             else:
# --> 150                 self._train_decoder_batch_no_dp(i)
#     151
#     152         self.model_steps += 1
#
# <ipython-input-60-2be0eeab1281> in _train_decoder_batch_no_dp(self, i)
#     171             decoder_criterion = self.decoder_criterion
#     172
# --> 173         x_batch_train, y_batch_train = (x.to(self.device) for x in next(self.train_data_generators[i]))
#     174         encoder_optimizer.zero_grad()
#     175         decoder_optimizer.zero_grad()
#
# <ipython-input-4-d044b9ce010e> in inf_loader_generator(dataloader)
#       4     '''
#       5     while True:
# ----> 6         for x, y in dataloader:
#       7             yield x, y
#
# ~/.conda/envs/csl/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     361
#     362     def __next__(self):
# --> 363         data = self._next_data()
#     364         self._num_yielded += 1
#     365         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/.conda/envs/csl/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     401     def _next_data(self):
#     402         index = self._next_index()  # may raise StopIteration
# --> 403         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     404         if self._pin_memory:
#     405             data = _utils.pin_memory.pin_memory(data)
#
# ~/.conda/envs/csl/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/.conda/envs/csl/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/.conda/envs/csl/lib/python3.7/site-packages/torch/utils/data/dataset.py in __getitem__(self, idx)
#     255
#     256     def __getitem__(self, idx):
# --> 257         return self.dataset[self.indices[idx]]
#     258
#     259     def __len__(self):
#
# ~/.conda/envs/csl/lib/python3.7/site-packages/torchvision/datasets/mnist.py in __getitem__(self, index)
#      95
#      96         if self.transform is not None:
# ---> 97             img = self.transform(img)
#      98
#      99         if self.target_transform is not None:
#
# ~/.conda/envs/csl/lib/python3.7/site-packages/torchvision/transforms/transforms.py in __call__(self, pic)
#      90             Tensor: Converted image.
#      91         """
# ---> 92         return F.to_tensor(pic)
#      93
#      94     def __repr__(self):
#
# ~/.conda/envs/csl/lib/python3.7/site-packages/torchvision/transforms/functional.py in to_tensor(pic)
#      76         img = 255 * torch.from_numpy(np.array(pic, np.uint8, copy=False))
#      77     else:
# ---> 78         img = torch.ByteTensor(torch.ByteStorage.from_buffer(pic.tobytes()))
#      79
#      80     img = img.view(pic.size[1], pic.size[0], len(pic.getbands()))
#
# ~/.conda/envs/csl/lib/python3.7/site-packages/PIL/Image.py in tobytes(self, encoder_name, *args)
#     733         # unpack data
#     734         e = _getencoder(self.mode, encoder_name, args)
# --> 735         e.setimage(self.im)
#     736
#     737         bufsize = max(65536, self.size[0] * 4)  # see RawEncode.c
#
# KeyboardInterrupt:

# %%
test_accs_dp50 = []
training_times_dp50 = []
for i in range(1):
    m = MultipleDecoder(50, separate_encoders=False, separate_decoders=False, first_models=False)
    m.train(dp=True, epochs=5)
    #m.fine_tune(epochs=5)
    test_accs_dp50.extend([x[-1] for x in m.test_accs])
    training_times_dp50.append(m.training_time)
print(f"Average training time", np.mean(training_times_dp50))
print(f"Average test accuracy", np.mean(test_accs_dp50))
print(f"Median test accuracy", np.median(test_accs_dp50))
print(f"Standard deviation test accuracy", np.std(test_accs_dp50))
# Out:
# Second Models
# <class '__main__.EncoderCNN2'>
# <class '__main__.DecoderCNN2'>
# data slice [33286, ..., 41292]
# data slice [34415, ..., 27939]
# data slice [25912, ..., 45452]
# data slice [59661, ..., 55808]
# data slice [38928, ..., 23294]
# data slice [53778, ..., 4832]
# data slice [34234, ..., 30148]
# data slice [3416, ..., 10645]
# data slice [44282, ..., 35642]
# data slice [25464, ..., 11777]
# data slice [18876, ..., 4946]
# data slice [47729, ..., 15338]
# data slice [11697, ..., 17919]
# data slice [41584, ..., 41483]
# data slice [25309, ..., 35004]
# data slice [7838, ..., 42039]
# data slice [47036, ..., 38068]
# data slice [23779, ..., 55128]
# data slice [8551, ..., 5642]
# data slice [26662, ..., 32384]
# data slice [17249, ..., 16789]
# data slice [47554, ..., 52650]
# data slice [25768, ..., 37640]
# data slice [14239, ..., 29599]
# data slice [45384, ..., 45976]
# data slice [47772, ..., 6640]
# data slice [58639, ..., 38242]
# data slice [46334, ..., 4548]
# data slice [24565, ..., 29765]
# data slice [15701, ..., 43398]
# data slice [14123, ..., 18106]
# data slice [13051, ..., 19295]
# data slice [151, ..., 29255]
# data slice [20739, ..., 27676]
# data slice [3171, ..., 23095]
# data slice [22228, ..., 6460]
# data slice [52712, ..., 45407]
# data slice [6067, ..., 56767]
# data slice [30763, ..., 44907]
# data slice [36242, ..., 15635]
# data slice [24339, ..., 37073]
# data slice [23866, ..., 9492]
# data slice [41343, ..., 50935]
# data slice [15487, ..., 56086]
# data slice [16473, ..., 44923]
# data slice [48206, ..., 13677]
# data slice [10000, ..., 5473]
# data slice [58603, ..., 59128]
# data slice [43251, ..., 55359]
# data slice [52863, ..., 59848]
# Start of Epoch 0
# Average Train Loss: [1.7845, 1.7684, 1.7649, 1.799, 1.7658, 1.7796, 1.78, 1.7708, 1.7785, 1.7758, 1.755, 1.7688, 1.7637, 1.7606, 1.7533, 1.7697, 1.7635, 1.7759, 1.7762, 1.7597, 1.7621, 1.7687, 1.7648, 1.7729, 1.7695, 1.7427, 1.7735, 1.7781, 1.7824, 1.7672, 1.7498, 1.7673, 1.7765, 1.7739, 1.7518, 1.7632, 1.7573, 1.7791, 1.7555, 1.7502, 1.7943, 1.774, 1.761, 1.7811, 1.7688, 1.7535, 1.7704, 1.7656, 1.763, 1.7592]
# Test Accuracy: [0.68125, 0.68875, 0.6725, 0.6825, 0.69625, 0.66125, 0.68875, 0.68875, 0.68875, 0.66375, 0.66375, 0.66875, 0.68625, 0.655, 0.6975, 0.65, 0.7025, 0.69, 0.65625, 0.69125, 0.655, 0.6825, 0.665, 0.6875, 0.65375, 0.66875, 0.66375, 0.66625, 0.6375, 0.67125, 0.67, 0.68, 0.68375, 0.64625, 0.67125, 0.67, 0.665, 0.67625, 0.675, 0.65375, 0.66625, 0.69125, 0.65625, 0.695, 0.66, 0.6475, 0.66375, 0.65375, 0.66125, 0.64875]
# Start of Epoch 1
# Average Train Loss: [1.7652, 1.7507, 1.7481, 1.7824, 1.7447, 1.7644, 1.7636, 1.7564, 1.7548, 1.7599, 1.7375, 1.7529, 1.7456, 1.7475, 1.7368, 1.7488, 1.7447, 1.7591, 1.7598, 1.7425, 1.7469, 1.7506, 1.747, 1.7564, 1.7548, 1.7272, 1.7566, 1.7618, 1.7686, 1.756, 1.7359, 1.7494, 1.76, 1.755, 1.735, 1.7481, 1.7421, 1.7664, 1.7428, 1.7363, 1.7804, 1.7616, 1.7466, 1.7679, 1.7564, 1.7394, 1.7504, 1.7486, 1.7474, 1.7438]
# Start of Epoch 4
# Average Train Loss: [1.7083, 1.6941, 1.6835, 1.7268, 1.688, 1.7105, 1.7105, 1.7031, 1.7084, 1.701, 1.6826, 1.7037, 1.6901, 1.695, 1.682, 1.6943, 1.6897, 1.7023, 1.7131, 1.6872, 1.6974, 1.6964, 1.7019, 1.703, 1.6985, 1.6812, 1.7096, 1.71, 1.7165, 1.706, 1.6897, 1.6969, 1.7043, 1.6977, 1.6918, 1.6948, 1.6928, 1.7167, 1.6881, 1.6751, 1.7204, 1.7132, 1.6916, 1.7087, 1.7074, 1.6924, 1.6935, 1.6947, 1.6949, 1.6965]
# Test Accuracy: [0.78375, 0.78125, 0.77625, 0.7675, 0.765, 0.76375, 0.785, 0.775, 0.78125, 0.7625, 0.7875, 0.77375, 0.785, 0.77625, 0.77, 0.77125, 0.7725, 0.7925, 0.79, 0.775, 0.77875, 0.775, 0.8025, 0.78375, 0.75875, 0.795, 0.78875, 0.79, 0.78375, 0.79875, 0.76625, 0.76875, 0.77875, 0.79125, 0.7975, 0.76875, 0.76125, 0.79125, 0.76375, 0.78625, 0.785, 0.775, 0.78, 0.7775, 0.7725, 0.775, 0.76375, 0.8075, 0.7675, 0.7775]
# Finished Training
# Elapsed Test Time: 39.64940333366394
# Elapsed Training Time: 156.47980523109436
# Final Test Accuracy: [0.7754, 0.7758, 0.7797, 0.7731, 0.7796, 0.7773, 0.7793, 0.7813, 0.7805, 0.7799, 0.7863, 0.7767, 0.7775, 0.7805, 0.7803, 0.7777, 0.7765, 0.7731, 0.7764, 0.7776, 0.7764, 0.7769, 0.7768, 0.7798, 0.7817, 0.7775, 0.7794, 0.7754, 0.7783, 0.7825, 0.7773, 0.779, 0.7755, 0.7812, 0.7717, 0.7778, 0.7815, 0.778, 0.7776, 0.7784, 0.7787, 0.7729, 0.7829, 0.7759, 0.7822, 0.7841, 0.782, 0.778, 0.7811, 0.7771]
# Average training time 156.47980523109436
# Average test accuracy 0.778442
# Median test accuracy 0.778
# Standard deviation test accuracy 0.002910607496726411

# %%
test_accs_dp50 = []
training_times_dp50 = []
for i in range(1):
    m = MultipleDecoder(50, separate_encoders=False, separate_decoders=False, first_models=False, epsilon=1e5)
    m.train(dp=True, epochs=5)
    #m.fine_tune(epochs=5)
    test_accs_dp50.extend([x[-1] for x in m.test_accs])
    training_times_dp50.append(m.training_time)
print(f"Average training time", np.mean(training_times_dp50))
print(f"Average test accuracy", np.mean(test_accs_dp50))
print(f"Median test accuracy", np.median(test_accs_dp50))
print(f"Standard deviation test accuracy", np.std(test_accs_dp50))
# Out:
# Second Models
# <class '__main__.EncoderCNN2'>
# <class '__main__.DecoderCNN2'>
# data slice [45148, ..., 46796]
# data slice [28511, ..., 141]
# data slice [49368, ..., 58275]
# data slice [39335, ..., 34017]
# data slice [39537, ..., 16037]
# data slice [58780, ..., 31033]
# data slice [8599, ..., 28540]
# data slice [25260, ..., 921]
# data slice [33580, ..., 24848]
# data slice [3023, ..., 44457]
# data slice [6650, ..., 24919]
# data slice [30697, ..., 26891]
# data slice [50977, ..., 1882]
# data slice [45833, ..., 59446]
# data slice [24520, ..., 52656]
# data slice [25581, ..., 7045]
# data slice [33943, ..., 30192]
# data slice [7477, ..., 8074]
# data slice [39441, ..., 41724]
# data slice [1050, ..., 18636]
# data slice [2272, ..., 4349]
# data slice [16344, ..., 57775]
# data slice [26781, ..., 11060]
# data slice [20857, ..., 6307]
# data slice [34107, ..., 58433]
# data slice [38652, ..., 49018]
# data slice [2003, ..., 34918]
# Test Accuracy: [0.12125, 0.1025, 0.125, 0.125, 0.10375, 0.115, 0.11375, 0.1, 0.11125, 0.1075, 0.1175, 0.115, 0.1025, 0.11375, 0.1225, 0.10375, 0.11625, 0.10375, 0.10875, 0.1125, 0.11375, 0.09, 0.12625, 0.09875, 0.125, 0.1125, 0.115, 0.1075, 0.105, 0.11875, 0.10625, 0.12375, 0.10125, 0.10125, 0.10625, 0.0975, 0.12125, 0.135, 0.12375, 0.12, 0.11625, 0.1225, 0.125, 0.1175, 0.1225, 0.11125, 0.1175, 0.1325, 0.105, 0.10875]
# Finished Training
# Elapsed Test Time: 39.84725785255432
# Elapsed Training Time: 157.03271079063416
# Final Test Accuracy: [0.1141, 0.1156, 0.1149, 0.1123, 0.1113, 0.1112, 0.1124, 0.1135, 0.1128, 0.1135, 0.1153, 0.1152, 0.1146, 0.1155, 0.1101, 0.1134, 0.1168, 0.1135, 0.1133, 0.1123, 0.1159, 0.1108, 0.1098, 0.1165, 0.1139, 0.113, 0.1142, 0.1117, 0.1126, 0.1154, 0.1145, 0.1148, 0.114, 0.116, 0.1162, 0.1182, 0.1166, 0.1127, 0.1137, 0.1149, 0.1131, 0.1167, 0.1097, 0.1124, 0.1172, 0.1131, 0.1106, 0.1131, 0.1131, 0.1123]
# Average training time 157.03271079063416
# Average test accuracy 0.11376599999999999
# Median test accuracy 0.1135
# Standard deviation test accuracy 0.0019846017232684247

# %%
test_accs_dp50 = []
training_times_dp50 = []
for i in range(1):
    m = MultipleDecoder(50, separate_encoders=False, separate_decoders=False, first_models=False, epsilon=1e4)
    m.train(dp=True, epochs=5)
    #m.fine_tune(epochs=5)
    test_accs_dp50.extend([x[-1] for x in m.test_accs])
    training_times_dp50.append(m.training_time)
print(f"Average training time", np.mean(training_times_dp50))
print(f"Average test accuracy", np.mean(test_accs_dp50))
print(f"Median test accuracy", np.median(test_accs_dp50))
print(f"Standard deviation test accuracy", np.std(test_accs_dp50))
# Out:
# Second Models
# <class '__main__.EncoderCNN2'>
# <class '__main__.DecoderCNN2'>
# data slice [15066, ..., 43241]
# data slice [13611, ..., 3283]
# data slice [58943, ..., 25935]
# data slice [46744, ..., 40816]
# data slice [59200, ..., 17881]
# data slice [12701, ..., 49888]
# data slice [39311, ..., 2300]
# data slice [31170, ..., 46435]
# data slice [8387, ..., 38056]
# data slice [12254, ..., 11408]
# data slice [58422, ..., 35041]
# data slice [1934, ..., 699]
# data slice [24116, ..., 150]
# data slice [43974, ..., 16966]
# data slice [53943, ..., 51544]
# data slice [22945, ..., 40589]
# data slice [35001, ..., 17535]
# data slice [8283, ..., 29172]
# data slice [28075, ..., 20472]
# data slice [23843, ..., 44753]
# data slice [32746, ..., 17587]
# data slice [52109, ..., 9974]
# data slice [47416, ..., 22551]
# data slice [28557, ..., 55893]
# data slice [52687, ..., 46598]
# data slice [48308, ..., 11771]
# data slice [10585, ..., 23942]
# data slice [2503, ..., 26624]
# data slice [59400, ..., 4835]
# data slice [42481, ..., 58177]
# data slice [41564, ..., 43903]
# data slice [832, ..., 50951]
# data slice [43653, ..., 54221]
# data slice [2455, ..., 43946]
# data slice [12222, ..., 56733]
# data slice [34951, ..., 4447]
# data slice [26303, ..., 43841]
# data slice [3820, ..., 25889]
# data slice [3316, ..., 57173]
# data slice [45993, ..., 34283]
# data slice [41527, ..., 57236]
# data slice [10862, ..., 5756]
# data slice [13837, ..., 13469]
# data slice [47569, ..., 15385]
# data slice [35037, ..., 42917]
# data slice [8444, ..., 7134]
# data slice [51302, ..., 53322]
# Finished Training
# Elapsed Test Time: 39.72625517845154
# Elapsed Training Time: 156.50892686843872
# Final Test Accuracy: [0.8613, 0.8617, 0.86, 0.8623, 0.8591, 0.8623, 0.863, 0.8652, 0.8634, 0.8612, 0.8619, 0.8608, 0.862, 0.8623, 0.8642, 0.8579, 0.8618, 0.8622, 0.8624, 0.8594, 0.8581, 0.8633, 0.8626, 0.8621, 0.8589, 0.8649, 0.8626, 0.8593, 0.8601, 0.8629, 0.8637, 0.8649, 0.8614, 0.8606, 0.861, 0.8584, 0.8614, 0.8611, 0.8614, 0.8636, 0.8595, 0.864, 0.8652, 0.8626, 0.864, 0.8629, 0.8601, 0.8577, 0.8645, 0.8658]
# Average training time 156.50892686843872
# Average test accuracy 0.86186
# Median test accuracy 0.86205
# Standard deviation test accuracy 0.0020184152199188327

# %%
test_accs_dp50 = []
training_times_dp50 = []
for i in range(1):
    m = MultipleDecoder(50, separate_encoders=False, separate_decoders=False, first_models=False, epsilon=1e3)
    m.train(dp=True, epochs=5)
    #m.fine_tune(epochs=5)
    test_accs_dp50.extend([x[-1] for x in m.test_accs])
    training_times_dp50.append(m.training_time)
print(f"Average training time", np.mean(training_times_dp50))
print(f"Average test accuracy", np.mean(test_accs_dp50))
print(f"Median test accuracy", np.median(test_accs_dp50))
print(f"Standard deviation test accuracy", np.std(test_accs_dp50))
# Out:
# Second Models
# <class '__main__.EncoderCNN2'>
# <class '__main__.DecoderCNN2'>
# data slice [51995, ..., 33509]
# data slice [16268, ..., 14633]
# data slice [57370, ..., 18119]
# data slice [40933, ..., 25656]
# data slice [14007, ..., 4418]
# data slice [14904, ..., 37527]
# data slice [23811, ..., 6122]
# data slice [50594, ..., 10511]
# data slice [43394, ..., 25894]
# data slice [20789, ..., 44529]
# data slice [18194, ..., 11372]
# data slice [11898, ..., 13684]
# data slice [24080, ..., 33605]
# data slice [6606, ..., 59509]
# data slice [52596, ..., 46896]
# data slice [17649, ..., 8488]
# data slice [35289, ..., 16487]
# data slice [47329, ..., 31557]
# data slice [13767, ..., 4245]
# data slice [41336, ..., 6132]
# data slice [58886, ..., 3983]
# data slice [52201, ..., 40382]
# data slice [41403, ..., 37320]
# data slice [29735, ..., 7076]
# data slice [43277, ..., 54617]
# data slice [49094, ..., 58138]
# data slice [29605, ..., 30846]
# data slice [4054, ..., 33357]
# data slice [2792, ..., 44610]
# data slice [50058, ..., 54026]
# data slice [49353, ..., 42543]
# data slice [44649, ..., 29945]
# data slice [23596, ..., 10379]
# data slice [2721, ..., 41143]
# data slice [42952, ..., 24752]
# data slice [57677, ..., 29359]
# data slice [51187, ..., 47159]
# data slice [26670, ..., 32641]
# data slice [2754, ..., 7550]
# data slice [43627, ..., 643]
# data slice [4730, ..., 46248]
# data slice [15044, ..., 44390]
# data slice [3639, ..., 11925]
# data slice [16715, ..., 32869]
# data slice [28614, ..., 34454]
# data slice [39948, ..., 32053]
# data slice [42117, ..., 7823]
# data slice [15105, ..., 54971]
# data slice [51401, ..., 22894]
# data slice [8343, ..., 32522]
# Start of Epoch 0
# Final Test Accuracy: [0.1025, 0.1036, 0.1, 0.102, 0.1007, 0.1003, 0.1031, 0.103, 0.1003, 0.1019, 0.1038, 0.1035, 0.1055, 0.1026, 0.1042, 0.104, 0.1047, 0.1029, 0.1017, 0.0996, 0.1066, 0.1035, 0.1009, 0.1007, 0.1027, 0.0995, 0.1021, 0.1027, 0.1003, 0.1046, 0.1034, 0.1036, 0.1062, 0.1034, 0.1004, 0.1017, 0.1029, 0.0985, 0.102, 0.1045, 0.1012, 0.1051, 0.1022, 0.1001, 0.0988, 0.1056, 0.1062, 0.1026, 0.1049, 0.1024]
# Average training time 158.3410439491272
# Average test accuracy 0.102584
# Median test accuracy 0.10264999999999999
# Standard deviation test accuracy 0.0019661495365307286

# %%
class EmptyDecoder:
    def __init__(self, n, hidden_size=28, device=DEVICE, alpha=20, epsilon=1e6, first_models=True, separate_encoders=False, separate_decoders=False, dataset="mnist", same_decoder_init=False, unbalanced=False):
        """
        Creates n decoders for single encoder
        """
        self.device = device
        self.n = n
        self.hidden_size = hidden_size
        self.alpha = alpha
        self.epsilon = epsilon
        self.dataset = dataset
        
        if not first_models:
            print("Second Models")
            EncoderCNN = EncoderCNN2
            DecoderCNN = DecoderCNN2
            print(EncoderCNN)
            print(DecoderCNN)
        else:
            EncoderCNN = EncoderCNN2
            DecoderCNN = DecoderCNN
        
        self.separate_encoders = bool(separate_encoders)
        self.separate_decoders = bool(separate_decoders)
        if self.separate_encoders:
            self.encoders = []
            self.encoder_optimizers = []
            for i in range(self.n):
                self.encoders.append(EncoderCNN(1, self.hidden_size).to(self.device))
                self.encoder_optimizers.append(optim.Adam(self.encoders[i].parameters(),lr=0.001))
        else:
            self.encoder = EncoderCNN(1, self.hidden_size).to(self.device)
            self.encoder_optimizer = optim.Adam(self.encoder.parameters(),lr=0.001)
        
        self.decoder = DecoderCNN(self.hidden_size).to(self.device)
        self.decoder_criterion = nn.CrossEntropyLoss()
        
        if unbalanced:
            self.train_data_generators, self.test_data_generators = multiple_data_generators_unbalanced(self.n, batch_sizes=16, dataset=dataset)
        else:
            self.train_data_generators, self.test_data_generators = multiple_data_generators(self.n, batch_sizes=16, dataset=dataset)

    def train(self, epochs=20, train_steps_per_epoch=75, test_steps_per_epoch=50, final_test_steps=625, randomize_order=False, dp=True):
        self._train_init(epochs=epochs, train_steps_per_epoch=train_steps_per_epoch, test_steps_per_epoch=test_steps_per_epoch, randomize_order=randomize_order)
        
        import time
        start = time.time()
        elapsed_test_time = 0.0
        while True:
            if self.model_steps >= (self.train_steps_per_epoch*self.epochs):
                print("Finished Training")
                break
            if self.model_steps % self.train_steps_per_epoch == 0:
                print("Start of Epoch", (self.model_steps // self.train_steps_per_epoch))
  
            self._train_batch(dp=dp)

            if self.model_steps % self.train_steps_per_epoch == 0:
                train_losses = [round(10000 * np.mean(x))/10000 for x in self.train_losses]
                print(f"Average Train Loss:", train_losses)
                #for i in range(self.n):
                #    print(f"Average Train Loss for {i}:", np.mean(self.train_losses[i]))
                
                if test_steps_per_epoch:
                    start_test = time.time()
                    for i in range(self.n):
                        if self.separate_encoders:
                            encoder = self.encoders[i]
                        else:
                            encoder = self.encoder
                        
                        decoder = self.decoder
                        self.test_accs[i].append(encdec_accuracy(encoder, decoder, self.test_data_generators[i], self.test_steps_per_epoch, device=self.device))
                
                    test_accs = [x[-1] for x in self.test_accs]
                    print(f"Test Accuracy:", test_accs)
                    end_test = time.time()
                    elapsed_test_time += end_test - start_test
                #for i in range(self.n):
                #    print(f"Test Accuracy {i}:", self.test_accs[i][-1])
        
        end = time.time()
        elapsed = end - start
        self.training_time = elapsed - elapsed_test_time
        print(f"Elapsed Test Time:", elapsed_test_time)
        print(f"Elapsed Training Time:", self.training_time)
        for i in range(self.n):
            if self.separate_encoders:
                encoder = self.encoders[i]
            else:
                encoder = self.encoder
            decoder = self.decoder
            self.test_accs[i].append(encdec_accuracy(encoder, decoder, self.test_data_generators[i], final_test_steps, device=self.device))
            
        test_accs = [x[-1] for x in self.test_accs]
        print(f"Final Test Accuracy:", test_accs)
    
    def _train_init(self, epochs=20, train_steps_per_epoch=375, test_steps_per_epoch=100, randomize_order=False):
        self.epochs = epochs
        self.model_steps = 0
        if self.alpha is None or self.epsilon is None:
            self.epsilon_iter = None
        else:
            self.epsilon_iter = self.epsilon / self.epochs
        
        self.train_steps_per_epoch = train_steps_per_epoch
        self.test_steps_per_epoch = test_steps_per_epoch
        self.randomize_order = randomize_order
        
        # plotting criteria
        self.train_losses = [[] for x in range(self.n)]
        self.test_accs = [[] for x in range(self.n)]        

    def _train_batch(self, dp=True):
        index = list(range(self.n))
        if self.randomize_order:
            np.random.shuffle(index)
        
        for i in index:
            if dp:
                self._train_decoder_batch_dp(i)
            else:
                self._train_decoder_batch_no_dp(i)
        
        self.model_steps += 1
        
    def _train_decoder_batch_no_dp(self, i):
        """
        Train decoder i on the next batch without differential privacy
        """
        if self.separate_encoders:
            encoder = self.encoders[i]
            encoder_optimizer = self.encoder_optimizers[i]
        else:
            encoder = self.encoder
            encoder_optimizer = self.encoder_optimizer
        
        decoder = self.decoder
        decoder_criterion = self.decoder_criterion
        
        x_batch_train, y_batch_train = (x.to(self.device) for x in next(self.train_data_generators[i]))
        encoder_optimizer.zero_grad()
        
        # compute loss
        embedding = encoder.forward(x_batch_train)
        outputs = decoder.forward(embedding)
        loss = decoder_criterion(outputs, y_batch_train)

        loss.backward()
        self.train_losses[i].append(loss.item())

        # perform the a gradient step
        encoder_optimizer.step()
        
    def _train_decoder_batch_dp(self, i):
        """
        Train decoder i on the next batch using differential privacy
        """
        if self.separate_encoders:
            encoder = self.encoders[i]
            encoder_optimizer = self.encoder_optimizers[i]
        else:
            encoder = self.encoder
            encoder_optimizer = self.encoder_optimizer
        
        decoder = self.decoder
        decoder_criterion = self.decoder_criterion
        
        x_batch_train, y_batch_train = (x.to(self.device) for x in next(self.train_data_generators[i]))
        encoder_optimizer.zero_grad()
        
        # Need grad on input for sensitivity; not sure if cloning is needed
        x_batch_train = torch.autograd.Variable(torch.clone(x_batch_train).to(self.device), requires_grad=True)
        
        # compute loss
        embedding = encoder.forward(x_batch_train)
        outputs = decoder.forward(embedding)
        loss = decoder_criterion(outputs, y_batch_train)
        
        batch_sensitivities = compute_immediate_sensitivity(
            encoder, x_batch_train, loss
        )
        batch_sensitivity = torch.max(batch_sensitivities) / len(x_batch_train)
        
        loss.backward()
        # step 4. compute noise
        # this is the scale of the Gaussian noise to be added to the batch gradient
        sigma = torch.sqrt(
            (batch_sensitivity ** 2 * self.alpha) / (2 * self.epsilon_iter)
        )
        
        # logging
        #x = loss.item()
        #if np.isnan(x):
        #    log.debug(
        #        f"Epoch (before adj): {epoch}; batch_idx: {batch_idx} loss: {loss}"
        #    )
        #    x = 0
        #    log.debug(
        #        f"    epoch (adfter adj): {epoch}; batch_idx: {batch_idx} loss: {loss}"
        #    )
        #train_loss += x
        
        self.train_losses[i].append(loss.item())
        
        # step 5. update gradients with computed sensitivities
        with torch.no_grad():
            for p in encoder.parameters():
                p.grad += sigma * torch.randn(1).to(self.device)
        
        # perform the a gradient step
        encoder_optimizer.step()

    def fine_tune(self, dp=False, **kwargs):
        """
        Used to fine tune individual encoder / decoder pairs AFTER primary collective training
        """
        import copy
        self.separate_encoders = True
        if self.separate_encoders:
            self.encoders = []
            self.encoder_optimizers = []
            for i in range(self.n):
                self.encoders.append(copy.deepcopy(self.encoder).to(self.device))
                self.encoder_optimizers.append(optim.Adam(self.encoders[i].parameters(),lr=0.001))

        self.training_time_dp = self.training_time
        self.test_accs_dp = self.test_accs
        self.train(dp=dp, **kwargs)
        
        self.training_time += self.training_time_dp

# %%
test_accs_dp10 = []
training_times_dp10 = []
for i in range(1):
    m = EmptyDecoder(10, separate_encoders=False, separate_decoders=False, first_models=False, epsilon=1e6)
    m.train(dp=True, epochs=10)
    #m.fine_tune(epochs=5)
    test_accs_dp10.extend([x[-1] for x in m.test_accs])
    training_times_dp10.append(m.training_time)
print(f"Average training time", np.mean(training_times_dp10))
print(f"Average test accuracy", np.mean(test_accs_dp10))
print(f"Median test accuracy", np.median(test_accs_dp10))
print(f"Standard deviation test accuracy", np.std(test_accs_dp10))
# Out:
# Second Models
# <class '__main__.EncoderCNN2'>
# <class '__main__.DecoderCNN2'>
# data slice [46832, ..., 1555]
# data slice [31874, ..., 10270]
# data slice [47191, ..., 37569]
# data slice [56936, ..., 48741]
# data slice [20658, ..., 58834]
# data slice [22692, ..., 42243]
# data slice [59251, ..., 39880]
# data slice [45659, ..., 7007]
# data slice [19656, ..., 14762]
# data slice [49080, ..., 59971]
# Start of Epoch 0
# Average Train Loss: [1.8211, 1.8385, 1.8106, 1.817, 1.8412, 1.8141, 1.8226, 1.8204, 1.8336, 1.8349]
# Test Accuracy: [0.765, 0.78875, 0.7925, 0.7725, 0.7925, 0.7875, 0.76375, 0.79, 0.80125, 0.79]
# Start of Epoch 1
# Average Train Loss: [1.7218, 1.7361, 1.7088, 1.7136, 1.7385, 1.7165, 1.7221, 1.7167, 1.7317, 1.7276]
# Test Accuracy: [0.8775, 0.85125, 0.87, 0.85375, 0.83875, 0.8525, 0.8425, 0.85125, 0.865, 0.8625]
# Start of Epoch 2
# Average Train Loss: [1.6816, 1.6905, 1.6694, 1.6742, 1.6946, 1.6765, 1.6812, 1.6777, 1.6904, 1.6852]
# Test Accuracy: [0.85, 0.84625, 0.8525, 0.8625, 0.855, 0.85375, 0.85125, 0.8775, 0.86375, 0.8625]
# Start of Epoch 3
# Average Train Loss: [1.6612, 1.67, 1.65, 1.6544, 1.6734, 1.6563, 1.6607, 1.657, 1.6684, 1.6649]
# Test Accuracy: [0.8275, 0.81625, 0.8225, 0.8025, 0.82, 0.82625, 0.82625, 0.8275, 0.825, 0.80125]
# Start of Epoch 4
# Average Train Loss: [1.6377, 1.6449, 1.6286, 1.6306, 1.6475, 1.6328, 1.6358, 1.6331, 1.6423, 1.6396]
# Test Accuracy: [0.95875, 0.94625, 0.9475, 0.955, 0.95375, 0.96, 0.94875, 0.95375, 0.95625, 0.95375]
# Start of Epoch 5
# Average Train Loss: [1.6156, 1.622, 1.6083, 1.6093, 1.6238, 1.6113, 1.6133, 1.6117, 1.6203, 1.6174]
# Test Accuracy: [0.965, 0.955, 0.96375, 0.96, 0.97125, 0.96875, 0.95125, 0.9525, 0.96375, 0.9625]
# Start of Epoch 6
# Average Train Loss: [1.5983, 1.6037, 1.5925, 1.5914, 1.6059, 1.5942, 1.596, 1.5945, 1.6027, 1.6]
# Test Accuracy: [0.9775, 0.96125, 0.965, 0.96375, 0.965, 0.965, 0.96625, 0.965, 0.95625, 0.9725]
# Start of Epoch 7
# Average Train Loss: [1.5857, 1.59, 1.5808, 1.5787, 1.5925, 1.5811, 1.5829, 1.5823, 1.5893, 1.5872]
# Test Accuracy: [0.9675, 0.96625, 0.9725, 0.9575, 0.955, 0.9625, 0.97375, 0.95625, 0.9525, 0.96375]
# Start of Epoch 8
# Average Train Loss: [1.5746, 1.5793, 1.5706, 1.5685, 1.5814, 1.5704, 1.5721, 1.5718, 1.5785, 1.5761]
# Test Accuracy: [0.965, 0.97375, 0.97, 0.97, 0.9575, 0.98, 0.9625, 0.9725, 0.96875, 0.95875]
# Start of Epoch 9
# Average Train Loss: [1.5666, 1.5704, 1.5625, 1.5598, 1.5725, 1.5625, 1.5633, 1.5631, 1.5695, 1.5674]
# Test Accuracy: [0.965, 0.9675, 0.96125, 0.97625, 0.97375, 0.96625, 0.975, 0.98, 0.97375, 0.97375]
# Finished Training
# Elapsed Test Time: 15.9827721118927
# Elapsed Training Time: 61.58276557922363
# Final Test Accuracy: [0.9712, 0.9723, 0.972, 0.9723, 0.9705, 0.9721, 0.9725, 0.971, 0.9715, 0.9712]
# Average training time 61.58276557922363
# Average test accuracy 0.97166
# Median test accuracy 0.97175
# Standard deviation test accuracy 0.0006374950980203836

# %%
test_accs_dp10 = []
training_times_dp10 = []
for i in range(1):
    m = EmptyDecoder(10, separate_encoders=False, separate_decoders=False, first_models=False, epsilon=2e5)
    m.train(dp=True, epochs=10)
    #m.fine_tune(epochs=5)
    test_accs_dp10.extend([x[-1] for x in m.test_accs])
    training_times_dp10.append(m.training_time)
print(f"Average training time", np.mean(training_times_dp10))
print(f"Average test accuracy", np.mean(test_accs_dp10))
print(f"Median test accuracy", np.median(test_accs_dp10))
print(f"Standard deviation test accuracy", np.std(test_accs_dp10))
# Out:
# Second Models
# <class '__main__.EncoderCNN2'>
# <class '__main__.DecoderCNN2'>
# data slice [48846, ..., 13431]
# data slice [7406, ..., 39944]
# data slice [25688, ..., 34640]
# data slice [10729, ..., 6981]
# data slice [29883, ..., 14167]
# data slice [59553, ..., 1290]
# data slice [58437, ..., 38177]
# data slice [31837, ..., 2395]
# data slice [11147, ..., 51147]
# data slice [44380, ..., 24510]
# Start of Epoch 0
# Average Train Loss: [1.8089, 1.7899, 1.8149, 1.7743, 1.7849, 1.7919, 1.7658, 1.762, 1.7857, 1.7878]
# Test Accuracy: [0.76125, 0.795, 0.7575, 0.75625, 0.77875, 0.76125, 0.7525, 0.77375, 0.74375, 0.755]
# Start of Epoch 1
# Average Train Loss: [1.7475, 1.7349, 1.7506, 1.7119, 1.729, 1.7346, 1.71, 1.7173, 1.7325, 1.7258]

    test_accs_dp10.extend([x[-1] for x in m.test_accs])
    training_times_dp10.append(m.training_time)
print(f"Average training time", np.mean(training_times_dp10))
print(f"Average test accuracy", np.mean(test_accs_dp10))
print(f"Median test accuracy", np.median(test_accs_dp10))
print(f"Standard deviation test accuracy", np.std(test_accs_dp10))
# Out:
# Second Models
# <class '__main__.EncoderCNN2'>
# <class '__main__.DecoderCNN2'>
# data slice [48304, ..., 6709]
# data slice [53129, ..., 48192]
# data slice [26819, ..., 40633]
# data slice [37345, ..., 21909]
# data slice [27175, ..., 7624]
# data slice [34167, ..., 358]
# data slice [37179, ..., 52088]
# data slice [2327, ..., 29179]
# data slice [37973, ..., 44675]
# data slice [58255, ..., 24982]
# Start of Epoch 0
# Average Train Loss: [1.7832, 1.7838, 1.7893, 1.778, 1.7763, 1.7809, 1.7678, 1.7741, 1.7652, 1.765]
# Test Accuracy: [0.79, 0.78875, 0.78, 0.7675, 0.78625, 0.775, 0.7675, 0.76875, 0.81, 0.78]
# Start of Epoch 1
# Average Train Loss: [1.7466, 1.7422, 1.7517, 1.7432, 1.7343, 1.7445, 1.7306, 1.7421, 1.7302, 1.7293]
# Test Accuracy: [0.715, 0.75375, 0.7425, 0.72875, 0.7425, 0.725, 0.7625, 0.71, 0.75, 0.76125]
# Start of Epoch 2
# Average Train Loss: [1.7222, 1.7181, 1.7248, 1.7189, 1.7124, 1.7179, 1.7039, 1.7196, 1.7062, 1.7055]
# Test Accuracy: [0.82, 0.8175, 0.81875, 0.8075, 0.8275, 0.83, 0.81125, 0.82125, 0.81625, 0.82625]
# Start of Epoch 3
# Average Train Loss: [1.7073, 1.7026, 1.7088, 1.7027, 1.6953, 1.7016, 1.6866, 1.7048, 1.6902, 1.6897]
# Test Accuracy: [0.84125, 0.845, 0.85875, 0.85375, 0.81875, 0.815, 0.82375, 0.835, 0.8375, 0.835]
# Start of Epoch 4
# Average Train Loss: [1.6937, 1.6878, 1.6933, 1.6891, 1.6812, 1.6877, 1.6699, 1.6915, 1.6765, 1.6753]
# Test Accuracy: [0.83875, 0.825, 0.8525, 0.855, 0.84125, 0.845, 0.85875, 0.84625, 0.8575, 0.8675]
# Start of Epoch 5
# Average Train Loss: [1.6842, 1.6784, 1.6837, 1.679, 1.6707, 1.6776, 1.6589, 1.6813, 1.6676, 1.6654]
# Test Accuracy: [0.825, 0.8375, 0.8275, 0.81375, 0.815, 0.82375, 0.815, 0.83875, 0.82375, 0.81]
# Start of Epoch 6
# Average Train Loss: [1.6794, 1.672, 1.6774, 1.6732, 1.6642, 1.6716, 1.6523, 1.6753, 1.6628, 1.6601]
# Test Accuracy: [0.85875, 0.84875, 0.85375, 0.845, 0.8525, 0.83, 0.82125, 0.85, 0.84625, 0.83875]
# Start of Epoch 7
# Average Train Loss: [1.6733, 1.6656, 1.671, 1.6669, 1.6577, 1.6656, 1.6446, 1.669, 1.657, 1.6539]
# Test Accuracy: [0.84125, 0.8425, 0.825, 0.82875, 0.84875, 0.86125, 0.84625, 0.84125, 0.845, 0.855]
# Finished Training
# Elapsed Test Time: 12.66003155708313
# Elapsed Training Time: 48.479599714279175
# Final Test Accuracy: [0.8409, 0.8419, 0.8412, 0.8438, 0.8434, 0.8452, 0.8414, 0.8466, 0.8421, 0.8447]
# Start of Epoch 0
# Average Train Loss: [1.623, 1.6181, 1.6224, 1.6179, 1.6076, 1.6159, 1.5882, 1.6233, 1.6139, 1.6042]
# Test Accuracy: [0.86875, 0.86875, 0.83, 0.83, 0.85625, 0.835, 0.82625, 0.85125, 0.8375, 0.83375]
# Start of Epoch 1
# Average Train Loss: [1.6162, 1.6119, 1.6163, 1.6133, 1.6041, 1.6091, 1.5832, 1.6162, 1.6114, 1.5989]
# Test Accuracy: [0.85125, 0.8525, 0.86375, 0.84875, 0.8175, 0.83375, 0.86875, 0.83625, 0.8375, 0.84125]
# Finished Training
# Elapsed Test Time: 3.5182883739471436
# Elapsed Training Time: 6.410220146179199
# Final Test Accuracy: [0.8447, 0.8444, 0.845, 0.8491, 0.846, 0.8411, 0.85, 0.8413, 0.8474, 0.8404]
# Average training time 54.889819860458374
# Average test accuracy 0.84494
# Median test accuracy 0.84485
# Standard deviation test accuracy 0.0031471256727369375

# %%
test_accs_dp10 = []
training_times_dp10 = []
for i in range(1):
    m = EmptyDecoder(10, separate_encoders=False, separate_decoders=False, first_models=False, epsilon=1e4)
    m.train(dp=True, epochs=10)
    #m.fine_tune(epochs=5)
    test_accs_dp10.extend([x[-1] for x in m.test_accs])
    training_times_dp10.append(m.training_time)
print(f"Average training time", np.mean(training_times_dp10))
print(f"Average test accuracy", np.mean(test_accs_dp10))
print(f"Median test accuracy", np.median(test_accs_dp10))
print(f"Standard deviation test accuracy", np.std(test_accs_dp10))
# Out:
# Second Models
# <class '__main__.EncoderCNN2'>
# <class '__main__.DecoderCNN2'>
# data slice [49153, ..., 48891]
# data slice [22724, ..., 57320]
# data slice [42540, ..., 16539]
# data slice [31826, ..., 34647]
# data slice [18616, ..., 24885]
# data slice [44709, ..., 4970]
# data slice [38983, ..., 34016]
# data slice [25328, ..., 42468]
# data slice [17899, ..., 57963]
# data slice [19216, ..., 2970]
# Start of Epoch 0
# Average Train Loss: [1.9269, 1.9095, 1.9013, 1.9404, 1.8973, 1.9184, 1.9038, 1.9147, 1.8994, 1.8902]
# Test Accuracy: [0.67125, 0.6725, 0.66375, 0.64125, 0.6675, 0.64375, 0.65, 0.66375, 0.6725, 0.64125]
# Start of Epoch 1
# Average Train Loss: [1.8777, 1.857, 1.8483, 1.8882, 1.8557, 1.8703, 1.8612, 1.8648, 1.8588, 1.8416]
# Test Accuracy: [0.6825, 0.67375, 0.67125, 0.65875, 0.665, 0.6675, 0.66625, 0.65375, 0.65625, 0.6725]
# Start of Epoch 2
# Average Train Loss: [1.8586, 1.8392, 1.83, 1.8678, 1.8406, 1.85, 1.845, 1.8477, 1.841, 1.8251]
# Test Accuracy: [0.6275, 0.6575, 0.69, 0.69375, 0.6525, 0.7, 0.66, 0.69, 0.6875, 0.6775]
# Start of Epoch 3
# Average Train Loss: [1.8468, 1.8272, 1.8179, 1.8547, 1.8326, 1.8376, 1.8345, 1.8354, 1.8311, 1.8131]
# Test Accuracy: [0.64875, 0.685, 0.67625, 0.63375, 0.6675, 0.65, 0.6875, 0.64375, 0.62875, 0.66375]
# Start of Epoch 4
# Average Train Loss: [1.8387, 1.8179, 1.8091, 1.8463, 1.8266, 1.8285, 1.8271, 1.8255, 1.8231, 1.8051]
# Test Accuracy: [0.71375, 0.6775, 0.6675, 0.66625, 0.66125, 0.68, 0.67375, 0.6775, 0.68875, 0.67875]
# Start of Epoch 5
# Average Train Loss: [1.8313, 1.8114, 1.8012, 1.8385, 1.8198, 1.8211, 1.8212, 1.818, 1.8164, 1.7989]
# Test Accuracy: [0.665, 0.65375, 0.7025, 0.70125, 0.71625, 0.67875, 0.665, 0.68, 0.6975, 0.67125]
# Start of Epoch 6
# Average Train Loss: [1.8266, 1.8075, 1.7964, 1.8339, 1.8162, 1.8172, 1.8169, 1.8132, 1.8123, 1.794]
# Test Accuracy: [0.68125, 0.6675, 0.6725, 0.68625, 0.67875, 0.6775, 0.68625, 0.67, 0.68, 0.65375]
# Start of Epoch 7
# Average Train Loss: [1.822, 1.8031, 1.7918, 1.8291, 1.8116, 1.8123, 1.8129, 1.808, 1.8084, 1.7896]
# Test Accuracy: [0.6875, 0.6925, 0.67875, 0.66, 0.66375, 0.66375, 0.6925, 0.71625, 0.6775, 0.68125]
# Start of Epoch 8
# Average Train Loss: [1.8184, 1.7995, 1.7879, 1.8245, 1.8079, 1.8079, 1.8092, 1.8037, 1.8046, 1.786]
# Test Accuracy: [0.66125, 0.68375, 0.66875, 0.70875, 0.70125, 0.68375, 0.68375, 0.68375, 0.6725, 0.70125]
# Start of Epoch 9
# Average Train Loss: [1.8153, 1.7972, 1.7854, 1.8213, 1.8049, 1.8053, 1.8071, 1.8006, 1.8022, 1.7838]
# Test Accuracy: [0.715, 0.65625, 0.705, 0.68625, 0.68125, 0.71875, 0.67, 0.6675, 0.70125, 0.71125]
# Finished Training
# Elapsed Test Time: 15.785291194915771
# Elapsed Training Time: 60.41251611709595
# Final Test Accuracy: [0.6839, 0.6827, 0.6771, 0.6817, 0.6866, 0.683, 0.6843, 0.6854, 0.6843, 0.6847]
# Average training time 60.41251611709595
# Average test accuracy 0.6833700000000001
# Median test accuracy 0.6840999999999999
# Standard deviation test accuracy 0.0024702429030360466

# %%
test_accs_dp10 = []
training_times_dp10 = []
for i in range(1):
    m = EmptyDecoder(10, separate_encoders=False, separate_decoders=False, first_models=False, epsilon=1e3)
    m.train(dp=True, epochs=10)
    #m.fine_tune(epochs=5)
    test_accs_dp10.extend([x[-1] for x in m.test_accs])
    training_times_dp10.append(m.training_time)
print(f"Average training time", np.mean(training_times_dp10))
print(f"Average test accuracy", np.mean(test_accs_dp10))
print(f"Median test accuracy", np.median(test_accs_dp10))
print(f"Standard deviation test accuracy", np.std(test_accs_dp10))
# Out:
# Second Models
# <class '__main__.EncoderCNN2'>
# <class '__main__.DecoderCNN2'>
# data slice [8858, ..., 51403]
# data slice [38373, ..., 58069]
# data slice [41965, ..., 59917]
# data slice [11494, ..., 25615]
# data slice [26869, ..., 25932]
# data slice [9763, ..., 59144]
# data slice [51701, ..., 8538]
# data slice [59592, ..., 2909]
# data slice [17898, ..., 42958]
# data slice [34255, ..., 14848]
# Start of Epoch 0
# Average Train Loss: [2.1687, 2.1735, 2.1769, 2.1635, 2.1695, 2.1755, 2.1676, 2.1559, 2.1614, 2.1792]
# Test Accuracy: [0.37125, 0.35375, 0.35625, 0.35, 0.3575, 0.3425, 0.34875, 0.3875, 0.3675, 0.36]
# Start of Epoch 1
# Average Train Loss: [2.1353, 2.1384, 2.1368, 2.1243, 2.1474, 2.1424, 2.1254, 2.1226, 2.1279, 2.1523]
# Test Accuracy: [0.355, 0.3525, 0.3475, 0.395, 0.3675, 0.37625, 0.37375, 0.3575, 0.33875, 0.37875]
# Start of Epoch 2
# Average Train Loss: [2.0787, 2.0785, 2.0818, 2.0699, 2.0956, 2.0868, 2.0716, 2.0746, 2.0747, 2.1006]
# Test Accuracy: [0.6225, 0.65125, 0.64, 0.65125, 0.63, 0.61, 0.62, 0.62, 0.64, 0.62625]
# Start of Epoch 3
# Average Train Loss: [2.0177, 2.0104, 2.0149, 2.0027, 2.0265, 2.0219, 2.0032, 2.0129, 2.0088, 2.0398]
# Test Accuracy: [0.7125, 0.6975, 0.72125, 0.68375, 0.7, 0.70625, 0.68125, 0.6975, 0.71875, 0.6825]
# Start of Epoch 4
# Average Train Loss: [1.9713, 1.9598, 1.9685, 1.952, 1.9732, 1.9738, 1.9545, 1.9705, 1.9602, 1.9946]
# Test Accuracy: [0.71625, 0.70125, 0.7225, 0.72375, 0.7425, 0.7275, 0.685, 0.73125, 0.71875, 0.72625]
# Start of Epoch 5
# Average Train Loss: [1.9407, 1.9257, 1.9369, 1.92, 1.9406, 1.9407, 1.9221, 1.9402, 1.9275, 1.9642]
# Test Accuracy: [0.6575, 0.66875, 0.68375, 0.6575, 0.6375, 0.6675, 0.68875, 0.65875, 0.69125, 0.67]
# Start of Epoch 6
# Average Train Loss: [1.9135, 1.895, 1.9073, 1.8897, 1.9102, 1.9111, 1.8931, 1.9126, 1.8966, 1.9334]
# Test Accuracy: [0.785, 0.7475, 0.7475, 0.75, 0.76625, 0.72875, 0.76, 0.73125, 0.76, 0.7625]
# Start of Epoch 7
# Average Train Loss: [1.881, 1.8649, 1.8782, 1.8599, 1.8788, 1.8797, 1.8632, 1.8819, 1.8662, 1.9007]
# Test Accuracy: [0.8325, 0.8175, 0.81625, 0.83125, 0.82, 0.81875, 0.8325, 0.8525, 0.8125, 0.8525]
# Start of Epoch 8
# Average Train Loss: [1.8558, 1.8408, 1.8534, 1.8354, 1.8545, 1.854, 1.8392, 1.8572, 1.8417, 1.8751]
# Test Accuracy: [0.84625, 0.83875, 0.81625, 0.8425, 0.8275, 0.81625, 0.825, 0.8475, 0.81, 0.81875]
# Start of Epoch 9
# Average Train Loss: [1.837, 1.8238, 1.8368, 1.8185, 1.8368, 1.836, 1.8236, 1.8392, 1.8234, 1.8563]
# Test Accuracy: [0.83625, 0.83, 0.82625, 0.805, 0.8275, 0.83875, 0.83625, 0.82125, 0.81375, 0.84]
# Finished Training
# Elapsed Test Time: 15.902871131896973
# Elapsed Training Time: 60.887537717819214
# Final Test Accuracy: [0.8295, 0.828, 0.8247, 0.8298, 0.8289, 0.8272, 0.8279, 0.8291, 0.8304, 0.8268]
# Average training time 60.887537717819214
# Average test accuracy 0.8282299999999999
# Median test accuracy 0.8284499999999999
# Standard deviation test accuracy 0.0016037767924496245

# %%
test_accs_dp10 = []
training_times_dp10 = []
for i in range(1):
    m = EmptyDecoder(10, separate_encoders=False, separate_decoders=False, first_models=False, epsilon=1e2)
    m.train(dp=True, epochs=10)
    #m.fine_tune(epochs=5)
    test_accs_dp10.extend([x[-1] for x in m.test_accs])
    training_times_dp10.append(m.training_time)
print(f"Average training time", np.mean(training_times_dp10))
print(f"Average test accuracy", np.mean(test_accs_dp10))
print(f"Median test accuracy", np.median(test_accs_dp10))
print(f"Standard deviation test accuracy", np.std(test_accs_dp10))
# Out:
# Second Models
# <class '__main__.EncoderCNN2'>
# <class '__main__.DecoderCNN2'>
# data slice [45990, ..., 30972]
# data slice [43637, ..., 39553]
# data slice [50585, ..., 29423]
# data slice [43735, ..., 53254]
# data slice [34567, ..., 30669]
# data slice [33318, ..., 8847]
# data slice [37541, ..., 11666]
# data slice [5517, ..., 42705]
# data slice [43474, ..., 20326]
# data slice [58052, ..., 34057]
# Start of Epoch 0
# Average Train Loss: [2.0628, 2.0485, 2.0595, 2.0697, 2.0808, 2.0722, 2.0482, 2.0656, 2.0789, 2.0342]
# Test Accuracy: [0.4875, 0.49625, 0.48625, 0.4725, 0.45375, 0.48375, 0.4825, 0.45375, 0.48875, 0.50875]
# Start of Epoch 1
# Average Train Loss: [2.0816, 2.0753, 2.0729, 2.0873, 2.097, 2.0878, 2.0664, 2.0855, 2.0967, 2.061]
# Test Accuracy: [0.37125, 0.35375, 0.385, 0.39375, 0.4025, 0.3975, 0.42875, 0.3775, 0.38625, 0.40625]
# Start of Epoch 2
# Average Train Loss: [2.0775, 2.0691, 2.0679, 2.0831, 2.0905, 2.0834, 2.0583, 2.0842, 2.0925, 2.0588]
# Test Accuracy: [0.42625, 0.4525, 0.44625, 0.44125, 0.43625, 0.45375, 0.4475, 0.415, 0.42125, 0.4575]
# Start of Epoch 3
# Average Train Loss: [2.0698, 2.0634, 2.0601, 2.0756, 2.0833, 2.0777, 2.0497, 2.0766, 2.0856, 2.0526]
# Test Accuracy: [0.43125, 0.43875, 0.45875, 0.4425, 0.43125, 0.45625, 0.43375, 0.4575, 0.4625, 0.42625]
# Start of Epoch 4
# Average Train Loss: [2.0796, 2.0748, 2.0716, 2.0856, 2.0917, 2.089, 2.0605, 2.0878, 2.0958, 2.0647]
# Test Accuracy: [0.09375, 0.095, 0.09125, 0.10375, 0.12125, 0.09375, 0.10625, 0.0975, 0.09, 0.0825]
# Start of Epoch 5
# Average Train Loss: [2.1168, 2.1128, 2.1102, 2.1217, 2.1268, 2.1247, 2.1009, 2.1237, 2.1303, 2.1043]
# Test Accuracy: [0.11, 0.10875, 0.0925, 0.1225, 0.09875, 0.09125, 0.10875, 0.09, 0.10125, 0.095]
# Start of Epoch 6
# Average Train Loss: [2.1434, 2.1399, 2.1377, 2.1474, 2.1518, 2.1501, 2.1298, 2.1493, 2.1549, 2.1326]
# Test Accuracy: [0.10625, 0.115, 0.115, 0.0975, 0.10125, 0.09875, 0.0875, 0.10625, 0.0925, 0.11875]
# Start of Epoch 7
# Average Train Loss: [2.1633, 2.1602, 2.1583, 2.1667, 2.1706, 2.1692, 2.1514, 2.1685, 2.1734, 2.1538]
# Test Accuracy: [0.08375, 0.085, 0.0925, 0.095, 0.09375, 0.0925, 0.10375, 0.09, 0.0925, 0.1075]
# Start of Epoch 8
# Average Train Loss: [2.1788, 2.176, 2.1743, 2.1817, 2.1853, 2.1841, 2.1683, 2.1834, 2.1878, 2.1703]
# Test Accuracy: [0.1025, 0.105, 0.0775, 0.08375, 0.09375, 0.11625, 0.10625, 0.10375, 0.10125, 0.10125]
# Start of Epoch 9
# Average Train Loss: [2.1912, 2.1886, 2.1872, 2.1937, 2.1969, 2.1959, 2.1817, 2.1953, 2.1993, 2.1835]
# Test Accuracy: [0.10625, 0.11625, 0.105, 0.10875, 0.07875, 0.09125, 0.095, 0.115, 0.10625, 0.10125]
# Finished Training
# Elapsed Test Time: 15.764744997024536
# Elapsed Training Time: 64.5399067401886
# Final Test Accuracy: [0.0965, 0.0976, 0.0962, 0.0958, 0.0974, 0.0997, 0.0993, 0.1014, 0.0965, 0.0983]
# Average training time 64.5399067401886
# Average test accuracy 0.09787000000000001
# Median test accuracy 0.0975
# Standard deviation test accuracy 0.0017076592165886036
